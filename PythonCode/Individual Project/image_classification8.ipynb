# %% [markdown]
# # Import Libraries

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dropout, Flatten, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.models import load_model
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np

# %%
   # Configure TensorFlow to grow GPU memory allocation as needed
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# %% [markdown]
# Downloading CIFAR 10:

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %% [markdown]
# The standard practice for splitting data into training, validation, and test sets typically follows these guidelines:
# Training Set (60-80%): Used to train the model
# Validation Set (10-20%): Used for hyperparameter tuning and model selection
# Test Set (10-20%): Used for final model evaluation
#
# Since the training and test set are already split in this data set in a 1/6 proportion, we will further carve 10% out of the training set to be used for validation.
#
# Source: https://www.v7labs.com/blog/train-validation-test-set

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.15, random_state=0)

# %%
print('Train Images Shape:      ', X_train.shape)
print('Train Labels Shape:      ', y_train.shape)

print('\nValidation Images Shape: ', X_valid.shape)
print('Validation Labels Shape: ', y_valid.shape)

print('\nTest Images Shape:       ', X_test.shape)
print('Test Labels Shape:       ', y_test.shape)
# Out:
# Train Images Shape:       (42500, 32, 32, 3)
# Train Labels Shape:       (42500, 1)
#
# Validation Images Shape:  (7500, 32, 32, 3)
# Validation Labels Shape:  (7500, 1)
#
# Test Images Shape:        (10000, 32, 32, 3)
# Test Labels Shape:        (10000, 1)

# %%
# Display a 3x3 grid of random images
plt.figure(figsize=(8, 8))

# Define the class names, so that they can be shown in the plot
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# Plot 9 random images from the training set
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.imshow(X_train[i])
    plt.title(f'Class: {class_names[y_train[i][0]]}')
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
# Convert pixel values data type to float32
X_train = X_train.astype('float32')
X_test  = X_test.astype('float32')
X_valid = X_valid.astype('float32')

# Calculate the mean and standard deviation of the training images
mean = np.mean(X_train)
std  = np.std(X_train)

# Normalize the data
# The tiny value 1e-7 is added to prevent division by zero
X_train = (X_train-mean)/(std+1e-7)
X_test  = (X_test-mean) /(std+1e-7)
X_valid = (X_valid-mean)/(std+1e-7)

# %%
# One-hot encoding of labels
y_train = to_categorical(y_train, 10)
y_valid = to_categorical(y_valid, 10)
y_test  = to_categorical(y_test, 10)

# %% [markdown]
# # Data Augmentation
#
# Rotation:
#
# Source: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0
#
# Horizontal Flip:
#
# Source: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0
#
# Brightness:
#
# Source: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0
#
# Zoom:
#
# Source: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0
#
# Shearing:
#
# Source: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0
#
# Future work. Try:
# * Patch Suffle Regularization
# * Sample Pairing
# * Random Erasing

# %%
# Data augmentation
data_generator = ImageDataGenerator(
    # Rotate images randomly by up to 15 degrees
    rotation_range=15,
    # Randomly flip images horizontally
    horizontal_flip=True,
    # Shift images horizontally by up to 12% of their width
    width_shift_range=0.12,
    # Shift images vertically by up to 12% of their height
    height_shift_range=0.12,
    # Zoom images in by up to 10%
    zoom_range=0.1,
    # Change brightness by up to 10%
    brightness_range=[0.9,1.1],
    # Shear intensity (shear angle in counter-clockwise direction in degrees)
    shear_range=10,
    # Channel shift intensity
    channel_shift_range=0.1,
)

# %% [markdown]
# Using mixed precision training (FP16) which can significantly speed up training on modern GPUs

# %%
# Enable mixed precision training
tf.keras.mixed_precision.set_global_policy('mixed_float16')

# %% [markdown]
# Building the VGG16 inspired model
#
# Source: https://www.kaggle.com/code/farzadnekouei/cifar-10-image-classification-with-cnn

# %%
# Initialize a sequential model
model = Sequential()

# Set the weight decay value for L2 regularization
weight_decay = 0.0001

# Add the first convolutional layer with 32 filters of size 3x3
model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay), 
                 input_shape=X_train.shape[1:]))
# Add batch normalization layer
model.add(BatchNormalization())

# Add the second convolutional layer similar to the first
model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the first max pooling layer with pool size of 2x2
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add dropout layer with 0.2 dropout rate
model.add(Dropout(rate=0.2))

# Add the third and fourth convolutional layers with 64 filters
model.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))   
model.add(BatchNormalization())
model.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the second max pooling layer and increase dropout rate to 0.3
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.3))

# Add the fifth and sixth convolutional layers with 128 filters
model.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay))) 
model.add(BatchNormalization())
model.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the third max pooling layer and increase dropout rate to 0.4
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.4))

# Add the seventh and eighth convolutional layers with 256 filters
model.add(Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay))) 
model.add(BatchNormalization())
model.add(Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the fourth max pooling layer and increase dropout rate to 0.5
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.5))

# Flatten the tensor output from the previous layer
model.add(Flatten())

# Add a fully connected layer with softmax activation function for outputting class probabilities
model.add(Dense(10, activation='softmax'))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-04-14 09:40:17.295278: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Pro
# 2025-04-14 09:40:17.295444: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-04-14 09:40:17.295454: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2025-04-14 09:40:17.295617: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-04-14 09:40:17.295629: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 4, 4, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 4, 4, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 4, 4, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 4, 4, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 2, 2, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 2, 2, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │        10,250 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,186,346 (4.53 MB)
#  Trainable params: 1,184,426 (4.52 MB)
#  Non-trainable params: 1,920 (7.50 KB)

# %%
# Set the batch size for the training
batch_size = 64

# Set the maximum number of epochs for the training
epochs = 300

# Define the optimizer (Adam)
optimizer = Adam(learning_rate=0.0005)

# Compile the model with the defined optimizer, loss function, and metrics
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Add ReduceLROnPlateau callback
# Here, the learning rate will be reduced by half (factor=0.5) if no improvement in validation loss is observed for 10 epochs
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=0.00001)

# Add EarlyStopping callback
# Here, training will be stopped if no improvement in validation loss is observed for 40 epochs.
# The `restore_best_weights` parameter ensures that the model weights are reset to the values from the epoch
# with the best value of the monitored quantity (in this case, 'val_loss').
early_stopping = EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True, verbose=1)

# Fit the model on the training data, using the defined batch size and number of epochs
# The validation data is used to evaluate the model's performance during training
# The callbacks implemented are learning rate reduction when a plateau is reached in validation loss and
# stopping training early if no improvement is observed
model.fit(data_generator.flow(X_train, y_train, batch_size=batch_size, shuffle=True),
          epochs=epochs,
          validation_data=(X_valid, y_valid),
          callbacks=[reduce_lr, early_stopping], 
          verbose=2)
# Out:
# Epoch 1/300
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2025-04-14 09:40:19.524307: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 665/665 - 47s - 71ms/step - accuracy: 0.3247 - loss: 2.4095 - val_accuracy: 0.4408 - val_loss: 1.7783 - learning_rate: 5.0000e-04
# Epoch 2/300
# 665/665 - 36s - 55ms/step - accuracy: 0.4515 - loss: 1.7662 - val_accuracy: 0.5088 - val_loss: 1.5053 - learning_rate: 5.0000e-04
# Epoch 3/300
# 665/665 - 37s - 56ms/step - accuracy: 0.5120 - loss: 1.6045 - val_accuracy: 0.5299 - val_loss: 1.5025 - learning_rate: 5.0000e-04
# Epoch 4/300
# 665/665 - 38s - 57ms/step - accuracy: 0.5558 - loss: 1.4674 - val_accuracy: 0.6064 - val_loss: 1.2482 - learning_rate: 5.0000e-04
# Epoch 5/300
# 665/665 - 38s - 56ms/step - accuracy: 0.5822 - loss: 1.4042 - val_accuracy: 0.6147 - val_loss: 1.3081 - learning_rate: 5.0000e-04
# Epoch 6/300
# 665/665 - 38s - 57ms/step - accuracy: 0.6072 - loss: 1.3263 - val_accuracy: 0.6147 - val_loss: 1.2656 - learning_rate: 5.0000e-04
# Epoch 7/300
# 665/665 - 38s - 56ms/step - accuracy: 0.6201 - loss: 1.3061 - val_accuracy: 0.6783 - val_loss: 1.0603 - learning_rate: 5.0000e-04
# Epoch 8/300
# 665/665 - 38s - 57ms/step - accuracy: 0.6497 - loss: 1.2124 - val_accuracy: 0.6981 - val_loss: 1.0023 - learning_rate: 5.0000e-04
# Epoch 9/300
# 665/665 - 38s - 57ms/step - accuracy: 0.6416 - loss: 1.2860 - val_accuracy: 0.6731 - val_loss: 1.0858 - learning_rate: 5.0000e-04
# Epoch 10/300
# 665/665 - 37s - 56ms/step - accuracy: 0.6583 - loss: 1.2016 - val_accuracy: 0.6676 - val_loss: 1.2688 - learning_rate: 5.0000e-04
# Epoch 11/300
# 665/665 - 37s - 56ms/step - accuracy: 0.6721 - loss: 1.1620 - val_accuracy: 0.6569 - val_loss: 1.1705 - learning_rate: 5.0000e-04
# Epoch 12/300
# 665/665 - 38s - 57ms/step - accuracy: 0.6828 - loss: 1.1314 - val_accuracy: 0.7121 - val_loss: 0.9906 - learning_rate: 5.0000e-04
# Epoch 13/300
# 665/665 - 37s - 56ms/step - accuracy: 0.7040 - loss: 1.0651 - val_accuracy: 0.7293 - val_loss: 0.9581 - learning_rate: 5.0000e-04
# Epoch 14/300
# 665/665 - 40s - 59ms/step - accuracy: 0.7081 - loss: 1.0445 - val_accuracy: 0.7475 - val_loss: 0.9465 - learning_rate: 5.0000e-04
# Epoch 15/300
# 665/665 - 40s - 60ms/step - accuracy: 0.7148 - loss: 1.0351 - val_accuracy: 0.7116 - val_loss: 1.0309 - learning_rate: 5.0000e-04
# Epoch 16/300
# 665/665 - 38s - 58ms/step - accuracy: 0.7191 - loss: 1.0225 - val_accuracy: 0.7304 - val_loss: 1.0507 - learning_rate: 5.0000e-04
# Epoch 17/300
# 665/665 - 39s - 58ms/step - accuracy: 0.7181 - loss: 1.0353 - val_accuracy: 0.7551 - val_loss: 0.9053 - learning_rate: 5.0000e-04
# Epoch 18/300
# 665/665 - 39s - 59ms/step - accuracy: 0.7308 - loss: 0.9903 - val_accuracy: 0.7660 - val_loss: 0.8848 - learning_rate: 5.0000e-04
# Epoch 19/300
# 665/665 - 40s - 60ms/step - accuracy: 0.7406 - loss: 0.9683 - val_accuracy: 0.7768 - val_loss: 0.8449 - learning_rate: 5.0000e-04
# Epoch 20/300
# 665/665 - 38s - 58ms/step - accuracy: 0.7358 - loss: 0.9781 - val_accuracy: 0.7528 - val_loss: 0.9516 - learning_rate: 5.0000e-04
# Epoch 21/300
# 665/665 - 38s - 57ms/step - accuracy: 0.7420 - loss: 0.9610 - val_accuracy: 0.7912 - val_loss: 0.8014 - learning_rate: 5.0000e-04
# Epoch 22/300
# 665/665 - 38s - 57ms/step - accuracy: 0.7500 - loss: 0.9385 - val_accuracy: 0.7736 - val_loss: 0.8729 - learning_rate: 5.0000e-04
# Epoch 23/300
# 665/665 - 38s - 57ms/step - accuracy: 0.7573 - loss: 0.9156 - val_accuracy: 0.8105 - val_loss: 0.7466 - learning_rate: 5.0000e-04
# Epoch 24/300
# 665/665 - 38s - 57ms/step - accuracy: 0.7586 - loss: 0.9184 - val_accuracy: 0.7781 - val_loss: 0.8477 - learning_rate: 5.0000e-04
# Epoch 25/300
# 665/665 - 38s - 57ms/step - accuracy: 0.7589 - loss: 0.9260 - val_accuracy: 0.8045 - val_loss: 0.7820 - learning_rate: 5.0000e-04
# Epoch 26/300
# 665/665 - 38s - 57ms/step - accuracy: 0.7629 - loss: 0.9129 - val_accuracy: 0.7781 - val_loss: 0.8634 - learning_rate: 5.0000e-04
# Epoch 27/300
# 665/665 - 38s - 57ms/step - accuracy: 0.7735 - loss: 0.8842 - val_accuracy: 0.7919 - val_loss: 0.8212 - learning_rate: 5.0000e-04
# Epoch 28/300
# 665/665 - 38s - 57ms/step - accuracy: 0.7715 - loss: 0.8800 - val_accuracy: 0.8077 - val_loss: 0.7762 - learning_rate: 5.0000e-04
# Epoch 29/300
# 665/665 - 38s - 57ms/step - accuracy: 0.7792 - loss: 0.8588 - val_accuracy: 0.7973 - val_loss: 0.8152 - learning_rate: 5.0000e-04
# Epoch 30/300
# 665/665 - 38s - 57ms/step - accuracy: 0.7813 - loss: 0.8576 - val_accuracy: 0.8341 - val_loss: 0.7093 - learning_rate: 5.0000e-04
# Epoch 31/300
# 665/665 - 38s - 57ms/step - accuracy: 0.7748 - loss: 0.8847 - val_accuracy: 0.8128 - val_loss: 0.7755 - learning_rate: 5.0000e-04
# Epoch 32/300
# 665/665 - 38s - 57ms/step - accuracy: 0.7826 - loss: 0.8617 - val_accuracy: 0.8257 - val_loss: 0.7308 - learning_rate: 5.0000e-04
# Epoch 33/300
# 665/665 - 38s - 57ms/step - accuracy: 0.7876 - loss: 0.8412 - val_accuracy: 0.8311 - val_loss: 0.7220 - learning_rate: 5.0000e-04
# Epoch 34/300
# 665/665 - 38s - 57ms/step - accuracy: 0.7885 - loss: 0.8374 - val_accuracy: 0.8332 - val_loss: 0.7071 - learning_rate: 5.0000e-04
# Epoch 35/300
# 665/665 - 38s - 57ms/step - accuracy: 0.7904 - loss: 0.8419 - val_accuracy: 0.8168 - val_loss: 0.7603 - learning_rate: 5.0000e-04
# Epoch 36/300
# 665/665 - 38s - 56ms/step - accuracy: 0.7873 - loss: 0.8484 - val_accuracy: 0.8265 - val_loss: 0.7329 - learning_rate: 5.0000e-04
# Epoch 37/300
# 665/665 - 37s - 55ms/step - accuracy: 0.7860 - loss: 0.8663 - val_accuracy: 0.8096 - val_loss: 0.7841 - learning_rate: 5.0000e-04
# Epoch 38/300
# 665/665 - 37s - 56ms/step - accuracy: 0.7968 - loss: 0.8208 - val_accuracy: 0.8413 - val_loss: 0.6832 - learning_rate: 5.0000e-04
# Epoch 39/300
# 665/665 - 37s - 56ms/step - accuracy: 0.8054 - loss: 0.7965 - val_accuracy: 0.8303 - val_loss: 0.7233 - learning_rate: 5.0000e-04
# Epoch 40/300
# 665/665 - 37s - 55ms/step - accuracy: 0.7987 - loss: 0.8121 - val_accuracy: 0.8101 - val_loss: 0.7915 - learning_rate: 5.0000e-04
# Epoch 41/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8010 - loss: 0.8165 - val_accuracy: 0.8248 - val_loss: 0.7508 - learning_rate: 5.0000e-04
# Epoch 42/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8006 - loss: 0.8234 - val_accuracy: 0.8412 - val_loss: 0.7008 - learning_rate: 5.0000e-04
# Epoch 43/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8112 - loss: 0.7931 - val_accuracy: 0.8404 - val_loss: 0.7072 - learning_rate: 5.0000e-04
# Epoch 44/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8066 - loss: 0.8002 - val_accuracy: 0.8281 - val_loss: 0.7422 - learning_rate: 5.0000e-04
# Epoch 45/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8126 - loss: 0.7760 - val_accuracy: 0.8397 - val_loss: 0.7013 - learning_rate: 5.0000e-04
# Epoch 46/300
# 665/665 - 37s - 56ms/step - accuracy: 0.8109 - loss: 0.7949 - val_accuracy: 0.8275 - val_loss: 0.7542 - learning_rate: 5.0000e-04
# Epoch 47/300
# 665/665 - 40s - 60ms/step - accuracy: 0.8108 - loss: 0.7813 - val_accuracy: 0.8293 - val_loss: 0.7551 - learning_rate: 5.0000e-04
# Epoch 48/300
# 665/665 - 40s - 61ms/step - accuracy: 0.8112 - loss: 0.7816 - val_accuracy: 0.8439 - val_loss: 0.7062 - learning_rate: 5.0000e-04
# Epoch 49/300
# 665/665 - 39s - 58ms/step - accuracy: 0.8229 - loss: 0.7488 - val_accuracy: 0.8479 - val_loss: 0.6919 - learning_rate: 2.5000e-04
# Epoch 50/300
# 665/665 - 38s - 58ms/step - accuracy: 0.8320 - loss: 0.7158 - val_accuracy: 0.8543 - val_loss: 0.6539 - learning_rate: 2.5000e-04
# Epoch 51/300
# 665/665 - 38s - 58ms/step - accuracy: 0.8323 - loss: 0.7047 - val_accuracy: 0.8473 - val_loss: 0.6646 - learning_rate: 2.5000e-04
# Epoch 52/300
# 665/665 - 38s - 58ms/step - accuracy: 0.8363 - loss: 0.6883 - val_accuracy: 0.8580 - val_loss: 0.6418 - learning_rate: 2.5000e-04
# Epoch 53/300
# 665/665 - 39s - 58ms/step - accuracy: 0.8384 - loss: 0.6826 - val_accuracy: 0.8549 - val_loss: 0.6377 - learning_rate: 2.5000e-04
# Epoch 54/300
# 665/665 - 39s - 58ms/step - accuracy: 0.8377 - loss: 0.6845 - val_accuracy: 0.8613 - val_loss: 0.6305 - learning_rate: 2.5000e-04
# Epoch 55/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8423 - loss: 0.6704 - val_accuracy: 0.8667 - val_loss: 0.6065 - learning_rate: 2.5000e-04
# Epoch 56/300
# 665/665 - 39s - 59ms/step - accuracy: 0.8411 - loss: 0.6694 - val_accuracy: 0.8605 - val_loss: 0.6257 - learning_rate: 2.5000e-04
# Epoch 57/300
# 665/665 - 39s - 58ms/step - accuracy: 0.8453 - loss: 0.6537 - val_accuracy: 0.8619 - val_loss: 0.6162 - learning_rate: 2.5000e-04
# Epoch 58/300
# 665/665 - 37s - 56ms/step - accuracy: 0.8436 - loss: 0.6567 - val_accuracy: 0.8645 - val_loss: 0.5922 - learning_rate: 2.5000e-04
# Epoch 59/300
# 665/665 - 39s - 58ms/step - accuracy: 0.8461 - loss: 0.6491 - val_accuracy: 0.8607 - val_loss: 0.6110 - learning_rate: 2.5000e-04
# Epoch 60/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8488 - loss: 0.6341 - val_accuracy: 0.8657 - val_loss: 0.6009 - learning_rate: 2.5000e-04
# Epoch 61/300
# 665/665 - 39s - 58ms/step - accuracy: 0.8456 - loss: 0.6476 - val_accuracy: 0.8628 - val_loss: 0.6111 - learning_rate: 2.5000e-04
# Epoch 62/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8488 - loss: 0.6348 - val_accuracy: 0.8732 - val_loss: 0.5719 - learning_rate: 2.5000e-04
# Epoch 63/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8511 - loss: 0.6244 - val_accuracy: 0.8809 - val_loss: 0.5561 - learning_rate: 2.5000e-04
# Epoch 64/300
# 665/665 - 38s - 58ms/step - accuracy: 0.8490 - loss: 0.6271 - val_accuracy: 0.8709 - val_loss: 0.5837 - learning_rate: 2.5000e-04
# Epoch 65/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8509 - loss: 0.6238 - val_accuracy: 0.8671 - val_loss: 0.5930 - learning_rate: 2.5000e-04
# Epoch 66/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8528 - loss: 0.6145 - val_accuracy: 0.8811 - val_loss: 0.5497 - learning_rate: 2.5000e-04
# Epoch 67/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8504 - loss: 0.6161 - val_accuracy: 0.8635 - val_loss: 0.5997 - learning_rate: 2.5000e-04
# Epoch 68/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8555 - loss: 0.6060 - val_accuracy: 0.8691 - val_loss: 0.5760 - learning_rate: 2.5000e-04
# Epoch 69/300
# 665/665 - 39s - 59ms/step - accuracy: 0.8536 - loss: 0.6039 - val_accuracy: 0.8725 - val_loss: 0.5706 - learning_rate: 2.5000e-04
# Epoch 70/300
# 665/665 - 40s - 60ms/step - accuracy: 0.8536 - loss: 0.6138 - val_accuracy: 0.8585 - val_loss: 0.6127 - learning_rate: 2.5000e-04
# Epoch 71/300
# 665/665 - 39s - 58ms/step - accuracy: 0.8573 - loss: 0.5977 - val_accuracy: 0.8641 - val_loss: 0.6000 - learning_rate: 2.5000e-04
# Epoch 72/300
# 665/665 - 39s - 58ms/step - accuracy: 0.8557 - loss: 0.5964 - val_accuracy: 0.8679 - val_loss: 0.5872 - learning_rate: 2.5000e-04
# Epoch 73/300
# 665/665 - 38s - 58ms/step - accuracy: 0.8574 - loss: 0.5978 - val_accuracy: 0.8700 - val_loss: 0.5729 - learning_rate: 2.5000e-04
# Epoch 74/300
# 665/665 - 39s - 59ms/step - accuracy: 0.8580 - loss: 0.5888 - val_accuracy: 0.8653 - val_loss: 0.5954 - learning_rate: 2.5000e-04
# Epoch 75/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8590 - loss: 0.5885 - val_accuracy: 0.8701 - val_loss: 0.5739 - learning_rate: 2.5000e-04
# Epoch 76/300
# 665/665 - 39s - 58ms/step - accuracy: 0.8584 - loss: 0.5835 - val_accuracy: 0.8724 - val_loss: 0.5548 - learning_rate: 2.5000e-04
# Epoch 77/300
# 665/665 - 39s - 59ms/step - accuracy: 0.8649 - loss: 0.5634 - val_accuracy: 0.8736 - val_loss: 0.5521 - learning_rate: 1.2500e-04
# Epoch 78/300
# 665/665 - 38s - 58ms/step - accuracy: 0.8698 - loss: 0.5559 - val_accuracy: 0.8787 - val_loss: 0.5397 - learning_rate: 1.2500e-04
# Epoch 79/300
# 665/665 - 39s - 59ms/step - accuracy: 0.8712 - loss: 0.5474 - val_accuracy: 0.8781 - val_loss: 0.5356 - learning_rate: 1.2500e-04
# Epoch 80/300
# 665/665 - 39s - 59ms/step - accuracy: 0.8716 - loss: 0.5400 - val_accuracy: 0.8767 - val_loss: 0.5415 - learning_rate: 1.2500e-04
# Epoch 81/300
# 665/665 - 39s - 59ms/step - accuracy: 0.8753 - loss: 0.5348 - val_accuracy: 0.8723 - val_loss: 0.5566 - learning_rate: 1.2500e-04
# Epoch 82/300
# 665/665 - 39s - 59ms/step - accuracy: 0.8745 - loss: 0.5309 - val_accuracy: 0.8793 - val_loss: 0.5394 - learning_rate: 1.2500e-04
# Epoch 83/300
# 665/665 - 39s - 58ms/step - accuracy: 0.8734 - loss: 0.5310 - val_accuracy: 0.8773 - val_loss: 0.5438 - learning_rate: 1.2500e-04
# Epoch 84/300
# 665/665 - 38s - 58ms/step - accuracy: 0.8746 - loss: 0.5285 - val_accuracy: 0.8747 - val_loss: 0.5430 - learning_rate: 1.2500e-04
# Epoch 85/300
# 665/665 - 39s - 59ms/step - accuracy: 0.8753 - loss: 0.5263 - val_accuracy: 0.8756 - val_loss: 0.5379 - learning_rate: 1.2500e-04
# Epoch 86/300
# 665/665 - 39s - 58ms/step - accuracy: 0.8763 - loss: 0.5219 - val_accuracy: 0.8809 - val_loss: 0.5221 - learning_rate: 1.2500e-04
# Epoch 87/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8779 - loss: 0.5179 - val_accuracy: 0.8691 - val_loss: 0.5576 - learning_rate: 1.2500e-04
# Epoch 88/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8767 - loss: 0.5123 - val_accuracy: 0.8816 - val_loss: 0.5236 - learning_rate: 1.2500e-04
# Epoch 89/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8793 - loss: 0.5114 - val_accuracy: 0.8759 - val_loss: 0.5356 - learning_rate: 1.2500e-04
# Epoch 90/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8771 - loss: 0.5184 - val_accuracy: 0.8796 - val_loss: 0.5238 - learning_rate: 1.2500e-04
# Epoch 91/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8800 - loss: 0.5056 - val_accuracy: 0.8797 - val_loss: 0.5215 - learning_rate: 1.2500e-04
# Epoch 92/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8811 - loss: 0.5039 - val_accuracy: 0.8841 - val_loss: 0.5090 - learning_rate: 1.2500e-04
# Epoch 93/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8803 - loss: 0.5061 - val_accuracy: 0.8812 - val_loss: 0.5253 - learning_rate: 1.2500e-04
# Epoch 94/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8783 - loss: 0.5046 - val_accuracy: 0.8832 - val_loss: 0.5100 - learning_rate: 1.2500e-04
# Epoch 95/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8817 - loss: 0.4933 - val_accuracy: 0.8721 - val_loss: 0.5378 - learning_rate: 1.2500e-04
# Epoch 96/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8831 - loss: 0.4949 - val_accuracy: 0.8817 - val_loss: 0.5156 - learning_rate: 1.2500e-04
# Epoch 97/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8847 - loss: 0.4879 - val_accuracy: 0.8780 - val_loss: 0.5199 - learning_rate: 1.2500e-04
# Epoch 98/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8820 - loss: 0.4951 - val_accuracy: 0.8837 - val_loss: 0.5019 - learning_rate: 1.2500e-04
# Epoch 99/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8827 - loss: 0.4877 - val_accuracy: 0.8803 - val_loss: 0.5098 - learning_rate: 1.2500e-04
# Epoch 100/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8830 - loss: 0.4885 - val_accuracy: 0.8835 - val_loss: 0.5018 - learning_rate: 1.2500e-04
# Epoch 101/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8815 - loss: 0.4880 - val_accuracy: 0.8740 - val_loss: 0.5275 - learning_rate: 1.2500e-04
# Epoch 102/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8824 - loss: 0.4921 - val_accuracy: 0.8820 - val_loss: 0.4991 - learning_rate: 1.2500e-04
# Epoch 103/300
# 665/665 - 38s - 56ms/step - accuracy: 0.8845 - loss: 0.4845 - val_accuracy: 0.8772 - val_loss: 0.5277 - learning_rate: 1.2500e-04
# Epoch 104/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8848 - loss: 0.4809 - val_accuracy: 0.8841 - val_loss: 0.5008 - learning_rate: 1.2500e-04
# Epoch 105/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8869 - loss: 0.4803 - val_accuracy: 0.8841 - val_loss: 0.4974 - learning_rate: 1.2500e-04
# Epoch 106/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8840 - loss: 0.4818 - val_accuracy: 0.8852 - val_loss: 0.4917 - learning_rate: 1.2500e-04
# Epoch 107/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8868 - loss: 0.4747 - val_accuracy: 0.8833 - val_loss: 0.5037 - learning_rate: 1.2500e-04
# Epoch 108/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8858 - loss: 0.4753 - val_accuracy: 0.8799 - val_loss: 0.5085 - learning_rate: 1.2500e-04
# Epoch 109/300
# 665/665 - 37s - 56ms/step - accuracy: 0.8857 - loss: 0.4736 - val_accuracy: 0.8812 - val_loss: 0.5112 - learning_rate: 1.2500e-04
# Epoch 110/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8869 - loss: 0.4736 - val_accuracy: 0.8771 - val_loss: 0.5091 - learning_rate: 1.2500e-04
# Epoch 111/300
# 665/665 - 39s - 58ms/step - accuracy: 0.8871 - loss: 0.4689 - val_accuracy: 0.8805 - val_loss: 0.5095 - learning_rate: 1.2500e-04
# Epoch 112/300
# 665/665 - 39s - 59ms/step - accuracy: 0.8875 - loss: 0.4687 - val_accuracy: 0.8803 - val_loss: 0.5067 - learning_rate: 1.2500e-04
# Epoch 113/300
# 665/665 - 38s - 58ms/step - accuracy: 0.8850 - loss: 0.4702 - val_accuracy: 0.8824 - val_loss: 0.5049 - learning_rate: 1.2500e-04
# Epoch 114/300
# 665/665 - 38s - 58ms/step - accuracy: 0.8895 - loss: 0.4637 - val_accuracy: 0.8811 - val_loss: 0.5016 - learning_rate: 1.2500e-04
# Epoch 115/300
# 665/665 - 39s - 59ms/step - accuracy: 0.8871 - loss: 0.4661 - val_accuracy: 0.8827 - val_loss: 0.4968 - learning_rate: 1.2500e-04
# Epoch 116/300
# 665/665 - 39s - 59ms/step - accuracy: 0.8884 - loss: 0.4636 - val_accuracy: 0.8915 - val_loss: 0.4742 - learning_rate: 1.2500e-04
# Epoch 117/300
# 665/665 - 40s - 60ms/step - accuracy: 0.8878 - loss: 0.4655 - val_accuracy: 0.8833 - val_loss: 0.5017 - learning_rate: 1.2500e-04
# Epoch 118/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8906 - loss: 0.4601 - val_accuracy: 0.8883 - val_loss: 0.4835 - learning_rate: 1.2500e-04
# Epoch 119/300
# 665/665 - 43s - 65ms/step - accuracy: 0.8890 - loss: 0.4634 - val_accuracy: 0.8823 - val_loss: 0.5025 - learning_rate: 1.2500e-04
# Epoch 120/300
# 665/665 - 42s - 64ms/step - accuracy: 0.8875 - loss: 0.4625 - val_accuracy: 0.8904 - val_loss: 0.4766 - learning_rate: 1.2500e-04
# Epoch 121/300
# 665/665 - 43s - 65ms/step - accuracy: 0.8895 - loss: 0.4584 - val_accuracy: 0.8856 - val_loss: 0.4847 - learning_rate: 1.2500e-04
# Epoch 122/300
# 665/665 - 46s - 69ms/step - accuracy: 0.8887 - loss: 0.4562 - val_accuracy: 0.8863 - val_loss: 0.4854 - learning_rate: 1.2500e-04
# Epoch 123/300
# 665/665 - 46s - 69ms/step - accuracy: 0.8925 - loss: 0.4517 - val_accuracy: 0.8793 - val_loss: 0.5098 - learning_rate: 1.2500e-04
# Epoch 124/300
# 665/665 - 46s - 69ms/step - accuracy: 0.8894 - loss: 0.4587 - val_accuracy: 0.8848 - val_loss: 0.4878 - learning_rate: 1.2500e-04
# Epoch 125/300
# 665/665 - 46s - 69ms/step - accuracy: 0.8891 - loss: 0.4555 - val_accuracy: 0.8819 - val_loss: 0.4984 - learning_rate: 1.2500e-04
# Epoch 126/300
# 665/665 - 43s - 65ms/step - accuracy: 0.8886 - loss: 0.4578 - val_accuracy: 0.8745 - val_loss: 0.5140 - learning_rate: 1.2500e-04
# Epoch 127/300
# 665/665 - 45s - 67ms/step - accuracy: 0.8951 - loss: 0.4414 - val_accuracy: 0.8832 - val_loss: 0.4916 - learning_rate: 6.2500e-05
# Epoch 128/300
# 665/665 - 40s - 60ms/step - accuracy: 0.8967 - loss: 0.4386 - val_accuracy: 0.8897 - val_loss: 0.4746 - learning_rate: 6.2500e-05
# Epoch 129/300
# 665/665 - 39s - 59ms/step - accuracy: 0.8984 - loss: 0.4314 - val_accuracy: 0.8813 - val_loss: 0.4992 - learning_rate: 6.2500e-05
# Epoch 130/300
# 665/665 - 40s - 60ms/step - accuracy: 0.8980 - loss: 0.4296 - val_accuracy: 0.8848 - val_loss: 0.4881 - learning_rate: 6.2500e-05
# Epoch 131/300
# 665/665 - 39s - 58ms/step - accuracy: 0.8963 - loss: 0.4308 - val_accuracy: 0.8828 - val_loss: 0.4982 - learning_rate: 6.2500e-05
# Epoch 132/300
# 665/665 - 39s - 59ms/step - accuracy: 0.8994 - loss: 0.4232 - val_accuracy: 0.8875 - val_loss: 0.4813 - learning_rate: 6.2500e-05
# Epoch 133/300
# 665/665 - 40s - 59ms/step - accuracy: 0.9000 - loss: 0.4251 - val_accuracy: 0.8893 - val_loss: 0.4796 - learning_rate: 6.2500e-05
# Epoch 134/300
# 665/665 - 40s - 60ms/step - accuracy: 0.8989 - loss: 0.4231 - val_accuracy: 0.8883 - val_loss: 0.4792 - learning_rate: 6.2500e-05
# Epoch 135/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8986 - loss: 0.4211 - val_accuracy: 0.8865 - val_loss: 0.4840 - learning_rate: 6.2500e-05
# Epoch 136/300
# 665/665 - 38s - 58ms/step - accuracy: 0.8993 - loss: 0.4228 - val_accuracy: 0.8888 - val_loss: 0.4743 - learning_rate: 6.2500e-05
# Epoch 137/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9030 - loss: 0.4139 - val_accuracy: 0.8901 - val_loss: 0.4722 - learning_rate: 3.1250e-05
# Epoch 138/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9038 - loss: 0.4092 - val_accuracy: 0.8892 - val_loss: 0.4704 - learning_rate: 3.1250e-05
# Epoch 139/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9060 - loss: 0.4079 - val_accuracy: 0.8891 - val_loss: 0.4716 - learning_rate: 3.1250e-05
# Epoch 140/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9038 - loss: 0.4062 - val_accuracy: 0.8889 - val_loss: 0.4746 - learning_rate: 3.1250e-05
# Epoch 141/300
# 665/665 - 39s - 58ms/step - accuracy: 0.9023 - loss: 0.4107 - val_accuracy: 0.8869 - val_loss: 0.4792 - learning_rate: 3.1250e-05
# Epoch 142/300
# 665/665 - 38s - 58ms/step - accuracy: 0.9055 - loss: 0.4053 - val_accuracy: 0.8884 - val_loss: 0.4760 - learning_rate: 3.1250e-05
# Epoch 143/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9072 - loss: 0.4000 - val_accuracy: 0.8911 - val_loss: 0.4700 - learning_rate: 3.1250e-05
# Epoch 144/300
# 665/665 - 39s - 58ms/step - accuracy: 0.9056 - loss: 0.4030 - val_accuracy: 0.8911 - val_loss: 0.4708 - learning_rate: 3.1250e-05
# Epoch 145/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9065 - loss: 0.4002 - val_accuracy: 0.8904 - val_loss: 0.4742 - learning_rate: 3.1250e-05
# Epoch 146/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9044 - loss: 0.4024 - val_accuracy: 0.8885 - val_loss: 0.4762 - learning_rate: 3.1250e-05
# Epoch 147/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9052 - loss: 0.4027 - val_accuracy: 0.8891 - val_loss: 0.4754 - learning_rate: 3.1250e-05
# Epoch 148/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9060 - loss: 0.3991 - val_accuracy: 0.8877 - val_loss: 0.4756 - learning_rate: 3.1250e-05
# Epoch 149/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9055 - loss: 0.4004 - val_accuracy: 0.8923 - val_loss: 0.4661 - learning_rate: 3.1250e-05
# Epoch 150/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9060 - loss: 0.4025 - val_accuracy: 0.8889 - val_loss: 0.4715 - learning_rate: 3.1250e-05
# Epoch 151/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9063 - loss: 0.3971 - val_accuracy: 0.8907 - val_loss: 0.4652 - learning_rate: 3.1250e-05
# Epoch 152/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9069 - loss: 0.3993 - val_accuracy: 0.8925 - val_loss: 0.4657 - learning_rate: 3.1250e-05
# Epoch 153/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9070 - loss: 0.3944 - val_accuracy: 0.8897 - val_loss: 0.4699 - learning_rate: 3.1250e-05
# Epoch 154/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9072 - loss: 0.3936 - val_accuracy: 0.8908 - val_loss: 0.4693 - learning_rate: 3.1250e-05
# Epoch 155/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9080 - loss: 0.3921 - val_accuracy: 0.8892 - val_loss: 0.4678 - learning_rate: 3.1250e-05
# Epoch 156/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9070 - loss: 0.3944 - val_accuracy: 0.8893 - val_loss: 0.4671 - learning_rate: 3.1250e-05
# Epoch 157/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9091 - loss: 0.3919 - val_accuracy: 0.8925 - val_loss: 0.4667 - learning_rate: 3.1250e-05
# Epoch 158/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9073 - loss: 0.3930 - val_accuracy: 0.8920 - val_loss: 0.4611 - learning_rate: 3.1250e-05
# Epoch 159/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9086 - loss: 0.3907 - val_accuracy: 0.8937 - val_loss: 0.4595 - learning_rate: 3.1250e-05
# Epoch 160/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9101 - loss: 0.3860 - val_accuracy: 0.8929 - val_loss: 0.4635 - learning_rate: 3.1250e-05
# Epoch 161/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9073 - loss: 0.3918 - val_accuracy: 0.8944 - val_loss: 0.4615 - learning_rate: 3.1250e-05
# Epoch 162/300
# 665/665 - 36s - 55ms/step - accuracy: 0.9083 - loss: 0.3881 - val_accuracy: 0.8919 - val_loss: 0.4642 - learning_rate: 3.1250e-05
# Epoch 163/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9075 - loss: 0.3887 - val_accuracy: 0.8916 - val_loss: 0.4654 - learning_rate: 3.1250e-05
# Epoch 164/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9087 - loss: 0.3868 - val_accuracy: 0.8939 - val_loss: 0.4566 - learning_rate: 3.1250e-05
# Epoch 165/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9095 - loss: 0.3855 - val_accuracy: 0.8896 - val_loss: 0.4699 - learning_rate: 3.1250e-05
# Epoch 166/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9073 - loss: 0.3925 - val_accuracy: 0.8909 - val_loss: 0.4618 - learning_rate: 3.1250e-05
# Epoch 167/300
# 665/665 - 38s - 58ms/step - accuracy: 0.9085 - loss: 0.3860 - val_accuracy: 0.8964 - val_loss: 0.4467 - learning_rate: 3.1250e-05
# Epoch 168/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9116 - loss: 0.3787 - val_accuracy: 0.8927 - val_loss: 0.4565 - learning_rate: 3.1250e-05
# Epoch 169/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9093 - loss: 0.3832 - val_accuracy: 0.8917 - val_loss: 0.4648 - learning_rate: 3.1250e-05
# Epoch 170/300
# 665/665 - 38s - 56ms/step - accuracy: 0.9127 - loss: 0.3775 - val_accuracy: 0.8912 - val_loss: 0.4675 - learning_rate: 3.1250e-05
# Epoch 171/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9119 - loss: 0.3803 - val_accuracy: 0.8929 - val_loss: 0.4643 - learning_rate: 3.1250e-05
# Epoch 172/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9109 - loss: 0.3825 - val_accuracy: 0.8909 - val_loss: 0.4608 - learning_rate: 3.1250e-05
# Epoch 173/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9119 - loss: 0.3799 - val_accuracy: 0.8925 - val_loss: 0.4610 - learning_rate: 3.1250e-05
# Epoch 174/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9130 - loss: 0.3766 - val_accuracy: 0.8935 - val_loss: 0.4611 - learning_rate: 3.1250e-05
# Epoch 175/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9088 - loss: 0.3853 - val_accuracy: 0.8940 - val_loss: 0.4558 - learning_rate: 3.1250e-05
# Epoch 176/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9111 - loss: 0.3769 - val_accuracy: 0.8936 - val_loss: 0.4566 - learning_rate: 3.1250e-05
# Epoch 177/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9115 - loss: 0.3789 - val_accuracy: 0.8920 - val_loss: 0.4636 - learning_rate: 3.1250e-05
# Epoch 178/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9131 - loss: 0.3725 - val_accuracy: 0.8940 - val_loss: 0.4569 - learning_rate: 1.5625e-05
# Epoch 179/300
# 665/665 - 38s - 56ms/step - accuracy: 0.9123 - loss: 0.3721 - val_accuracy: 0.8929 - val_loss: 0.4598 - learning_rate: 1.5625e-05
# Epoch 180/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9123 - loss: 0.3760 - val_accuracy: 0.8935 - val_loss: 0.4591 - learning_rate: 1.5625e-05
# Epoch 181/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9125 - loss: 0.3744 - val_accuracy: 0.8949 - val_loss: 0.4540 - learning_rate: 1.5625e-05
# Epoch 182/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9141 - loss: 0.3684 - val_accuracy: 0.8904 - val_loss: 0.4634 - learning_rate: 1.5625e-05
# Epoch 183/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9127 - loss: 0.3744 - val_accuracy: 0.8940 - val_loss: 0.4523 - learning_rate: 1.5625e-05
# Epoch 184/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9132 - loss: 0.3722 - val_accuracy: 0.8937 - val_loss: 0.4618 - learning_rate: 1.5625e-05
# Epoch 185/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9132 - loss: 0.3723 - val_accuracy: 0.8929 - val_loss: 0.4558 - learning_rate: 1.5625e-05
# Epoch 186/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9149 - loss: 0.3637 - val_accuracy: 0.8935 - val_loss: 0.4563 - learning_rate: 1.5625e-05
# Epoch 187/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9139 - loss: 0.3701 - val_accuracy: 0.8928 - val_loss: 0.4611 - learning_rate: 1.5625e-05
# Epoch 188/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9142 - loss: 0.3667 - val_accuracy: 0.8939 - val_loss: 0.4571 - learning_rate: 1.0000e-05
# Epoch 189/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9146 - loss: 0.3645 - val_accuracy: 0.8936 - val_loss: 0.4538 - learning_rate: 1.0000e-05
# Epoch 190/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9141 - loss: 0.3706 - val_accuracy: 0.8943 - val_loss: 0.4570 - learning_rate: 1.0000e-05
# Epoch 191/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9140 - loss: 0.3684 - val_accuracy: 0.8953 - val_loss: 0.4507 - learning_rate: 1.0000e-05
# Epoch 192/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9165 - loss: 0.3664 - val_accuracy: 0.8943 - val_loss: 0.4543 - learning_rate: 1.0000e-05
# Epoch 193/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9136 - loss: 0.3691 - val_accuracy: 0.8928 - val_loss: 0.4571 - learning_rate: 1.0000e-05
# Epoch 194/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9138 - loss: 0.3666 - val_accuracy: 0.8945 - val_loss: 0.4525 - learning_rate: 1.0000e-05
# Epoch 195/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9150 - loss: 0.3651 - val_accuracy: 0.8945 - val_loss: 0.4521 - learning_rate: 1.0000e-05
# Epoch 196/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9166 - loss: 0.3604 - val_accuracy: 0.8936 - val_loss: 0.4548 - learning_rate: 1.0000e-05
# Epoch 197/300
# 665/665 - 38s - 58ms/step - accuracy: 0.9130 - loss: 0.3666 - val_accuracy: 0.8935 - val_loss: 0.4600 - learning_rate: 1.0000e-05
# Epoch 198/300
# 665/665 - 40s - 61ms/step - accuracy: 0.9161 - loss: 0.3628 - val_accuracy: 0.8949 - val_loss: 0.4542 - learning_rate: 1.0000e-05
# Epoch 199/300
# 665/665 - 38s - 58ms/step - accuracy: 0.9149 - loss: 0.3646 - val_accuracy: 0.8937 - val_loss: 0.4565 - learning_rate: 1.0000e-05
# Epoch 200/300
# 665/665 - 38s - 58ms/step - accuracy: 0.9132 - loss: 0.3688 - val_accuracy: 0.8945 - val_loss: 0.4556 - learning_rate: 1.0000e-05
# Epoch 201/300
# 665/665 - 38s - 58ms/step - accuracy: 0.9156 - loss: 0.3628 - val_accuracy: 0.8960 - val_loss: 0.4516 - learning_rate: 1.0000e-05
# Epoch 202/300
# 665/665 - 39s - 58ms/step - accuracy: 0.9156 - loss: 0.3656 - val_accuracy: 0.8955 - val_loss: 0.4518 - learning_rate: 1.0000e-05
# Epoch 203/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9177 - loss: 0.3578 - val_accuracy: 0.8931 - val_loss: 0.4562 - learning_rate: 1.0000e-05
# Epoch 204/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9160 - loss: 0.3639 - val_accuracy: 0.8931 - val_loss: 0.4544 - learning_rate: 1.0000e-05
# Epoch 205/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9153 - loss: 0.3635 - val_accuracy: 0.8916 - val_loss: 0.4577 - learning_rate: 1.0000e-05
# Epoch 206/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9142 - loss: 0.3651 - val_accuracy: 0.8945 - val_loss: 0.4512 - learning_rate: 1.0000e-05
# Epoch 207/300
# 665/665 - 38s - 58ms/step - accuracy: 0.9157 - loss: 0.3617 - val_accuracy: 0.8927 - val_loss: 0.4559 - learning_rate: 1.0000e-05
# Epoch 207: early stopping
# Restoring model weights from the end of the best epoch: 167.

# %%
plt.figure(figsize=(15,6))

# Plotting the training and validation loss
plt.subplot(1, 2, 1)
plt.plot(model.history.history['loss'], label='Train Loss', color='#8502d1')
plt.plot(model.history.history['val_loss'], label='Validation Loss', color='darkorange')
plt.legend()
plt.title('Loss Evolution')

# Plotting the training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(model.history.history['accuracy'], label='Train Accuracy', color='#8502d1')
plt.plot(model.history.history['val_accuracy'], label='Validation Accuracy', color='darkorange')
plt.legend()
plt.title('Accuracy Evolution')

plt.show()

# %%
# Use the model to make predictions, evaluate on test data
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=1)

print('\nTest Accuracy:', test_acc)
print('Test Loss:    ', test_loss)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8924 - loss: 0.4721
#
# Test Accuracy: 0.8937000036239624
# Test Loss:     0.4671419858932495
