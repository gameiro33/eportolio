# %% [markdown]
# # Import Libraries

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dropout, Flatten, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.models import load_model
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
   # Configure TensorFlow to grow GPU memory allocation as needed
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# %% [markdown]
# Downloading CIFAR 10:

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %% [markdown]
# The standard practice for splitting data into training, validation, and test sets typically follows these guidelines:
# Training Set (60-80%): Used to train the model
# Validation Set (10-20%): Used for hyperparameter tuning and model selection
# Test Set (10-20%): Used for final model evaluation
#
# Since the training and test set are already split in this data set in a 1/6 proportion, we will further carve 10% out of the training set to be used for validation.
#
# Source: https://www.v7labs.com/blog/train-validation-test-set

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.15, random_state=0)

# %%
print('Train Images Shape:      ', X_train.shape)
print('Train Labels Shape:      ', y_train.shape)

print('\nValidation Images Shape: ', X_valid.shape)
print('Validation Labels Shape: ', y_valid.shape)

print('\nTest Images Shape:       ', X_test.shape)
print('Test Labels Shape:       ', y_test.shape)
# Out:
# Train Images Shape:       (42500, 32, 32, 3)
# Train Labels Shape:       (42500, 1)
#
# Validation Images Shape:  (7500, 32, 32, 3)
# Validation Labels Shape:  (7500, 1)
#
# Test Images Shape:        (10000, 32, 32, 3)
# Test Labels Shape:        (10000, 1)

# %%
# Display a 3x3 grid of random images
plt.figure(figsize=(8, 8))

# Define the class names, so that they can be shown in the plot
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# Plot 9 random images from the training set
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.imshow(X_train[i])
    plt.title(f'Class: {class_names[y_train[i][0]]}')
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
# Convert pixel values data type to float32
X_train = X_train.astype('float32')
X_test  = X_test.astype('float32')
X_valid = X_valid.astype('float32')

# Normalize pixel values to be between 0 and 1
X_train = X_train / 255.0
X_test = X_test / 255.0
X_valid = X_valid / 255.0

# Transform target variable into one-hotencoding
y_train = to_categorical(y_train, 10)
y_valid = to_categorical(y_valid, 10)
y_test  = to_categorical(y_test, 10)

# %% [markdown]
# # Data Augmentation
#
# Rotation:
#
# Source: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0
#
# Horizontal Flip:
#
# Source: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0
#
# Future work. Try:
# * Patch Suffle Regularization
# * Sample Pairing
# * Random Erasing

# %%
# Data augmentation
data_generator = ImageDataGenerator(
    # Rotate images randomly by up to 15 degrees
    rotation_range=15,
    # Shift images horizontally by up to 12% of their width
    width_shift_range=0.12,
    # Shift images vertically by up to 12% of their height
    height_shift_range=0.12,
    # Randomly flip images horizontally
    horizontal_flip=True,
    # Randomly flip images vertically
    vertical_flip= True,
    # Adapt image brightness
    brightness_range=[0.8, 1.2],
    # Shear by up to 10%
    shear_range=10,
    # Channel shift intensity
    channel_shift_range=0.1,
)

# %% [markdown]
# Using mixed precision training (FP16) which can significantly speed up training on modern GPUs

# %%
# Enable mixed precision training
tf.keras.mixed_precision.set_global_policy('mixed_float16')

# %% [markdown]
# Building the VGG16 inspired model
#
# Source: https://www.kaggle.com/code/farzadnekouei/cifar-10-image-classification-with-cnn

# %%
# Initialize a sequential model
model = Sequential()

# Set the weight decay value for L2 regularization
weight_decay = 0.0001

# Add the first convolutional layer with 32 filters of size 3x3
model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay), 
                 input_shape=X_train.shape[1:]))
# Add batch normalization layer
model.add(BatchNormalization())

# Add the second convolutional layer similar to the first
model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the first max pooling layer with pool size of 2x2
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add dropout layer with 0.2 dropout rate
model.add(Dropout(rate=0.2))

# Add the third and fourth convolutional layers with 64 filters
model.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))   
model.add(BatchNormalization())
model.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the second max pooling layer and increase dropout rate to 0.3
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.3))

# Add the fifth and sixth convolutional layers with 128 filters
model.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay))) 
model.add(BatchNormalization())
model.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the third max pooling layer and increase dropout rate to 0.4
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.4))

# Add the seventh and eighth convolutional layers with 256 filters
model.add(Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay))) 
model.add(BatchNormalization())
model.add(Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the fourth max pooling layer and increase dropout rate to 0.5
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.5))

# Flatten the tensor output from the previous layer
model.add(Flatten())

# Add a fully connected layer with softmax activation function for outputting class probabilities
model.add(Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_16 (Conv2D)              │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_18 (Conv2D)              │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_20          │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_21 (Conv2D)              │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_21          │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_22 (Conv2D)              │ (None, 4, 4, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_22          │ (None, 4, 4, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_23 (Conv2D)              │ (None, 4, 4, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_23          │ (None, 4, 4, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 2, 2, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 2, 2, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │        10,250 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,186,346 (4.53 MB)
#  Trainable params: 1,184,426 (4.52 MB)
#  Non-trainable params: 1,920 (7.50 KB)

# %%
# Set the batch size for the training
batch_size = 64


# Set the maximum number of epochs for the training
epochs = 300

# Define the optimizer (Adam)
optimizer = Adam(learning_rate=0.001)

# Compile the model with the defined optimizer, loss function, and metrics
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Add ReduceLROnPlateau callback
# Here, the learning rate will be reduced by half (factor=0.5) if no improvement in validation loss is observed for 10 epochs
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=0.00001)

# Add EarlyStopping callback
# Here, training will be stopped if no improvement in validation loss is observed for 40 epochs.
# The `restore_best_weights` parameter ensures that the model weights are reset to the values from the epoch
# with the best value of the monitored quantity (in this case, 'val_loss').
early_stopping = EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True, verbose=1)

train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))\
    .shuffle(1000)\
    .batch(batch_size)\
    .prefetch(tf.data.AUTOTUNE)

valid_ds = tf.data.Dataset.from_tensor_slices((X_valid, y_valid))\
    .batch(batch_size)\
    .prefetch(tf.data.AUTOTUNE)

# Then in model.fit:
model.fit(train_ds,
            epochs=epochs,
            validation_data=valid_ds,
            callbacks=[reduce_lr, early_stopping],
            verbose=2)
# Out:
# Epoch 1/300
# 665/665 - 44s - 66ms/step - accuracy: 0.3868 - loss: 2.1655 - val_accuracy: 0.4768 - val_loss: 1.5536 - learning_rate: 0.0010
# Epoch 2/300
# 665/665 - 37s - 55ms/step - accuracy: 0.5168 - loss: 1.6340 - val_accuracy: 0.5501 - val_loss: 1.4315 - learning_rate: 0.0010
# Epoch 3/300
# 665/665 - 37s - 55ms/step - accuracy: 0.5679 - loss: 1.5601 - val_accuracy: 0.4497 - val_loss: 2.2855 - learning_rate: 0.0010
# Epoch 4/300
# 665/665 - 37s - 56ms/step - accuracy: 0.5773 - loss: 1.5276 - val_accuracy: 0.5588 - val_loss: 1.4625 - learning_rate: 0.0010
# Epoch 5/300
# 665/665 - 37s - 56ms/step - accuracy: 0.5433 - loss: 1.7164 - val_accuracy: 0.4340 - val_loss: 1.9859 - learning_rate: 0.0010
# Epoch 6/300
# 665/665 - 37s - 56ms/step - accuracy: 0.5576 - loss: 1.6686 - val_accuracy: 0.6221 - val_loss: 1.3098 - learning_rate: 0.0010
# Epoch 7/300
# 665/665 - 38s - 57ms/step - accuracy: 0.6013 - loss: 1.5685 - val_accuracy: 0.6612 - val_loss: 1.2703 - learning_rate: 0.0010
# Epoch 8/300
# 665/665 - 37s - 56ms/step - accuracy: 0.6055 - loss: 1.5825 - val_accuracy: 0.6275 - val_loss: 1.4079 - learning_rate: 0.0010
# Epoch 9/300
# 665/665 - 37s - 56ms/step - accuracy: 0.6513 - loss: 1.4412 - val_accuracy: 0.6743 - val_loss: 1.2353 - learning_rate: 0.0010
# Epoch 10/300
# 665/665 - 38s - 58ms/step - accuracy: 0.6399 - loss: 1.4998 - val_accuracy: 0.6916 - val_loss: 1.2313 - learning_rate: 0.0010
# Epoch 11/300
# 665/665 - 37s - 56ms/step - accuracy: 0.6767 - loss: 1.3571 - val_accuracy: 0.6539 - val_loss: 1.3445 - learning_rate: 0.0010
# Epoch 12/300
# 665/665 - 39s - 59ms/step - accuracy: 0.7023 - loss: 1.2770 - val_accuracy: 0.7012 - val_loss: 1.2070 - learning_rate: 0.0010
# Epoch 13/300
# 665/665 - 40s - 60ms/step - accuracy: 0.6769 - loss: 1.4073 - val_accuracy: 0.6703 - val_loss: 1.6524 - learning_rate: 0.0010
# Epoch 14/300
# 665/665 - 38s - 57ms/step - accuracy: 0.7096 - loss: 1.2934 - val_accuracy: 0.6960 - val_loss: 1.2487 - learning_rate: 0.0010
# Epoch 15/300
# 665/665 - 37s - 56ms/step - accuracy: 0.7341 - loss: 1.1923 - val_accuracy: 0.7612 - val_loss: 1.0654 - learning_rate: 0.0010
# Epoch 16/300
# 665/665 - 38s - 57ms/step - accuracy: 0.7442 - loss: 1.1623 - val_accuracy: 0.7295 - val_loss: 1.4640 - learning_rate: 0.0010
# Epoch 17/300
# 665/665 - 42s - 64ms/step - accuracy: 0.7508 - loss: 1.1407 - val_accuracy: 0.6480 - val_loss: 1.5388 - learning_rate: 0.0010
# Epoch 18/300
# 665/665 - 41s - 62ms/step - accuracy: 0.7624 - loss: 1.1093 - val_accuracy: 0.7615 - val_loss: 1.0849 - learning_rate: 0.0010
# Epoch 19/300
# 665/665 - 41s - 62ms/step - accuracy: 0.7737 - loss: 1.0597 - val_accuracy: 0.7912 - val_loss: 0.9968 - learning_rate: 0.0010
# Epoch 20/300
# 665/665 - 44s - 67ms/step - accuracy: 0.7864 - loss: 1.0011 - val_accuracy: 0.7952 - val_loss: 0.9829 - learning_rate: 0.0010
# Epoch 21/300
# 665/665 - 42s - 62ms/step - accuracy: 0.7883 - loss: 1.0170 - val_accuracy: 0.7913 - val_loss: 1.0194 - learning_rate: 0.0010
# Epoch 22/300
# 665/665 - 45s - 68ms/step - accuracy: 0.8004 - loss: 0.9717 - val_accuracy: 0.7935 - val_loss: 0.9800 - learning_rate: 0.0010
# Epoch 23/300
# 665/665 - 43s - 65ms/step - accuracy: 0.8010 - loss: 0.9780 - val_accuracy: 0.8072 - val_loss: 0.9571 - learning_rate: 0.0010
# Epoch 24/300
# 665/665 - 43s - 65ms/step - accuracy: 0.8137 - loss: 0.9371 - val_accuracy: 0.8032 - val_loss: 0.9759 - learning_rate: 0.0010
# Epoch 25/300
# 665/665 - 45s - 67ms/step - accuracy: 0.8181 - loss: 0.9249 - val_accuracy: 0.8049 - val_loss: 0.9775 - learning_rate: 0.0010
# Epoch 26/300
# 665/665 - 43s - 64ms/step - accuracy: 0.8100 - loss: 0.9469 - val_accuracy: 0.7996 - val_loss: 0.9931 - learning_rate: 0.0010
# Epoch 27/300
# 665/665 - 42s - 63ms/step - accuracy: 0.8217 - loss: 0.9249 - val_accuracy: 0.7813 - val_loss: 1.0589 - learning_rate: 0.0010
# Epoch 28/300
# 665/665 - 42s - 63ms/step - accuracy: 0.8314 - loss: 0.8915 - val_accuracy: 0.8159 - val_loss: 0.9405 - learning_rate: 0.0010
# Epoch 29/300
# 665/665 - 42s - 63ms/step - accuracy: 0.8366 - loss: 0.8727 - val_accuracy: 0.8113 - val_loss: 0.9533 - learning_rate: 0.0010
# Epoch 30/300
# 665/665 - 43s - 64ms/step - accuracy: 0.8437 - loss: 0.8515 - val_accuracy: 0.8116 - val_loss: 0.9614 - learning_rate: 0.0010
# Epoch 31/300
# 665/665 - 42s - 63ms/step - accuracy: 0.8521 - loss: 0.8203 - val_accuracy: 0.8136 - val_loss: 0.9399 - learning_rate: 0.0010
# Epoch 32/300
# 665/665 - 42s - 64ms/step - accuracy: 0.8516 - loss: 0.8149 - val_accuracy: 0.8120 - val_loss: 0.9681 - learning_rate: 0.0010
# Epoch 33/300
# 665/665 - 42s - 63ms/step - accuracy: 0.8554 - loss: 0.8081 - val_accuracy: 0.8129 - val_loss: 0.9655 - learning_rate: 0.0010
# Epoch 34/300
# 665/665 - 43s - 64ms/step - accuracy: 0.8542 - loss: 0.8124 - val_accuracy: 0.8175 - val_loss: 0.9553 - learning_rate: 0.0010
# Epoch 35/300
# 665/665 - 41s - 61ms/step - accuracy: 0.8654 - loss: 0.7815 - val_accuracy: 0.8273 - val_loss: 0.9097 - learning_rate: 0.0010
# Epoch 36/300
# 665/665 - 39s - 58ms/step - accuracy: 0.8623 - loss: 0.7901 - val_accuracy: 0.7921 - val_loss: 1.0484 - learning_rate: 0.0010
# Epoch 37/300
# 665/665 - 39s - 59ms/step - accuracy: 0.8657 - loss: 0.7722 - val_accuracy: 0.8295 - val_loss: 0.9078 - learning_rate: 0.0010
# Epoch 38/300
# 665/665 - 39s - 59ms/step - accuracy: 0.8686 - loss: 0.7696 - val_accuracy: 0.8271 - val_loss: 0.9266 - learning_rate: 0.0010
# Epoch 39/300
# 665/665 - 39s - 59ms/step - accuracy: 0.8727 - loss: 0.7620 - val_accuracy: 0.8157 - val_loss: 0.9608 - learning_rate: 0.0010
# Epoch 40/300
# 665/665 - 38s - 58ms/step - accuracy: 0.8752 - loss: 0.7507 - val_accuracy: 0.8305 - val_loss: 0.9052 - learning_rate: 0.0010
# Epoch 41/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8755 - loss: 0.7534 - val_accuracy: 0.8256 - val_loss: 0.9475 - learning_rate: 0.0010
# Epoch 42/300
# 665/665 - 38s - 58ms/step - accuracy: 0.8754 - loss: 0.7578 - val_accuracy: 0.8291 - val_loss: 0.9296 - learning_rate: 0.0010
# Epoch 43/300
# 665/665 - 39s - 58ms/step - accuracy: 0.8815 - loss: 0.7367 - val_accuracy: 0.8399 - val_loss: 0.8949 - learning_rate: 0.0010
# Epoch 44/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8844 - loss: 0.7211 - val_accuracy: 0.8339 - val_loss: 0.9151 - learning_rate: 0.0010
# Epoch 45/300
# 665/665 - 39s - 58ms/step - accuracy: 0.8824 - loss: 0.7254 - val_accuracy: 0.8388 - val_loss: 0.8863 - learning_rate: 0.0010
# Epoch 46/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8801 - loss: 0.7388 - val_accuracy: 0.8279 - val_loss: 0.9272 - learning_rate: 0.0010
# Epoch 47/300
# 665/665 - 38s - 58ms/step - accuracy: 0.8884 - loss: 0.7116 - val_accuracy: 0.8391 - val_loss: 0.9010 - learning_rate: 0.0010
# Epoch 48/300
# 665/665 - 39s - 58ms/step - accuracy: 0.8838 - loss: 0.7314 - val_accuracy: 0.8316 - val_loss: 0.9321 - learning_rate: 0.0010
# Epoch 49/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8910 - loss: 0.7068 - val_accuracy: 0.8331 - val_loss: 0.9076 - learning_rate: 0.0010
# Epoch 50/300
# 665/665 - 40s - 60ms/step - accuracy: 0.8880 - loss: 0.7172 - val_accuracy: 0.8361 - val_loss: 0.9110 - learning_rate: 0.0010
# Epoch 51/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8925 - loss: 0.7071 - val_accuracy: 0.8289 - val_loss: 0.9564 - learning_rate: 0.0010
# Epoch 52/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8944 - loss: 0.6990 - val_accuracy: 0.8455 - val_loss: 0.8812 - learning_rate: 0.0010
# Epoch 53/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8898 - loss: 0.7144 - val_accuracy: 0.8491 - val_loss: 0.8838 - learning_rate: 0.0010
# Epoch 54/300
# 665/665 - 37s - 56ms/step - accuracy: 0.8978 - loss: 0.6909 - val_accuracy: 0.8469 - val_loss: 0.8838 - learning_rate: 0.0010
# Epoch 55/300
# 665/665 - 37s - 56ms/step - accuracy: 0.8966 - loss: 0.6924 - val_accuracy: 0.8380 - val_loss: 0.9420 - learning_rate: 0.0010
# Epoch 56/300
# 665/665 - 37s - 56ms/step - accuracy: 0.8933 - loss: 0.7028 - val_accuracy: 0.8248 - val_loss: 0.9687 - learning_rate: 0.0010
# Epoch 57/300
# 665/665 - 37s - 56ms/step - accuracy: 0.8999 - loss: 0.6873 - val_accuracy: 0.8416 - val_loss: 0.9164 - learning_rate: 0.0010
# Epoch 58/300
# 665/665 - 37s - 56ms/step - accuracy: 0.8957 - loss: 0.7013 - val_accuracy: 0.8335 - val_loss: 0.9308 - learning_rate: 0.0010
# Epoch 59/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9013 - loss: 0.6834 - val_accuracy: 0.8427 - val_loss: 0.9069 - learning_rate: 0.0010
# Epoch 60/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8986 - loss: 0.6920 - val_accuracy: 0.8468 - val_loss: 0.8805 - learning_rate: 0.0010
# Epoch 61/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9005 - loss: 0.6802 - val_accuracy: 0.8433 - val_loss: 0.9054 - learning_rate: 0.0010
# Epoch 62/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9027 - loss: 0.6752 - val_accuracy: 0.8515 - val_loss: 0.8783 - learning_rate: 0.0010
# Epoch 63/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9034 - loss: 0.6724 - val_accuracy: 0.8420 - val_loss: 0.9006 - learning_rate: 0.0010
# Epoch 64/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9025 - loss: 0.6746 - val_accuracy: 0.8447 - val_loss: 0.9061 - learning_rate: 0.0010
# Epoch 65/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9003 - loss: 0.6880 - val_accuracy: 0.8447 - val_loss: 0.8869 - learning_rate: 0.0010
# Epoch 66/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9055 - loss: 0.6650 - val_accuracy: 0.8485 - val_loss: 0.8841 - learning_rate: 0.0010
# Epoch 67/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9028 - loss: 0.6790 - val_accuracy: 0.8468 - val_loss: 0.9041 - learning_rate: 0.0010
# Epoch 68/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9045 - loss: 0.6770 - val_accuracy: 0.8387 - val_loss: 0.9253 - learning_rate: 0.0010
# Epoch 69/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9071 - loss: 0.6610 - val_accuracy: 0.8516 - val_loss: 0.8858 - learning_rate: 0.0010
# Epoch 70/300
# 665/665 - 39s - 58ms/step - accuracy: 0.9064 - loss: 0.6659 - val_accuracy: 0.8556 - val_loss: 0.8636 - learning_rate: 0.0010
# Epoch 71/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9063 - loss: 0.6678 - val_accuracy: 0.8448 - val_loss: 0.8927 - learning_rate: 0.0010
# Epoch 72/300
# 665/665 - 788s - 1s/step - accuracy: 0.9076 - loss: 0.6606 - val_accuracy: 0.8520 - val_loss: 0.8767 - learning_rate: 0.0010
# Epoch 73/300
# 665/665 - 35s - 53ms/step - accuracy: 0.9085 - loss: 0.6570 - val_accuracy: 0.8507 - val_loss: 0.8762 - learning_rate: 0.0010
# Epoch 74/300
# 665/665 - 977s - 1s/step - accuracy: 0.9068 - loss: 0.6609 - val_accuracy: 0.8524 - val_loss: 0.8828 - learning_rate: 0.0010
# Epoch 75/300
# 665/665 - 718s - 1s/step - accuracy: 0.9105 - loss: 0.6552 - val_accuracy: 0.8445 - val_loss: 0.9140 - learning_rate: 0.0010
# Epoch 76/300
# 665/665 - 36s - 54ms/step - accuracy: 0.9075 - loss: 0.6650 - val_accuracy: 0.8533 - val_loss: 0.8616 - learning_rate: 0.0010
# Epoch 77/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9071 - loss: 0.6677 - val_accuracy: 0.8568 - val_loss: 0.8609 - learning_rate: 0.0010
# Epoch 78/300
# 665/665 - 38s - 56ms/step - accuracy: 0.9109 - loss: 0.6574 - val_accuracy: 0.8409 - val_loss: 0.9346 - learning_rate: 0.0010
# Epoch 79/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9078 - loss: 0.6603 - val_accuracy: 0.8607 - val_loss: 0.8533 - learning_rate: 0.0010
# Epoch 80/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9113 - loss: 0.6545 - val_accuracy: 0.8495 - val_loss: 0.8776 - learning_rate: 0.0010
# Epoch 81/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9133 - loss: 0.6462 - val_accuracy: 0.8569 - val_loss: 0.8532 - learning_rate: 0.0010
# Epoch 82/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9117 - loss: 0.6543 - val_accuracy: 0.8443 - val_loss: 0.8929 - learning_rate: 0.0010
# Epoch 83/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9086 - loss: 0.6663 - val_accuracy: 0.8564 - val_loss: 0.8627 - learning_rate: 0.0010
# Epoch 84/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9150 - loss: 0.6380 - val_accuracy: 0.8520 - val_loss: 0.8658 - learning_rate: 0.0010
# Epoch 85/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9121 - loss: 0.6459 - val_accuracy: 0.8568 - val_loss: 0.8704 - learning_rate: 0.0010
# Epoch 86/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9128 - loss: 0.6449 - val_accuracy: 0.8481 - val_loss: 0.8842 - learning_rate: 0.0010
# Epoch 87/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9123 - loss: 0.6511 - val_accuracy: 0.8565 - val_loss: 0.8662 - learning_rate: 0.0010
# Epoch 88/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9119 - loss: 0.6520 - val_accuracy: 0.8405 - val_loss: 0.9402 - learning_rate: 0.0010
# Epoch 89/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9142 - loss: 0.6404 - val_accuracy: 0.8523 - val_loss: 0.8838 - learning_rate: 0.0010
# Epoch 90/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9148 - loss: 0.6411 - val_accuracy: 0.8471 - val_loss: 0.8934 - learning_rate: 0.0010
# Epoch 91/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9169 - loss: 0.6358 - val_accuracy: 0.8531 - val_loss: 0.8837 - learning_rate: 0.0010
# Epoch 92/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9368 - loss: 0.5680 - val_accuracy: 0.8719 - val_loss: 0.8247 - learning_rate: 5.0000e-04
# Epoch 93/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9412 - loss: 0.5389 - val_accuracy: 0.8696 - val_loss: 0.8131 - learning_rate: 5.0000e-04
# Epoch 94/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9455 - loss: 0.5156 - val_accuracy: 0.8751 - val_loss: 0.8259 - learning_rate: 5.0000e-04
# Epoch 95/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9466 - loss: 0.5034 - val_accuracy: 0.8732 - val_loss: 0.8015 - learning_rate: 5.0000e-04
# Epoch 96/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9505 - loss: 0.4861 - val_accuracy: 0.8692 - val_loss: 0.8015 - learning_rate: 5.0000e-04
# Epoch 97/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9492 - loss: 0.4781 - val_accuracy: 0.8637 - val_loss: 0.8153 - learning_rate: 5.0000e-04
# Epoch 98/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9516 - loss: 0.4639 - val_accuracy: 0.8701 - val_loss: 0.7980 - learning_rate: 5.0000e-04
# Epoch 99/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9521 - loss: 0.4573 - val_accuracy: 0.8707 - val_loss: 0.7922 - learning_rate: 5.0000e-04
# Epoch 100/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9511 - loss: 0.4553 - val_accuracy: 0.8711 - val_loss: 0.8015 - learning_rate: 5.0000e-04
# Epoch 101/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9529 - loss: 0.4478 - val_accuracy: 0.8720 - val_loss: 0.7707 - learning_rate: 5.0000e-04
# Epoch 102/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9500 - loss: 0.4543 - val_accuracy: 0.8717 - val_loss: 0.7737 - learning_rate: 5.0000e-04
# Epoch 103/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9472 - loss: 0.4568 - val_accuracy: 0.8728 - val_loss: 0.7660 - learning_rate: 5.0000e-04
# Epoch 104/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9539 - loss: 0.4363 - val_accuracy: 0.8693 - val_loss: 0.7817 - learning_rate: 5.0000e-04
# Epoch 105/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9519 - loss: 0.4373 - val_accuracy: 0.8735 - val_loss: 0.7615 - learning_rate: 5.0000e-04
# Epoch 106/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9556 - loss: 0.4220 - val_accuracy: 0.8632 - val_loss: 0.8027 - learning_rate: 5.0000e-04
# Epoch 107/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9554 - loss: 0.4201 - val_accuracy: 0.8688 - val_loss: 0.7530 - learning_rate: 5.0000e-04
# Epoch 108/300
# 665/665 - 38s - 56ms/step - accuracy: 0.9552 - loss: 0.4181 - val_accuracy: 0.8721 - val_loss: 0.7674 - learning_rate: 5.0000e-04
# Epoch 109/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9554 - loss: 0.4179 - val_accuracy: 0.8683 - val_loss: 0.7561 - learning_rate: 5.0000e-04
# Epoch 110/300
# 665/665 - 38s - 58ms/step - accuracy: 0.9536 - loss: 0.4183 - val_accuracy: 0.8687 - val_loss: 0.7714 - learning_rate: 5.0000e-04
# Epoch 111/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9540 - loss: 0.4140 - val_accuracy: 0.8669 - val_loss: 0.7684 - learning_rate: 5.0000e-04
# Epoch 112/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9554 - loss: 0.4084 - val_accuracy: 0.8723 - val_loss: 0.7618 - learning_rate: 5.0000e-04
# Epoch 113/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9541 - loss: 0.4122 - val_accuracy: 0.8675 - val_loss: 0.7685 - learning_rate: 5.0000e-04
# Epoch 114/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9560 - loss: 0.4032 - val_accuracy: 0.8703 - val_loss: 0.7447 - learning_rate: 5.0000e-04
# Epoch 115/300
# 665/665 - 40s - 59ms/step - accuracy: 0.9547 - loss: 0.4066 - val_accuracy: 0.8725 - val_loss: 0.7636 - learning_rate: 5.0000e-04
# Epoch 116/300
# 665/665 - 38s - 58ms/step - accuracy: 0.9557 - loss: 0.4009 - val_accuracy: 0.8652 - val_loss: 0.7914 - learning_rate: 5.0000e-04
# Epoch 117/300
# 665/665 - 38s - 58ms/step - accuracy: 0.9544 - loss: 0.4051 - val_accuracy: 0.8596 - val_loss: 0.8163 - learning_rate: 5.0000e-04
# Epoch 118/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9543 - loss: 0.4036 - val_accuracy: 0.8727 - val_loss: 0.7553 - learning_rate: 5.0000e-04
# Epoch 119/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9525 - loss: 0.4100 - val_accuracy: 0.8692 - val_loss: 0.7552 - learning_rate: 5.0000e-04
# Epoch 120/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9542 - loss: 0.4046 - val_accuracy: 0.8749 - val_loss: 0.7428 - learning_rate: 5.0000e-04
# Epoch 121/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9562 - loss: 0.4005 - val_accuracy: 0.8768 - val_loss: 0.7360 - learning_rate: 5.0000e-04
# Epoch 122/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9565 - loss: 0.3952 - val_accuracy: 0.8716 - val_loss: 0.7512 - learning_rate: 5.0000e-04
# Epoch 123/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9525 - loss: 0.4069 - val_accuracy: 0.8673 - val_loss: 0.7605 - learning_rate: 5.0000e-04
# Epoch 124/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9560 - loss: 0.3924 - val_accuracy: 0.8701 - val_loss: 0.7602 - learning_rate: 5.0000e-04
# Epoch 125/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9547 - loss: 0.3972 - val_accuracy: 0.8721 - val_loss: 0.7542 - learning_rate: 5.0000e-04
# Epoch 126/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9543 - loss: 0.3994 - val_accuracy: 0.8732 - val_loss: 0.7516 - learning_rate: 5.0000e-04
# Epoch 127/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9567 - loss: 0.3895 - val_accuracy: 0.8729 - val_loss: 0.7665 - learning_rate: 5.0000e-04
# Epoch 128/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9540 - loss: 0.3963 - val_accuracy: 0.8663 - val_loss: 0.7701 - learning_rate: 5.0000e-04
# Epoch 129/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9558 - loss: 0.3945 - val_accuracy: 0.8689 - val_loss: 0.7461 - learning_rate: 5.0000e-04
# Epoch 130/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9579 - loss: 0.3884 - val_accuracy: 0.8671 - val_loss: 0.7595 - learning_rate: 5.0000e-04
# Epoch 131/300
# 665/665 - 40s - 61ms/step - accuracy: 0.9569 - loss: 0.3896 - val_accuracy: 0.8721 - val_loss: 0.7289 - learning_rate: 5.0000e-04
# Epoch 132/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9545 - loss: 0.3958 - val_accuracy: 0.8703 - val_loss: 0.7595 - learning_rate: 5.0000e-04
# Epoch 133/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9512 - loss: 0.4057 - val_accuracy: 0.8704 - val_loss: 0.7463 - learning_rate: 5.0000e-04
# Epoch 134/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9571 - loss: 0.3874 - val_accuracy: 0.8707 - val_loss: 0.7525 - learning_rate: 5.0000e-04
# Epoch 135/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9535 - loss: 0.3967 - val_accuracy: 0.8708 - val_loss: 0.7417 - learning_rate: 5.0000e-04
# Epoch 136/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9578 - loss: 0.3863 - val_accuracy: 0.8759 - val_loss: 0.7294 - learning_rate: 5.0000e-04
# Epoch 137/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9557 - loss: 0.3855 - val_accuracy: 0.8679 - val_loss: 0.7450 - learning_rate: 5.0000e-04
# Epoch 138/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9567 - loss: 0.3855 - val_accuracy: 0.8692 - val_loss: 0.7704 - learning_rate: 5.0000e-04
# Epoch 139/300
# 665/665 - 38s - 56ms/step - accuracy: 0.9568 - loss: 0.3873 - val_accuracy: 0.8751 - val_loss: 0.7309 - learning_rate: 5.0000e-04
# Epoch 140/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9559 - loss: 0.3914 - val_accuracy: 0.8773 - val_loss: 0.7323 - learning_rate: 5.0000e-04
# Epoch 141/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9574 - loss: 0.3844 - val_accuracy: 0.8689 - val_loss: 0.7511 - learning_rate: 5.0000e-04
# Epoch 142/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9667 - loss: 0.3566 - val_accuracy: 0.8788 - val_loss: 0.7165 - learning_rate: 2.5000e-04
# Epoch 143/300
# 665/665 - 38s - 58ms/step - accuracy: 0.9718 - loss: 0.3356 - val_accuracy: 0.8791 - val_loss: 0.7128 - learning_rate: 2.5000e-04
# Epoch 144/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9712 - loss: 0.3332 - val_accuracy: 0.8808 - val_loss: 0.7133 - learning_rate: 2.5000e-04
# Epoch 145/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9711 - loss: 0.3279 - val_accuracy: 0.8832 - val_loss: 0.7045 - learning_rate: 2.5000e-04
# Epoch 146/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9733 - loss: 0.3201 - val_accuracy: 0.8769 - val_loss: 0.7391 - learning_rate: 2.5000e-04
# Epoch 147/300
# 665/665 - 38s - 58ms/step - accuracy: 0.9742 - loss: 0.3126 - val_accuracy: 0.8820 - val_loss: 0.7284 - learning_rate: 2.5000e-04
# Epoch 148/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9761 - loss: 0.3065 - val_accuracy: 0.8845 - val_loss: 0.7213 - learning_rate: 2.5000e-04
# Epoch 149/300
# 665/665 - 38s - 56ms/step - accuracy: 0.9748 - loss: 0.3046 - val_accuracy: 0.8791 - val_loss: 0.7323 - learning_rate: 2.5000e-04
# Epoch 150/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9760 - loss: 0.2993 - val_accuracy: 0.8824 - val_loss: 0.7195 - learning_rate: 2.5000e-04
# Epoch 151/300
# 665/665 - 39s - 58ms/step - accuracy: 0.9755 - loss: 0.2973 - val_accuracy: 0.8775 - val_loss: 0.7351 - learning_rate: 2.5000e-04
# Epoch 152/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9758 - loss: 0.2941 - val_accuracy: 0.8752 - val_loss: 0.7355 - learning_rate: 2.5000e-04
# Epoch 153/300
# 665/665 - 39s - 58ms/step - accuracy: 0.9759 - loss: 0.2888 - val_accuracy: 0.8832 - val_loss: 0.7222 - learning_rate: 2.5000e-04
# Epoch 154/300
# 665/665 - 39s - 58ms/step - accuracy: 0.9781 - loss: 0.2849 - val_accuracy: 0.8795 - val_loss: 0.7325 - learning_rate: 2.5000e-04
# Epoch 155/300
# 665/665 - 40s - 60ms/step - accuracy: 0.9771 - loss: 0.2842 - val_accuracy: 0.8849 - val_loss: 0.7213 - learning_rate: 2.5000e-04
# Epoch 156/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9805 - loss: 0.2710 - val_accuracy: 0.8867 - val_loss: 0.7049 - learning_rate: 1.2500e-04
# Epoch 157/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9814 - loss: 0.2632 - val_accuracy: 0.8879 - val_loss: 0.7099 - learning_rate: 1.2500e-04
# Epoch 158/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9839 - loss: 0.2578 - val_accuracy: 0.8876 - val_loss: 0.7043 - learning_rate: 1.2500e-04
# Epoch 159/300
# 665/665 - 36s - 55ms/step - accuracy: 0.9847 - loss: 0.2537 - val_accuracy: 0.8871 - val_loss: 0.7152 - learning_rate: 1.2500e-04
# Epoch 160/300
# 665/665 - 36s - 55ms/step - accuracy: 0.9846 - loss: 0.2498 - val_accuracy: 0.8875 - val_loss: 0.7066 - learning_rate: 1.2500e-04
# Epoch 161/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9839 - loss: 0.2483 - val_accuracy: 0.8899 - val_loss: 0.7050 - learning_rate: 1.2500e-04
# Epoch 162/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9844 - loss: 0.2472 - val_accuracy: 0.8879 - val_loss: 0.7090 - learning_rate: 1.2500e-04
# Epoch 163/300
# 665/665 - 36s - 55ms/step - accuracy: 0.9844 - loss: 0.2435 - val_accuracy: 0.8896 - val_loss: 0.7050 - learning_rate: 1.2500e-04
# Epoch 164/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9844 - loss: 0.2413 - val_accuracy: 0.8884 - val_loss: 0.7092 - learning_rate: 1.2500e-04
# Epoch 165/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9864 - loss: 0.2359 - val_accuracy: 0.8885 - val_loss: 0.7056 - learning_rate: 1.2500e-04
# Epoch 166/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9864 - loss: 0.2329 - val_accuracy: 0.8907 - val_loss: 0.6979 - learning_rate: 1.2500e-04
# Epoch 167/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9868 - loss: 0.2293 - val_accuracy: 0.8913 - val_loss: 0.6985 - learning_rate: 1.2500e-04
# Epoch 168/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9862 - loss: 0.2266 - val_accuracy: 0.8865 - val_loss: 0.6965 - learning_rate: 1.2500e-04
# Epoch 169/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9853 - loss: 0.2305 - val_accuracy: 0.8891 - val_loss: 0.7007 - learning_rate: 1.2500e-04
# Epoch 170/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9857 - loss: 0.2272 - val_accuracy: 0.8884 - val_loss: 0.7095 - learning_rate: 1.2500e-04
# Epoch 171/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9860 - loss: 0.2235 - val_accuracy: 0.8872 - val_loss: 0.6909 - learning_rate: 1.2500e-04
# Epoch 172/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9866 - loss: 0.2208 - val_accuracy: 0.8889 - val_loss: 0.7100 - learning_rate: 1.2500e-04
# Epoch 173/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9864 - loss: 0.2202 - val_accuracy: 0.8859 - val_loss: 0.7051 - learning_rate: 1.2500e-04
# Epoch 174/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9855 - loss: 0.2216 - val_accuracy: 0.8893 - val_loss: 0.6932 - learning_rate: 1.2500e-04
# Epoch 175/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9876 - loss: 0.2159 - val_accuracy: 0.8849 - val_loss: 0.6953 - learning_rate: 1.2500e-04
# Epoch 176/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9884 - loss: 0.2087 - val_accuracy: 0.8895 - val_loss: 0.6936 - learning_rate: 1.2500e-04
# Epoch 177/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9870 - loss: 0.2123 - val_accuracy: 0.8899 - val_loss: 0.6936 - learning_rate: 1.2500e-04
# Epoch 178/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9872 - loss: 0.2111 - val_accuracy: 0.8883 - val_loss: 0.6979 - learning_rate: 1.2500e-04
# Epoch 179/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9864 - loss: 0.2096 - val_accuracy: 0.8896 - val_loss: 0.6971 - learning_rate: 1.2500e-04
# Epoch 180/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9873 - loss: 0.2068 - val_accuracy: 0.8868 - val_loss: 0.7057 - learning_rate: 1.2500e-04
# Epoch 181/300
# 665/665 - 68s - 102ms/step - accuracy: 0.9872 - loss: 0.2071 - val_accuracy: 0.8875 - val_loss: 0.6996 - learning_rate: 1.2500e-04
# Epoch 182/300
# 665/665 - 566s - 851ms/step - accuracy: 0.9878 - loss: 0.2036 - val_accuracy: 0.8904 - val_loss: 0.6947 - learning_rate: 6.2500e-05
# Epoch 183/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9883 - loss: 0.2010 - val_accuracy: 0.8889 - val_loss: 0.6960 - learning_rate: 6.2500e-05
# Epoch 184/300
# 665/665 - 39s - 59ms/step - accuracy: 0.9895 - loss: 0.1970 - val_accuracy: 0.8900 - val_loss: 0.6891 - learning_rate: 6.2500e-05
# Epoch 185/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9898 - loss: 0.1940 - val_accuracy: 0.8891 - val_loss: 0.6909 - learning_rate: 6.2500e-05
# Epoch 186/300
# 665/665 - 39s - 58ms/step - accuracy: 0.9898 - loss: 0.1937 - val_accuracy: 0.8907 - val_loss: 0.6872 - learning_rate: 6.2500e-05
# Epoch 187/300
# 665/665 - 38s - 58ms/step - accuracy: 0.9896 - loss: 0.1930 - val_accuracy: 0.8909 - val_loss: 0.6910 - learning_rate: 6.2500e-05
# Epoch 188/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9914 - loss: 0.1885 - val_accuracy: 0.8905 - val_loss: 0.6924 - learning_rate: 6.2500e-05
# Epoch 189/300
# 665/665 - 39s - 58ms/step - accuracy: 0.9910 - loss: 0.1887 - val_accuracy: 0.8896 - val_loss: 0.6952 - learning_rate: 6.2500e-05
# Epoch 190/300
# 665/665 - 39s - 58ms/step - accuracy: 0.9904 - loss: 0.1873 - val_accuracy: 0.8913 - val_loss: 0.6955 - learning_rate: 6.2500e-05
# Epoch 191/300
# 665/665 - 40s - 61ms/step - accuracy: 0.9911 - loss: 0.1867 - val_accuracy: 0.8905 - val_loss: 0.6910 - learning_rate: 6.2500e-05
# Epoch 192/300
# 665/665 - 39s - 58ms/step - accuracy: 0.9909 - loss: 0.1854 - val_accuracy: 0.8920 - val_loss: 0.6855 - learning_rate: 6.2500e-05
# Epoch 193/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9898 - loss: 0.1861 - val_accuracy: 0.8931 - val_loss: 0.6904 - learning_rate: 6.2500e-05
# Epoch 194/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9913 - loss: 0.1819 - val_accuracy: 0.8925 - val_loss: 0.6968 - learning_rate: 6.2500e-05
# Epoch 195/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9912 - loss: 0.1815 - val_accuracy: 0.8920 - val_loss: 0.6936 - learning_rate: 6.2500e-05
# Epoch 196/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9906 - loss: 0.1827 - val_accuracy: 0.8888 - val_loss: 0.6999 - learning_rate: 6.2500e-05
# Epoch 197/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9912 - loss: 0.1810 - val_accuracy: 0.8924 - val_loss: 0.6924 - learning_rate: 6.2500e-05
# Epoch 198/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9914 - loss: 0.1785 - val_accuracy: 0.8920 - val_loss: 0.7009 - learning_rate: 6.2500e-05
# Epoch 199/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9914 - loss: 0.1785 - val_accuracy: 0.8929 - val_loss: 0.6901 - learning_rate: 6.2500e-05
# Epoch 200/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9921 - loss: 0.1750 - val_accuracy: 0.8904 - val_loss: 0.6878 - learning_rate: 6.2500e-05
# Epoch 201/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9922 - loss: 0.1744 - val_accuracy: 0.8907 - val_loss: 0.6894 - learning_rate: 6.2500e-05
# Epoch 202/300
# 665/665 - 47s - 71ms/step - accuracy: 0.9914 - loss: 0.1748 - val_accuracy: 0.8900 - val_loss: 0.6974 - learning_rate: 6.2500e-05
# Epoch 203/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9921 - loss: 0.1734 - val_accuracy: 0.8911 - val_loss: 0.6884 - learning_rate: 3.1250e-05
# Epoch 204/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9919 - loss: 0.1727 - val_accuracy: 0.8900 - val_loss: 0.6906 - learning_rate: 3.1250e-05
# Epoch 205/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9926 - loss: 0.1699 - val_accuracy: 0.8916 - val_loss: 0.6924 - learning_rate: 3.1250e-05
# Epoch 206/300
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 34
#      29 valid_ds = tf.data.Dataset.from_tensor_slices((X_valid, y_valid))\
#      30     .batch(batch_size)\
#      31     .prefetch(tf.data.AUTOTUNE)
#      33 # Then in model.fit:
# ---> 34 model.fit(train_ds,
#      35             epochs=epochs,
#      36             validation_data=valid_ds,
#      37             callbacks=[reduce_lr, early_stopping],
#      38             verbose=2)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py:371, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     369 for step, iterator in epoch_iterator:
#     370     callbacks.on_train_batch_begin(step)
# --> 371     logs = self.train_function(iterator)
#     372     callbacks.on_train_batch_end(step, logs)
#     373     if self.stop_training:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py:219, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     215 def function(iterator):
#     216     if isinstance(
#     217         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     218     ):
# --> 219         opt_outputs = multi_step_on_iterator(iterator)
#     220         if not opt_outputs.has_value():
#     221             raise StopIteration
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(15,6))

# Plotting the training and validation loss
plt.subplot(1, 2, 1)
plt.plot(model.history.history['loss'], label='Train Loss', color='#8502d1')
plt.plot(model.history.history['val_loss'], label='Validation Loss', color='darkorange')
plt.legend()
plt.title('Loss Evolution')

# Plotting the training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(model.history.history['accuracy'], label='Train Accuracy', color='#8502d1')
plt.plot(model.history.history['val_accuracy'], label='Validation Accuracy', color='darkorange')
plt.legend()
plt.title('Accuracy Evolution')

plt.show()
