# %% [markdown]
# # Import Libraries

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dropout, Flatten, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.models import load_model
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np

# %%
   # Configure TensorFlow to grow GPU memory allocation as needed
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# %% [markdown]
# Downloading CIFAR 10:

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %% [markdown]
# The standard practice for splitting data into training, validation, and test sets typically follows these guidelines:
# Training Set (60-80%): Used to train the model
# Validation Set (10-20%): Used for hyperparameter tuning and model selection
# Test Set (10-20%): Used for final model evaluation
#
# Since the training and test set are already split in this data set in a 1/6 proportion, we will further carve 10% out of the training set to be used for validation.
#
# Source: https://www.v7labs.com/blog/train-validation-test-set

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.15, random_state=0)

# %%
print('Train Images Shape:      ', X_train.shape)
print('Train Labels Shape:      ', y_train.shape)

print('\nValidation Images Shape: ', X_valid.shape)
print('Validation Labels Shape: ', y_valid.shape)

print('\nTest Images Shape:       ', X_test.shape)
print('Test Labels Shape:       ', y_test.shape)
# Out:
# Train Images Shape:       (42500, 32, 32, 3)
# Train Labels Shape:       (42500, 1)
#
# Validation Images Shape:  (7500, 32, 32, 3)
# Validation Labels Shape:  (7500, 1)
#
# Test Images Shape:        (10000, 32, 32, 3)
# Test Labels Shape:        (10000, 1)

# %%
# Display a 3x3 grid of random images
plt.figure(figsize=(8, 8))

# Define the class names, so that they can be shown in the plot
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# Plot 9 random images from the training set
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.imshow(X_train[i])
    plt.title(f'Class: {class_names[y_train[i][0]]}')
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
# Convert pixel values data type to float32
X_train = X_train.astype('float32')
X_test  = X_test.astype('float32')
X_valid = X_valid.astype('float32')

# Calculate the mean and standard deviation of the training images
mean = np.mean(X_train)
std  = np.std(X_train)

# Normalize the data
# The tiny value 1e-7 is added to prevent division by zero
X_train = (X_train-mean)/(std+1e-7)
X_test  = (X_test-mean) /(std+1e-7)
X_valid = (X_valid-mean)/(std+1e-7)

# %%
# One-hot encoding of labels
y_train = to_categorical(y_train, 10)
y_valid = to_categorical(y_valid, 10)
y_test  = to_categorical(y_test, 10)

# %% [markdown]
# # Data Augmentation
#
# Rotation:
#
# Source: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0
#
# Horizontal Flip:
#
# Source: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0
#
# Brightness:
#
# Source: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0
#
# Zoom:
#
# Source: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0
#
# Shearing:
#
# Source: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0
#
# Future work. Try:
# * Patch Suffle Regularization
# * Sample Pairing
# * Random Erasing

# %%
# Data augmentation
data_generator = ImageDataGenerator(
    # Rotate images randomly by up to 15 degrees
    rotation_range=15,
    # Randomly flip images horizontally
    horizontal_flip=True,
    # Zoom images in by up to 10%
    zoom_range=0.1,
    # Change brightness by up to 10%
    brightness_range=[0.9,1.1],
    # Shear intensity (shear angle in counter-clockwise direction in degrees)
    shear_range=10,
    # Channel shift intensity
    channel_shift_range=0.1,
)

# %% [markdown]
# Using mixed precision training (FP16) which can significantly speed up training on modern GPUs

# %%
# Enable mixed precision training
tf.keras.mixed_precision.set_global_policy('mixed_float16')

# %% [markdown]
# Building the VGG16 inspired model
#
# Source: https://www.kaggle.com/code/farzadnekouei/cifar-10-image-classification-with-cnn

# %%
# Initialize a sequential model
model = Sequential()

# Set the weight decay value for L2 regularization
weight_decay = 0.0001

# Add the first convolutional layer with 32 filters of size 3x3
model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay), 
                 input_shape=X_train.shape[1:]))
# Add batch normalization layer
model.add(BatchNormalization())

# Add the second convolutional layer similar to the first
model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the first max pooling layer with pool size of 2x2
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add dropout layer with 0.2 dropout rate
model.add(Dropout(rate=0.2))

# Add the third and fourth convolutional layers with 64 filters
model.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))   
model.add(BatchNormalization())
model.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the second max pooling layer and increase dropout rate to 0.3
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.3))

# Add the fifth and sixth convolutional layers with 128 filters
model.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay))) 
model.add(BatchNormalization())
model.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the third max pooling layer and increase dropout rate to 0.4
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.4))

# Add the seventh and eighth convolutional layers with 256 filters
model.add(Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay))) 
model.add(BatchNormalization())
model.add(Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the fourth max pooling layer and increase dropout rate to 0.5
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.5))

# Flatten the tensor output from the previous layer
model.add(Flatten())

# Add a fully connected layer with softmax activation function for outputting class probabilities
model.add(Dense(10, activation='softmax'))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-04-12 21:47:01.468840: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Pro
# 2025-04-12 21:47:01.468883: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-04-12 21:47:01.468902: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2025-04-12 21:47:01.468930: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-04-12 21:47:01.468945: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 4, 4, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 4, 4, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 4, 4, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 4, 4, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 2, 2, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 2, 2, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │        10,250 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,186,346 (4.53 MB)
#  Trainable params: 1,184,426 (4.52 MB)
#  Non-trainable params: 1,920 (7.50 KB)

# %%
# Set the batch size for the training
batch_size = 64

# Set the maximum number of epochs for the training
epochs = 300

# Define the optimizer (Adam)
optimizer = Adam(learning_rate=0.0005)

# Compile the model with the defined optimizer, loss function, and metrics
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Add ReduceLROnPlateau callback
# Here, the learning rate will be reduced by half (factor=0.5) if no improvement in validation loss is observed for 10 epochs
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=0.00001)

# Add EarlyStopping callback
# Here, training will be stopped if no improvement in validation loss is observed for 40 epochs.
# The `restore_best_weights` parameter ensures that the model weights are reset to the values from the epoch
# with the best value of the monitored quantity (in this case, 'val_loss').
early_stopping = EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True, verbose=1)

# Fit the model on the training data, using the defined batch size and number of epochs
# The validation data is used to evaluate the model's performance during training
# The callbacks implemented are learning rate reduction when a plateau is reached in validation loss and
# stopping training early if no improvement is observed
model.fit(data_generator.flow(X_train, y_train, batch_size=batch_size),
          epochs=epochs,
          validation_data=(X_valid, y_valid),
          callbacks=[reduce_lr, early_stopping], 
          verbose=2)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/300
# 2025-04-12 21:47:04.931307: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 665/665 - 83s - 125ms/step - accuracy: 0.3472 - loss: 2.2837 - val_accuracy: 0.4781 - val_loss: 1.6310 - learning_rate: 5.0000e-04
# Epoch 2/300
# 665/665 - 63s - 95ms/step - accuracy: 0.4864 - loss: 1.6677 - val_accuracy: 0.5191 - val_loss: 1.4980 - learning_rate: 5.0000e-04
# Epoch 3/300
# 665/665 - 62s - 93ms/step - accuracy: 0.5614 - loss: 1.4555 - val_accuracy: 0.6172 - val_loss: 1.2241 - learning_rate: 5.0000e-04
# Epoch 4/300
# 665/665 - 63s - 95ms/step - accuracy: 0.6033 - loss: 1.3241 - val_accuracy: 0.6172 - val_loss: 1.3503 - learning_rate: 5.0000e-04
# Epoch 5/300
# 665/665 - 66s - 99ms/step - accuracy: 0.6293 - loss: 1.2749 - val_accuracy: 0.6777 - val_loss: 1.0735 - learning_rate: 5.0000e-04
# Epoch 6/300
# 665/665 - 66s - 100ms/step - accuracy: 0.6173 - loss: 1.3634 - val_accuracy: 0.6825 - val_loss: 1.2275 - learning_rate: 5.0000e-04
# Epoch 7/300
# 665/665 - 64s - 97ms/step - accuracy: 0.6661 - loss: 1.2102 - val_accuracy: 0.6943 - val_loss: 1.0269 - learning_rate: 5.0000e-04
# Epoch 8/300
# 665/665 - 65s - 98ms/step - accuracy: 0.6383 - loss: 1.3366 - val_accuracy: 0.6964 - val_loss: 1.0513 - learning_rate: 5.0000e-04
# Epoch 9/300
# 665/665 - 65s - 98ms/step - accuracy: 0.6601 - loss: 1.2415 - val_accuracy: 0.7072 - val_loss: 1.0101 - learning_rate: 5.0000e-04
# Epoch 10/300
# 665/665 - 65s - 98ms/step - accuracy: 0.6920 - loss: 1.1190 - val_accuracy: 0.7401 - val_loss: 0.9624 - learning_rate: 5.0000e-04
# Epoch 11/300
# 665/665 - 64s - 96ms/step - accuracy: 0.7021 - loss: 1.0880 - val_accuracy: 0.7439 - val_loss: 1.0602 - learning_rate: 5.0000e-04
# Epoch 12/300
# 665/665 - 64s - 97ms/step - accuracy: 0.7150 - loss: 1.0425 - val_accuracy: 0.7520 - val_loss: 0.9201 - learning_rate: 5.0000e-04
# Epoch 13/300
# 665/665 - 65s - 97ms/step - accuracy: 0.7322 - loss: 0.9828 - val_accuracy: 0.7668 - val_loss: 0.8544 - learning_rate: 5.0000e-04
# Epoch 14/300
# 665/665 - 64s - 96ms/step - accuracy: 0.7328 - loss: 0.9752 - val_accuracy: 0.7348 - val_loss: 1.0040 - learning_rate: 5.0000e-04
# Epoch 15/300
# 665/665 - 169s - 255ms/step - accuracy: 0.7360 - loss: 0.9771 - val_accuracy: 0.7727 - val_loss: 0.8541 - learning_rate: 5.0000e-04
# Epoch 16/300
# 665/665 - 1022s - 2s/step - accuracy: 0.7479 - loss: 0.9393 - val_accuracy: 0.7753 - val_loss: 0.8384 - learning_rate: 5.0000e-04
# Epoch 17/300
# 665/665 - 240s - 361ms/step - accuracy: 0.7529 - loss: 0.9281 - val_accuracy: 0.7923 - val_loss: 0.7937 - learning_rate: 5.0000e-04
# Epoch 18/300
# 665/665 - 61s - 92ms/step - accuracy: 0.7600 - loss: 0.9113 - val_accuracy: 0.7996 - val_loss: 0.7831 - learning_rate: 5.0000e-04
# Epoch 19/300
# 665/665 - 61s - 92ms/step - accuracy: 0.7727 - loss: 0.8698 - val_accuracy: 0.7960 - val_loss: 0.7977 - learning_rate: 5.0000e-04
# Epoch 20/300
# 665/665 - 61s - 91ms/step - accuracy: 0.7673 - loss: 0.9015 - val_accuracy: 0.7991 - val_loss: 0.7905 - learning_rate: 5.0000e-04
# Epoch 21/300
# 665/665 - 61s - 92ms/step - accuracy: 0.7746 - loss: 0.8721 - val_accuracy: 0.8097 - val_loss: 0.7723 - learning_rate: 5.0000e-04
# Epoch 22/300
# 665/665 - 61s - 92ms/step - accuracy: 0.7780 - loss: 0.8562 - val_accuracy: 0.8057 - val_loss: 0.7807 - learning_rate: 5.0000e-04
# Epoch 23/300
# 665/665 - 62s - 93ms/step - accuracy: 0.7839 - loss: 0.8520 - val_accuracy: 0.8013 - val_loss: 0.8068 - learning_rate: 5.0000e-04
# Epoch 24/300
# 665/665 - 61s - 91ms/step - accuracy: 0.7834 - loss: 0.8594 - val_accuracy: 0.8049 - val_loss: 0.7822 - learning_rate: 5.0000e-04
# Epoch 25/300
# 665/665 - 62s - 93ms/step - accuracy: 0.7847 - loss: 0.8540 - val_accuracy: 0.8088 - val_loss: 0.7900 - learning_rate: 5.0000e-04
# Epoch 26/300
# 665/665 - 62s - 94ms/step - accuracy: 0.7956 - loss: 0.8153 - val_accuracy: 0.8177 - val_loss: 0.7452 - learning_rate: 5.0000e-04
# Epoch 27/300
# 665/665 - 1032s - 2s/step - accuracy: 0.7983 - loss: 0.8103 - val_accuracy: 0.8084 - val_loss: 0.7691 - learning_rate: 5.0000e-04
# Epoch 28/300
# 665/665 - 1043s - 2s/step - accuracy: 0.7927 - loss: 0.8374 - val_accuracy: 0.8028 - val_loss: 0.8138 - learning_rate: 5.0000e-04
# Epoch 29/300
# 665/665 - 962s - 1s/step - accuracy: 0.7973 - loss: 0.8347 - val_accuracy: 0.7973 - val_loss: 0.8313 - learning_rate: 5.0000e-04
# Epoch 30/300
# 665/665 - 1052s - 2s/step - accuracy: 0.8008 - loss: 0.8129 - val_accuracy: 0.8295 - val_loss: 0.7243 - learning_rate: 5.0000e-04
# Epoch 31/300
# 665/665 - 1059s - 2s/step - accuracy: 0.7985 - loss: 0.8333 - val_accuracy: 0.8229 - val_loss: 0.7503 - learning_rate: 5.0000e-04
# Epoch 32/300
# 665/665 - 956s - 1s/step - accuracy: 0.8028 - loss: 0.8203 - val_accuracy: 0.8052 - val_loss: 0.8210 - learning_rate: 5.0000e-04
# Epoch 33/300
# 665/665 - 45s - 67ms/step - accuracy: 0.8114 - loss: 0.7824 - val_accuracy: 0.8227 - val_loss: 0.7671 - learning_rate: 5.0000e-04
# Epoch 34/300
# 665/665 - 856s - 1s/step - accuracy: 0.8100 - loss: 0.7961 - val_accuracy: 0.8097 - val_loss: 0.8049 - learning_rate: 5.0000e-04
# Epoch 35/300
# 665/665 - 1011s - 2s/step - accuracy: 0.8137 - loss: 0.7836 - val_accuracy: 0.8311 - val_loss: 0.7360 - learning_rate: 5.0000e-04
# Epoch 36/300
# 665/665 - 45s - 68ms/step - accuracy: 0.8161 - loss: 0.7760 - val_accuracy: 0.8213 - val_loss: 0.7630 - learning_rate: 5.0000e-04
# Epoch 37/300
# 665/665 - 957s - 1s/step - accuracy: 0.8113 - loss: 0.7989 - val_accuracy: 0.8288 - val_loss: 0.7621 - learning_rate: 5.0000e-04
# Epoch 38/300
# 665/665 - 963s - 1s/step - accuracy: 0.8264 - loss: 0.7548 - val_accuracy: 0.8200 - val_loss: 0.7907 - learning_rate: 5.0000e-04
# Epoch 39/300
# 665/665 - 960s - 1s/step - accuracy: 0.8246 - loss: 0.7615 - val_accuracy: 0.8393 - val_loss: 0.7146 - learning_rate: 5.0000e-04
# Epoch 40/300
# 665/665 - 897s - 1s/step - accuracy: 0.8218 - loss: 0.7593 - val_accuracy: 0.8239 - val_loss: 0.7835 - learning_rate: 5.0000e-04
# Epoch 41/300
# 665/665 - 2021s - 3s/step - accuracy: 0.8274 - loss: 0.7447 - val_accuracy: 0.8175 - val_loss: 0.7964 - learning_rate: 5.0000e-04
# Epoch 42/300
# 665/665 - 960s - 1s/step - accuracy: 0.8234 - loss: 0.7637 - val_accuracy: 0.8391 - val_loss: 0.7099 - learning_rate: 5.0000e-04
# Epoch 43/300
# 665/665 - 971s - 1s/step - accuracy: 0.8265 - loss: 0.7625 - val_accuracy: 0.8065 - val_loss: 0.8777 - learning_rate: 5.0000e-04
# Epoch 44/300
# 665/665 - 822s - 1s/step - accuracy: 0.8190 - loss: 0.7869 - val_accuracy: 0.8465 - val_loss: 0.7071 - learning_rate: 5.0000e-04
# Epoch 45/300
# 665/665 - 386s - 581ms/step - accuracy: 0.8292 - loss: 0.7594 - val_accuracy: 0.8499 - val_loss: 0.6874 - learning_rate: 5.0000e-04
# Epoch 46/300
# 665/665 - 1069s - 2s/step - accuracy: 0.8330 - loss: 0.7438 - val_accuracy: 0.8259 - val_loss: 0.7696 - learning_rate: 5.0000e-04
# Epoch 47/300
# 665/665 - 1085s - 2s/step - accuracy: 0.8303 - loss: 0.7483 - val_accuracy: 0.8416 - val_loss: 0.7131 - learning_rate: 5.0000e-04
# Epoch 48/300
# 665/665 - 1004s - 2s/step - accuracy: 0.8327 - loss: 0.7472 - val_accuracy: 0.8293 - val_loss: 0.7754 - learning_rate: 5.0000e-04
# Epoch 49/300
# 665/665 - 953s - 1s/step - accuracy: 0.8388 - loss: 0.7195 - val_accuracy: 0.8313 - val_loss: 0.7504 - learning_rate: 5.0000e-04
# Epoch 50/300
# 665/665 - 121s - 183ms/step - accuracy: 0.8383 - loss: 0.7193 - val_accuracy: 0.8399 - val_loss: 0.7161 - learning_rate: 5.0000e-04
# Epoch 51/300
# 665/665 - 44s - 66ms/step - accuracy: 0.8249 - loss: 0.7689 - val_accuracy: 0.8499 - val_loss: 0.7095 - learning_rate: 5.0000e-04
# Epoch 52/300
# 665/665 - 977s - 1s/step - accuracy: 0.8341 - loss: 0.7444 - val_accuracy: 0.8395 - val_loss: 0.7368 - learning_rate: 5.0000e-04
# Epoch 53/300
# 665/665 - 1015s - 2s/step - accuracy: 0.8403 - loss: 0.7227 - val_accuracy: 0.8441 - val_loss: 0.7179 - learning_rate: 5.0000e-04
# Epoch 54/300
# 665/665 - 963s - 1s/step - accuracy: 0.8359 - loss: 0.7379 - val_accuracy: 0.8456 - val_loss: 0.7234 - learning_rate: 5.0000e-04
# Epoch 55/300
# 665/665 - 604s - 908ms/step - accuracy: 0.8423 - loss: 0.7201 - val_accuracy: 0.8519 - val_loss: 0.6933 - learning_rate: 5.0000e-04
# Epoch 56/300
# 665/665 - 1002s - 2s/step - accuracy: 0.8560 - loss: 0.6708 - val_accuracy: 0.8584 - val_loss: 0.6727 - learning_rate: 2.5000e-04
# Epoch 57/300
# 665/665 - 1032s - 2s/step - accuracy: 0.8602 - loss: 0.6533 - val_accuracy: 0.8633 - val_loss: 0.6530 - learning_rate: 2.5000e-04
# Epoch 58/300
# 665/665 - 993s - 1s/step - accuracy: 0.8668 - loss: 0.6349 - val_accuracy: 0.8597 - val_loss: 0.6612 - learning_rate: 2.5000e-04
# Epoch 59/300
# 665/665 - 640s - 963ms/step - accuracy: 0.8673 - loss: 0.6283 - val_accuracy: 0.8636 - val_loss: 0.6413 - learning_rate: 2.5000e-04
# Epoch 60/300
# 665/665 - 44s - 67ms/step - accuracy: 0.8694 - loss: 0.6157 - val_accuracy: 0.8659 - val_loss: 0.6302 - learning_rate: 2.5000e-04
# Epoch 61/300
# 665/665 - 964s - 1s/step - accuracy: 0.8684 - loss: 0.6125 - val_accuracy: 0.8548 - val_loss: 0.6566 - learning_rate: 2.5000e-04
# Epoch 62/300
# 665/665 - 1053s - 2s/step - accuracy: 0.8720 - loss: 0.6045 - val_accuracy: 0.8588 - val_loss: 0.6490 - learning_rate: 2.5000e-04
# Epoch 63/300
# 665/665 - 961s - 1s/step - accuracy: 0.8741 - loss: 0.5880 - val_accuracy: 0.8539 - val_loss: 0.6738 - learning_rate: 2.5000e-04
# Epoch 64/300
# 665/665 - 45s - 67ms/step - accuracy: 0.8746 - loss: 0.5879 - val_accuracy: 0.8669 - val_loss: 0.6138 - learning_rate: 2.5000e-04
# Epoch 65/300
# 665/665 - 625s - 940ms/step - accuracy: 0.8732 - loss: 0.5901 - val_accuracy: 0.8644 - val_loss: 0.6233 - learning_rate: 2.5000e-04
# Epoch 66/300
# 665/665 - 1000s - 2s/step - accuracy: 0.8748 - loss: 0.5793 - val_accuracy: 0.8587 - val_loss: 0.6521 - learning_rate: 2.5000e-04
# Epoch 67/300
# 665/665 - 670s - 1s/step - accuracy: 0.8761 - loss: 0.5766 - val_accuracy: 0.8663 - val_loss: 0.6149 - learning_rate: 2.5000e-04
# Epoch 68/300
# 665/665 - 52s - 78ms/step - accuracy: 0.8748 - loss: 0.5726 - val_accuracy: 0.8731 - val_loss: 0.5919 - learning_rate: 2.5000e-04
# Epoch 69/300
# 665/665 - 985s - 1s/step - accuracy: 0.8758 - loss: 0.5777 - val_accuracy: 0.8672 - val_loss: 0.6223 - learning_rate: 2.5000e-04
# Epoch 70/300
# 665/665 - 881s - 1s/step - accuracy: 0.8780 - loss: 0.5666 - val_accuracy: 0.8692 - val_loss: 0.6044 - learning_rate: 2.5000e-04
# Epoch 71/300
# 665/665 - 192s - 289ms/step - accuracy: 0.8768 - loss: 0.5638 - val_accuracy: 0.8669 - val_loss: 0.6174 - learning_rate: 2.5000e-04
# Epoch 72/300
# 665/665 - 49s - 73ms/step - accuracy: 0.8819 - loss: 0.5527 - val_accuracy: 0.8764 - val_loss: 0.5857 - learning_rate: 2.5000e-04
# Epoch 73/300
# 665/665 - 46s - 69ms/step - accuracy: 0.8845 - loss: 0.5476 - val_accuracy: 0.8744 - val_loss: 0.5961 - learning_rate: 2.5000e-04
# Epoch 74/300
# 665/665 - 46s - 69ms/step - accuracy: 0.8760 - loss: 0.5618 - val_accuracy: 0.8705 - val_loss: 0.5955 - learning_rate: 2.5000e-04
# Epoch 75/300
# 665/665 - 46s - 69ms/step - accuracy: 0.8823 - loss: 0.5446 - val_accuracy: 0.8708 - val_loss: 0.5950 - learning_rate: 2.5000e-04
# Epoch 76/300
# 665/665 - 46s - 69ms/step - accuracy: 0.8828 - loss: 0.5482 - val_accuracy: 0.8687 - val_loss: 0.6004 - learning_rate: 2.5000e-04
# Epoch 77/300
# 665/665 - 46s - 69ms/step - accuracy: 0.8836 - loss: 0.5420 - val_accuracy: 0.8617 - val_loss: 0.6349 - learning_rate: 2.5000e-04
# Epoch 78/300
# 665/665 - 47s - 70ms/step - accuracy: 0.8850 - loss: 0.5359 - val_accuracy: 0.8581 - val_loss: 0.6304 - learning_rate: 2.5000e-04
# Epoch 79/300
# 665/665 - 46s - 70ms/step - accuracy: 0.8821 - loss: 0.5428 - val_accuracy: 0.8677 - val_loss: 0.6033 - learning_rate: 2.5000e-04
# Epoch 80/300
# 665/665 - 46s - 69ms/step - accuracy: 0.8846 - loss: 0.5375 - val_accuracy: 0.8737 - val_loss: 0.5889 - learning_rate: 2.5000e-04
# Epoch 81/300
# 665/665 - 46s - 69ms/step - accuracy: 0.8861 - loss: 0.5271 - val_accuracy: 0.8709 - val_loss: 0.5885 - learning_rate: 2.5000e-04
# Epoch 82/300
# 665/665 - 46s - 69ms/step - accuracy: 0.8869 - loss: 0.5268 - val_accuracy: 0.8684 - val_loss: 0.5907 - learning_rate: 2.5000e-04
# Epoch 83/300
# 665/665 - 46s - 69ms/step - accuracy: 0.8921 - loss: 0.5083 - val_accuracy: 0.8785 - val_loss: 0.5657 - learning_rate: 1.2500e-04
# Epoch 84/300
# 665/665 - 46s - 69ms/step - accuracy: 0.8968 - loss: 0.4946 - val_accuracy: 0.8727 - val_loss: 0.5864 - learning_rate: 1.2500e-04
# Epoch 85/300
# 665/665 - 47s - 70ms/step - accuracy: 0.8980 - loss: 0.4865 - val_accuracy: 0.8751 - val_loss: 0.5828 - learning_rate: 1.2500e-04
# Epoch 86/300
# 665/665 - 462s - 695ms/step - accuracy: 0.8985 - loss: 0.4845 - val_accuracy: 0.8757 - val_loss: 0.5654 - learning_rate: 1.2500e-04
# Epoch 87/300
# 665/665 - 482s - 724ms/step - accuracy: 0.9024 - loss: 0.4750 - val_accuracy: 0.8785 - val_loss: 0.5595 - learning_rate: 1.2500e-04
# Epoch 88/300
# 665/665 - 897s - 1s/step - accuracy: 0.8996 - loss: 0.4796 - val_accuracy: 0.8791 - val_loss: 0.5712 - learning_rate: 1.2500e-04
# Epoch 89/300
# 665/665 - 48s - 72ms/step - accuracy: 0.9021 - loss: 0.4730 - val_accuracy: 0.8757 - val_loss: 0.5672 - learning_rate: 1.2500e-04
# Epoch 90/300
# 665/665 - 52s - 78ms/step - accuracy: 0.9032 - loss: 0.4684 - val_accuracy: 0.8796 - val_loss: 0.5505 - learning_rate: 1.2500e-04
# Epoch 91/300
# 665/665 - 73s - 109ms/step - accuracy: 0.9041 - loss: 0.4596 - val_accuracy: 0.8771 - val_loss: 0.5659 - learning_rate: 1.2500e-04
# Epoch 92/300
# 665/665 - 46s - 69ms/step - accuracy: 0.9054 - loss: 0.4584 - val_accuracy: 0.8791 - val_loss: 0.5585 - learning_rate: 1.2500e-04
# Epoch 93/300
# 665/665 - 46s - 69ms/step - accuracy: 0.9039 - loss: 0.4594 - val_accuracy: 0.8792 - val_loss: 0.5542 - learning_rate: 1.2500e-04
# Epoch 94/300
# 665/665 - 46s - 69ms/step - accuracy: 0.9068 - loss: 0.4527 - val_accuracy: 0.8819 - val_loss: 0.5481 - learning_rate: 1.2500e-04
# Epoch 95/300
# 665/665 - 46s - 69ms/step - accuracy: 0.9080 - loss: 0.4497 - val_accuracy: 0.8817 - val_loss: 0.5564 - learning_rate: 1.2500e-04
# Epoch 96/300
# 665/665 - 46s - 69ms/step - accuracy: 0.9069 - loss: 0.4463 - val_accuracy: 0.8815 - val_loss: 0.5395 - learning_rate: 1.2500e-04
# Epoch 97/300
# 665/665 - 46s - 68ms/step - accuracy: 0.9074 - loss: 0.4488 - val_accuracy: 0.8743 - val_loss: 0.5617 - learning_rate: 1.2500e-04
# Epoch 98/300
# 665/665 - 46s - 69ms/step - accuracy: 0.9072 - loss: 0.4470 - val_accuracy: 0.8809 - val_loss: 0.5486 - learning_rate: 1.2500e-04
# Epoch 99/300
# 665/665 - 45s - 68ms/step - accuracy: 0.9090 - loss: 0.4419 - val_accuracy: 0.8809 - val_loss: 0.5418 - learning_rate: 1.2500e-04
# Epoch 100/300
# 665/665 - 45s - 68ms/step - accuracy: 0.9105 - loss: 0.4356 - val_accuracy: 0.8795 - val_loss: 0.5490 - learning_rate: 1.2500e-04
# Epoch 101/300
# 665/665 - 44s - 67ms/step - accuracy: 0.9084 - loss: 0.4353 - val_accuracy: 0.8704 - val_loss: 0.5884 - learning_rate: 1.2500e-04
# Epoch 102/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9088 - loss: 0.4352 - val_accuracy: 0.8797 - val_loss: 0.5530 - learning_rate: 1.2500e-04
# Epoch 103/300
# 665/665 - 38s - 56ms/step - accuracy: 0.9111 - loss: 0.4337 - val_accuracy: 0.8788 - val_loss: 0.5444 - learning_rate: 1.2500e-04
# Epoch 104/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9124 - loss: 0.4256 - val_accuracy: 0.8833 - val_loss: 0.5383 - learning_rate: 1.2500e-04
# Epoch 105/300
# 665/665 - 38s - 57ms/step - accuracy: 0.9104 - loss: 0.4295 - val_accuracy: 0.8753 - val_loss: 0.5631 - learning_rate: 1.2500e-04
# Epoch 106/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9116 - loss: 0.4265 - val_accuracy: 0.8825 - val_loss: 0.5356 - learning_rate: 1.2500e-04
# Epoch 107/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9128 - loss: 0.4227 - val_accuracy: 0.8824 - val_loss: 0.5378 - learning_rate: 1.2500e-04
# Epoch 108/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9127 - loss: 0.4215 - val_accuracy: 0.8836 - val_loss: 0.5407 - learning_rate: 1.2500e-04
# Epoch 109/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9107 - loss: 0.4258 - val_accuracy: 0.8819 - val_loss: 0.5391 - learning_rate: 1.2500e-04
# Epoch 110/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9128 - loss: 0.4195 - val_accuracy: 0.8765 - val_loss: 0.5561 - learning_rate: 1.2500e-04
# Epoch 111/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9126 - loss: 0.4193 - val_accuracy: 0.8824 - val_loss: 0.5332 - learning_rate: 1.2500e-04
# Epoch 112/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9122 - loss: 0.4198 - val_accuracy: 0.8804 - val_loss: 0.5343 - learning_rate: 1.2500e-04
# Epoch 113/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9126 - loss: 0.4196 - val_accuracy: 0.8764 - val_loss: 0.5507 - learning_rate: 1.2500e-04
# Epoch 114/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9149 - loss: 0.4098 - val_accuracy: 0.8820 - val_loss: 0.5460 - learning_rate: 1.2500e-04
# Epoch 115/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9146 - loss: 0.4141 - val_accuracy: 0.8839 - val_loss: 0.5313 - learning_rate: 1.2500e-04
# Epoch 116/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9161 - loss: 0.4063 - val_accuracy: 0.8792 - val_loss: 0.5438 - learning_rate: 1.2500e-04
# Epoch 117/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9142 - loss: 0.4109 - val_accuracy: 0.8779 - val_loss: 0.5523 - learning_rate: 1.2500e-04
# Epoch 118/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9172 - loss: 0.4028 - val_accuracy: 0.8856 - val_loss: 0.5263 - learning_rate: 1.2500e-04
# Epoch 119/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9161 - loss: 0.4058 - val_accuracy: 0.8761 - val_loss: 0.5531 - learning_rate: 1.2500e-04
# Epoch 120/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9167 - loss: 0.4018 - val_accuracy: 0.8771 - val_loss: 0.5583 - learning_rate: 1.2500e-04
# Epoch 121/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9170 - loss: 0.3989 - val_accuracy: 0.8765 - val_loss: 0.5523 - learning_rate: 1.2500e-04
# Epoch 122/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9166 - loss: 0.4031 - val_accuracy: 0.8808 - val_loss: 0.5359 - learning_rate: 1.2500e-04
# Epoch 123/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9167 - loss: 0.3974 - val_accuracy: 0.8820 - val_loss: 0.5348 - learning_rate: 1.2500e-04
# Epoch 124/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9159 - loss: 0.4014 - val_accuracy: 0.8880 - val_loss: 0.5164 - learning_rate: 1.2500e-04
# Epoch 125/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9154 - loss: 0.3993 - val_accuracy: 0.8861 - val_loss: 0.5324 - learning_rate: 1.2500e-04
# Epoch 126/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9170 - loss: 0.3951 - val_accuracy: 0.8873 - val_loss: 0.5255 - learning_rate: 1.2500e-04
# Epoch 127/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9184 - loss: 0.3966 - val_accuracy: 0.8825 - val_loss: 0.5345 - learning_rate: 1.2500e-04
# Epoch 128/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9172 - loss: 0.3920 - val_accuracy: 0.8799 - val_loss: 0.5437 - learning_rate: 1.2500e-04
# Epoch 129/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9177 - loss: 0.3892 - val_accuracy: 0.8835 - val_loss: 0.5442 - learning_rate: 1.2500e-04
# Epoch 130/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9180 - loss: 0.3901 - val_accuracy: 0.8853 - val_loss: 0.5377 - learning_rate: 1.2500e-04
# Epoch 131/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9190 - loss: 0.3905 - val_accuracy: 0.8857 - val_loss: 0.5182 - learning_rate: 1.2500e-04
# Epoch 132/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9195 - loss: 0.3883 - val_accuracy: 0.8839 - val_loss: 0.5298 - learning_rate: 1.2500e-04
# Epoch 133/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9191 - loss: 0.3895 - val_accuracy: 0.8816 - val_loss: 0.5398 - learning_rate: 1.2500e-04
# Epoch 134/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9198 - loss: 0.3850 - val_accuracy: 0.8852 - val_loss: 0.5380 - learning_rate: 1.2500e-04
# Epoch 135/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9250 - loss: 0.3681 - val_accuracy: 0.8888 - val_loss: 0.5267 - learning_rate: 6.2500e-05
# Epoch 136/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9252 - loss: 0.3689 - val_accuracy: 0.8868 - val_loss: 0.5236 - learning_rate: 6.2500e-05
# Epoch 137/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9280 - loss: 0.3618 - val_accuracy: 0.8891 - val_loss: 0.5198 - learning_rate: 6.2500e-05
# Epoch 138/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9276 - loss: 0.3598 - val_accuracy: 0.8867 - val_loss: 0.5284 - learning_rate: 6.2500e-05
# Epoch 139/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9282 - loss: 0.3627 - val_accuracy: 0.8901 - val_loss: 0.5123 - learning_rate: 6.2500e-05
# Epoch 140/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9305 - loss: 0.3539 - val_accuracy: 0.8895 - val_loss: 0.5178 - learning_rate: 6.2500e-05
# Epoch 141/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9285 - loss: 0.3565 - val_accuracy: 0.8911 - val_loss: 0.5189 - learning_rate: 6.2500e-05
# Epoch 142/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9296 - loss: 0.3573 - val_accuracy: 0.8860 - val_loss: 0.5291 - learning_rate: 6.2500e-05
# Epoch 143/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9286 - loss: 0.3554 - val_accuracy: 0.8897 - val_loss: 0.5189 - learning_rate: 6.2500e-05
# Epoch 144/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9288 - loss: 0.3552 - val_accuracy: 0.8859 - val_loss: 0.5243 - learning_rate: 6.2500e-05
# Epoch 145/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9327 - loss: 0.3466 - val_accuracy: 0.8903 - val_loss: 0.5117 - learning_rate: 6.2500e-05
# Epoch 146/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9295 - loss: 0.3487 - val_accuracy: 0.8888 - val_loss: 0.5205 - learning_rate: 6.2500e-05
# Epoch 147/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9298 - loss: 0.3502 - val_accuracy: 0.8869 - val_loss: 0.5205 - learning_rate: 6.2500e-05
# Epoch 148/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9294 - loss: 0.3523 - val_accuracy: 0.8929 - val_loss: 0.5016 - learning_rate: 6.2500e-05
# Epoch 149/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9318 - loss: 0.3447 - val_accuracy: 0.8900 - val_loss: 0.5110 - learning_rate: 6.2500e-05
# Epoch 150/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9324 - loss: 0.3436 - val_accuracy: 0.8903 - val_loss: 0.5094 - learning_rate: 6.2500e-05
# Epoch 151/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9332 - loss: 0.3391 - val_accuracy: 0.8895 - val_loss: 0.5138 - learning_rate: 6.2500e-05
# Epoch 152/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9296 - loss: 0.3485 - val_accuracy: 0.8908 - val_loss: 0.4928 - learning_rate: 6.2500e-05
# Epoch 153/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9321 - loss: 0.3415 - val_accuracy: 0.8909 - val_loss: 0.5137 - learning_rate: 6.2500e-05
# Epoch 154/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9337 - loss: 0.3364 - val_accuracy: 0.8927 - val_loss: 0.5066 - learning_rate: 6.2500e-05
# Epoch 155/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9353 - loss: 0.3363 - val_accuracy: 0.8895 - val_loss: 0.5098 - learning_rate: 6.2500e-05
# Epoch 156/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9314 - loss: 0.3419 - val_accuracy: 0.8891 - val_loss: 0.5205 - learning_rate: 6.2500e-05
# Epoch 157/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9327 - loss: 0.3380 - val_accuracy: 0.8919 - val_loss: 0.5095 - learning_rate: 6.2500e-05
# Epoch 158/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9344 - loss: 0.3354 - val_accuracy: 0.8912 - val_loss: 0.5093 - learning_rate: 6.2500e-05
# Epoch 159/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9364 - loss: 0.3275 - val_accuracy: 0.8864 - val_loss: 0.5188 - learning_rate: 6.2500e-05
# Epoch 160/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9360 - loss: 0.3306 - val_accuracy: 0.8896 - val_loss: 0.5195 - learning_rate: 6.2500e-05
# Epoch 161/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9345 - loss: 0.3319 - val_accuracy: 0.8879 - val_loss: 0.5180 - learning_rate: 6.2500e-05
# Epoch 162/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9347 - loss: 0.3300 - val_accuracy: 0.8887 - val_loss: 0.5079 - learning_rate: 6.2500e-05
# Epoch 163/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9350 - loss: 0.3262 - val_accuracy: 0.8921 - val_loss: 0.5075 - learning_rate: 3.1250e-05
# Epoch 164/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9387 - loss: 0.3237 - val_accuracy: 0.8908 - val_loss: 0.5121 - learning_rate: 3.1250e-05
# Epoch 165/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9368 - loss: 0.3226 - val_accuracy: 0.8939 - val_loss: 0.4976 - learning_rate: 3.1250e-05
# Epoch 166/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9381 - loss: 0.3188 - val_accuracy: 0.8921 - val_loss: 0.5071 - learning_rate: 3.1250e-05
# Epoch 167/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9384 - loss: 0.3177 - val_accuracy: 0.8907 - val_loss: 0.5130 - learning_rate: 3.1250e-05
# Epoch 168/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9390 - loss: 0.3171 - val_accuracy: 0.8925 - val_loss: 0.5045 - learning_rate: 3.1250e-05
# Epoch 169/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9387 - loss: 0.3163 - val_accuracy: 0.8931 - val_loss: 0.5037 - learning_rate: 3.1250e-05
# Epoch 170/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9393 - loss: 0.3160 - val_accuracy: 0.8923 - val_loss: 0.5095 - learning_rate: 3.1250e-05
# Epoch 171/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9403 - loss: 0.3137 - val_accuracy: 0.8937 - val_loss: 0.4963 - learning_rate: 3.1250e-05
# Epoch 172/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9405 - loss: 0.3145 - val_accuracy: 0.8945 - val_loss: 0.4947 - learning_rate: 3.1250e-05
# Epoch 173/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9410 - loss: 0.3079 - val_accuracy: 0.8939 - val_loss: 0.4974 - learning_rate: 1.5625e-05
# Epoch 174/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9418 - loss: 0.3075 - val_accuracy: 0.8936 - val_loss: 0.4957 - learning_rate: 1.5625e-05
# Epoch 175/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9438 - loss: 0.3051 - val_accuracy: 0.8935 - val_loss: 0.4993 - learning_rate: 1.5625e-05
# Epoch 176/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9405 - loss: 0.3079 - val_accuracy: 0.8925 - val_loss: 0.5056 - learning_rate: 1.5625e-05
# Epoch 177/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9436 - loss: 0.3056 - val_accuracy: 0.8957 - val_loss: 0.4967 - learning_rate: 1.5625e-05
# Epoch 178/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9408 - loss: 0.3069 - val_accuracy: 0.8936 - val_loss: 0.5025 - learning_rate: 1.5625e-05
# Epoch 179/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9417 - loss: 0.3083 - val_accuracy: 0.8928 - val_loss: 0.4991 - learning_rate: 1.5625e-05
# Epoch 180/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9430 - loss: 0.3037 - val_accuracy: 0.8927 - val_loss: 0.5029 - learning_rate: 1.5625e-05
# Epoch 181/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9428 - loss: 0.3025 - val_accuracy: 0.8944 - val_loss: 0.5036 - learning_rate: 1.5625e-05
# Epoch 182/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9433 - loss: 0.3024 - val_accuracy: 0.8929 - val_loss: 0.5002 - learning_rate: 1.5625e-05
# Epoch 183/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9431 - loss: 0.3028 - val_accuracy: 0.8960 - val_loss: 0.4971 - learning_rate: 1.0000e-05
# Epoch 184/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9429 - loss: 0.3031 - val_accuracy: 0.8949 - val_loss: 0.4970 - learning_rate: 1.0000e-05
# Epoch 185/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9421 - loss: 0.3051 - val_accuracy: 0.8935 - val_loss: 0.4998 - learning_rate: 1.0000e-05
# Epoch 186/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9421 - loss: 0.3030 - val_accuracy: 0.8955 - val_loss: 0.4948 - learning_rate: 1.0000e-05
# Epoch 187/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9429 - loss: 0.2993 - val_accuracy: 0.8949 - val_loss: 0.4998 - learning_rate: 1.0000e-05
# Epoch 188/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9430 - loss: 0.3023 - val_accuracy: 0.8949 - val_loss: 0.5012 - learning_rate: 1.0000e-05
# Epoch 189/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9425 - loss: 0.3019 - val_accuracy: 0.8944 - val_loss: 0.5007 - learning_rate: 1.0000e-05
# Epoch 190/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9434 - loss: 0.3004 - val_accuracy: 0.8941 - val_loss: 0.5010 - learning_rate: 1.0000e-05
# Epoch 191/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9436 - loss: 0.2972 - val_accuracy: 0.8931 - val_loss: 0.5050 - learning_rate: 1.0000e-05
# Epoch 192/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9453 - loss: 0.2999 - val_accuracy: 0.8941 - val_loss: 0.4961 - learning_rate: 1.0000e-05
# Epoch 192: early stopping
# Restoring model weights from the end of the best epoch: 152.

# %%
plt.figure(figsize=(15,6))

# Plotting the training and validation loss
plt.subplot(1, 2, 1)
plt.plot(model.history.history['loss'], label='Train Loss', color='#8502d1')
plt.plot(model.history.history['val_loss'], label='Validation Loss', color='darkorange')
plt.legend()
plt.title('Loss Evolution')

# Plotting the training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(model.history.history['accuracy'], label='Train Accuracy', color='#8502d1')
plt.plot(model.history.history['val_accuracy'], label='Validation Accuracy', color='darkorange')
plt.legend()
plt.title('Accuracy Evolution')

plt.show()

# %%
# Use the model to make predictions, evaluate on test data
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=1)

print('\nTest Accuracy:', test_acc)
print('Test Loss:    ', test_loss)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8929 - loss: 0.5040
#
# Test Accuracy: 0.8942000269889832
# Test Loss:     0.49927279353141785
