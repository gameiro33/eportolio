# %% [markdown]
# # Import Libraries

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dropout, Flatten, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.models import load_model
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import cv2
import urllib.request

# %%
   # Configure TensorFlow to grow GPU memory allocation as needed
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# %% [markdown]
# Downloading CIFAR 10:

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %% [markdown]
# The standard practice for splitting data into training, validation, and test sets typically follows these guidelines:
# Training Set (60-80%): Used to train the model
# Validation Set (10-20%): Used for hyperparameter tuning and model selection
# Test Set (10-20%): Used for final model evaluation
#
# Since the training and test set are already split in this data set in a 1/6 proportion, we will further carve 10% out of the training set to be used for validation.
#
# Source: https://www.v7labs.com/blog/train-validation-test-set

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.15, random_state=0)

# %%
print('Train Images Shape:      ', X_train.shape)
print('Train Labels Shape:      ', y_train.shape)

print('\nValidation Images Shape: ', X_valid.shape)
print('Validation Labels Shape: ', y_valid.shape)

print('\nTest Images Shape:       ', X_test.shape)
print('Test Labels Shape:       ', y_test.shape)
# Out:
# Train Images Shape:       (42500, 32, 32, 3)
# Train Labels Shape:       (42500, 1)
#
# Validation Images Shape:  (7500, 32, 32, 3)
# Validation Labels Shape:  (7500, 1)
#
# Test Images Shape:        (10000, 32, 32, 3)
# Test Labels Shape:        (10000, 1)

# %%
# Display a 3x3 grid of random images
plt.figure(figsize=(8, 8))

# Define the class names, so that they can be shown in the plot
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# Plot 9 random images from the training set
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.imshow(X_train[i])
    plt.title(f'Class: {class_names[y_train[i][0]]}')
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
# Convert pixel values data type to float32
X_train = X_train.astype('float32')
X_test  = X_test.astype('float32')
X_valid = X_valid.astype('float32')

# Calculate the mean and standard deviation of the training images
mean = np.mean(X_train)
std  = np.std(X_train)

# Normalize the data
# The tiny value 1e-7 is added to prevent division by zero
X_train = (X_train-mean)/(std+1e-7)
X_test  = (X_test-mean) /(std+1e-7)
X_valid = (X_valid-mean)/(std+1e-7)

# %%
# One-hot encoding of labels
y_train = to_categorical(y_train, 10)
y_valid = to_categorical(y_valid, 10)
y_test  = to_categorical(y_test, 10)

# %% [markdown]
# # Data Augmentation
#
# Rotation:
#
# Source: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0
#
# Horizontal Flip:
#
# Source: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0
#
# Brightness:
#
# Source: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0
#
# Zoom:
#
# Source: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0
#
# Shearing:
#
# Source: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0
#
# Future work. Try:
# * Patch Suffle Regularization
# * Sample Pairing
# * Random Erasing

# %%
# Data augmentation
data_generator = ImageDataGenerator(
    # Rotate images randomly by up to 15 degrees
    rotation_range=15,
    # Randomly flip images horizontally
    horizontal_flip=True,
    # Shift images horizontally by up to 12% of their width
    width_shift_range=0.12,
    # Shift images vertically by up to 12% of their height
    height_shift_range=0.12,
    # Zoom images in by up to 10%
    zoom_range=0.1,
    # Change brightness by up to 10%
    brightness_range=[0.9,1.1],
    # Shear intensity (shear angle in counter-clockwise direction in degrees)
    shear_range=10,
    # Channel shift intensity
    channel_shift_range=0.1,
)

# %% [markdown]
# Using mixed precision training (FP16) which can significantly speed up training on modern GPUs

# %%
# Enable mixed precision training
tf.keras.mixed_precision.set_global_policy('mixed_float16')

# %% [markdown]
# Building the VGG16 inspired model
#
# Source: https://www.kaggle.com/code/farzadnekouei/cifar-10-image-classification-with-cnn

# %%
# Initialize a sequential model
model = Sequential()

# Set the weight decay value for L2 regularization
weight_decay = 0.0001

# Add the first convolutional layer with 32 filters of size 3x3
model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay), 
                 input_shape=X_train.shape[1:]))
# Add batch normalization layer
model.add(BatchNormalization())

# Add the second convolutional layer similar to the first
model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the first max pooling layer with pool size of 2x2
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add dropout layer with 0.2 dropout rate
model.add(Dropout(rate=0.2))

# Add the third and fourth convolutional layers with 64 filters
model.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))   
model.add(BatchNormalization())
model.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the second max pooling layer and increase dropout rate to 0.3
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.3))

# Add the fifth and sixth convolutional layers with 128 filters
model.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay))) 
model.add(BatchNormalization())
model.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the third max pooling layer and increase dropout rate to 0.4
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.4))

# Add the seventh and eighth convolutional layers with 256 filters
model.add(Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay))) 
model.add(BatchNormalization())
model.add(Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the fourth max pooling layer and increase dropout rate to 0.5
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.5))

# Flatten the tensor output from the previous layer
model.add(Flatten())

# Add a fully connected layer with softmax activation function for outputting class probabilities
model.add(Dense(10, activation='softmax'))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-04-13 13:06:00.687360: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Pro
# 2025-04-13 13:06:00.687380: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-04-13 13:06:00.687392: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2025-04-13 13:06:00.687409: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-04-13 13:06:00.687420: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 4, 4, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 4, 4, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 4, 4, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 4, 4, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 2, 2, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 2, 2, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │        10,250 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,186,346 (4.53 MB)
#  Trainable params: 1,184,426 (4.52 MB)
#  Non-trainable params: 1,920 (7.50 KB)

# %%
# Set the batch size for the training
batch_size = 64

# Set the maximum number of epochs for the training
epochs = 300

# Define the optimizer (Adam)
optimizer = Adam(learning_rate=0.0005)

# Compile the model with the defined optimizer, loss function, and metrics
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Add ReduceLROnPlateau callback
# Here, the learning rate will be reduced by half (factor=0.5) if no improvement in validation loss is observed for 10 epochs
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=0.00001)

# Add EarlyStopping callback
# Here, training will be stopped if no improvement in validation loss is observed for 40 epochs.
# The `restore_best_weights` parameter ensures that the model weights are reset to the values from the epoch
# with the best value of the monitored quantity (in this case, 'val_loss').
early_stopping = EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True, verbose=1)

# Fit the model on the training data, using the defined batch size and number of epochs
# The validation data is used to evaluate the model's performance during training
# The callbacks implemented are learning rate reduction when a plateau is reached in validation loss and
# stopping training early if no improvement is observed
model.fit(data_generator.flow(X_train, y_train, batch_size=batch_size),
          epochs=epochs,
          validation_data=(X_valid, y_valid),
          callbacks=[reduce_lr, early_stopping], 
          verbose=2)
# Out:
# Epoch 1/300
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2025-04-13 13:06:02.275794: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 665/665 - 42s - 63ms/step - accuracy: 0.3295 - loss: 2.3986 - val_accuracy: 0.4536 - val_loss: 1.7535 - learning_rate: 5.0000e-04
# Epoch 2/300
# 665/665 - 36s - 54ms/step - accuracy: 0.4514 - loss: 1.7760 - val_accuracy: 0.5179 - val_loss: 1.4790 - learning_rate: 5.0000e-04
# Epoch 3/300
# 665/665 - 37s - 55ms/step - accuracy: 0.5092 - loss: 1.5813 - val_accuracy: 0.5491 - val_loss: 1.3847 - learning_rate: 5.0000e-04
# Epoch 4/300
# 665/665 - 37s - 56ms/step - accuracy: 0.5594 - loss: 1.4572 - val_accuracy: 0.5948 - val_loss: 1.2983 - learning_rate: 5.0000e-04
# Epoch 5/300
# 665/665 - 37s - 56ms/step - accuracy: 0.5753 - loss: 1.4086 - val_accuracy: 0.6153 - val_loss: 1.2301 - learning_rate: 5.0000e-04
# Epoch 6/300
# 665/665 - 37s - 56ms/step - accuracy: 0.5940 - loss: 1.3777 - val_accuracy: 0.6512 - val_loss: 1.1150 - learning_rate: 5.0000e-04
# Epoch 7/300
# 665/665 - 37s - 56ms/step - accuracy: 0.6154 - loss: 1.3338 - val_accuracy: 0.6171 - val_loss: 1.2475 - learning_rate: 5.0000e-04
# Epoch 8/300
# 665/665 - 37s - 56ms/step - accuracy: 0.6205 - loss: 1.3304 - val_accuracy: 0.6284 - val_loss: 1.4096 - learning_rate: 5.0000e-04
# Epoch 9/300
# 665/665 - 37s - 56ms/step - accuracy: 0.6409 - loss: 1.2660 - val_accuracy: 0.7197 - val_loss: 0.9446 - learning_rate: 5.0000e-04
# Epoch 10/300
# 665/665 - 37s - 56ms/step - accuracy: 0.6509 - loss: 1.2585 - val_accuracy: 0.6821 - val_loss: 1.0583 - learning_rate: 5.0000e-04
# Epoch 11/300
# 665/665 - 38s - 56ms/step - accuracy: 0.6546 - loss: 1.2254 - val_accuracy: 0.7185 - val_loss: 0.9672 - learning_rate: 5.0000e-04
# Epoch 12/300
# 665/665 - 37s - 56ms/step - accuracy: 0.6784 - loss: 1.1554 - val_accuracy: 0.6837 - val_loss: 1.1118 - learning_rate: 5.0000e-04
# Epoch 13/300
# 665/665 - 37s - 56ms/step - accuracy: 0.6828 - loss: 1.1535 - val_accuracy: 0.7396 - val_loss: 0.9405 - learning_rate: 5.0000e-04
# Epoch 14/300
# 665/665 - 37s - 56ms/step - accuracy: 0.7033 - loss: 1.0794 - val_accuracy: 0.7527 - val_loss: 0.9128 - learning_rate: 5.0000e-04
# Epoch 15/300
# 665/665 - 37s - 56ms/step - accuracy: 0.7045 - loss: 1.0906 - val_accuracy: 0.7260 - val_loss: 0.9891 - learning_rate: 5.0000e-04
# Epoch 16/300
# 665/665 - 37s - 56ms/step - accuracy: 0.7079 - loss: 1.0988 - val_accuracy: 0.7179 - val_loss: 1.0040 - learning_rate: 5.0000e-04
# Epoch 17/300
# 665/665 - 37s - 56ms/step - accuracy: 0.7095 - loss: 1.0881 - val_accuracy: 0.7712 - val_loss: 0.9154 - learning_rate: 5.0000e-04
# Epoch 18/300
# 665/665 - 37s - 56ms/step - accuracy: 0.7182 - loss: 1.0534 - val_accuracy: 0.7481 - val_loss: 0.9347 - learning_rate: 5.0000e-04
# Epoch 19/300
# 665/665 - 37s - 56ms/step - accuracy: 0.7286 - loss: 1.0436 - val_accuracy: 0.7613 - val_loss: 0.9263 - learning_rate: 5.0000e-04
# Epoch 20/300
# 665/665 - 37s - 56ms/step - accuracy: 0.7282 - loss: 1.0233 - val_accuracy: 0.7700 - val_loss: 0.8797 - learning_rate: 5.0000e-04
# Epoch 21/300
# 665/665 - 37s - 56ms/step - accuracy: 0.7402 - loss: 0.9991 - val_accuracy: 0.7671 - val_loss: 0.9104 - learning_rate: 5.0000e-04
# Epoch 22/300
# 665/665 - 37s - 56ms/step - accuracy: 0.7450 - loss: 0.9899 - val_accuracy: 0.7976 - val_loss: 0.8279 - learning_rate: 5.0000e-04
# Epoch 23/300
# 665/665 - 37s - 56ms/step - accuracy: 0.7497 - loss: 0.9652 - val_accuracy: 0.7883 - val_loss: 0.8497 - learning_rate: 5.0000e-04
# Epoch 24/300
# 665/665 - 37s - 56ms/step - accuracy: 0.7532 - loss: 0.9462 - val_accuracy: 0.8007 - val_loss: 0.8119 - learning_rate: 5.0000e-04
# Epoch 25/300
# 665/665 - 37s - 56ms/step - accuracy: 0.7561 - loss: 0.9415 - val_accuracy: 0.8001 - val_loss: 0.8099 - learning_rate: 5.0000e-04
# Epoch 26/300
# 665/665 - 37s - 56ms/step - accuracy: 0.7620 - loss: 0.9344 - val_accuracy: 0.8087 - val_loss: 0.7913 - learning_rate: 5.0000e-04
# Epoch 27/300
# 665/665 - 37s - 55ms/step - accuracy: 0.7632 - loss: 0.9231 - val_accuracy: 0.8061 - val_loss: 0.8197 - learning_rate: 5.0000e-04
# Epoch 28/300
# 665/665 - 37s - 55ms/step - accuracy: 0.7614 - loss: 0.9367 - val_accuracy: 0.7996 - val_loss: 0.8097 - learning_rate: 5.0000e-04
# Epoch 29/300
# 665/665 - 37s - 55ms/step - accuracy: 0.7695 - loss: 0.8983 - val_accuracy: 0.8289 - val_loss: 0.7264 - learning_rate: 5.0000e-04
# Epoch 30/300
# 665/665 - 37s - 55ms/step - accuracy: 0.
300
# 665/665 - 37s - 55ms/step - accuracy: 0.8609 - loss: 0.5724 - val_accuracy: 0.8692 - val_loss: 0.5571 - learning_rate: 2.5000e-04
# Epoch 80/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8591 - loss: 0.5791 - val_accuracy: 0.8676 - val_loss: 0.5697 - learning_rate: 2.5000e-04
# Epoch 81/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8584 - loss: 0.5765 - val_accuracy: 0.8677 - val_loss: 0.5593 - learning_rate: 2.5000e-04
# Epoch 82/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8573 - loss: 0.5776 - val_accuracy: 0.8692 - val_loss: 0.5639 - learning_rate: 2.5000e-04
# Epoch 83/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8619 - loss: 0.5680 - val_accuracy: 0.8776 - val_loss: 0.5232 - learning_rate: 2.5000e-04
# Epoch 84/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8580 - loss: 0.5728 - val_accuracy: 0.8753 - val_loss: 0.5330 - learning_rate: 2.5000e-04
# Epoch 85/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8612 - loss: 0.5647 - val_accuracy: 0.8687 - val_loss: 0.5577 - learning_rate: 2.5000e-04
# Epoch 86/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8597 - loss: 0.5728 - val_accuracy: 0.8728 - val_loss: 0.5483 - learning_rate: 2.5000e-04
# Epoch 87/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8640 - loss: 0.5634 - val_accuracy: 0.8799 - val_loss: 0.5307 - learning_rate: 2.5000e-04
# Epoch 88/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8631 - loss: 0.5614 - val_accuracy: 0.8696 - val_loss: 0.5540 - learning_rate: 2.5000e-04
# Epoch 89/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8652 - loss: 0.5530 - val_accuracy: 0.8728 - val_loss: 0.5451 - learning_rate: 2.5000e-04
# Epoch 90/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8607 - loss: 0.5673 - val_accuracy: 0.8757 - val_loss: 0.5429 - learning_rate: 2.5000e-04
# Epoch 91/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8664 - loss: 0.5502 - val_accuracy: 0.8769 - val_loss: 0.5291 - learning_rate: 2.5000e-04
# Epoch 92/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8637 - loss: 0.5566 - val_accuracy: 0.8737 - val_loss: 0.5484 - learning_rate: 2.5000e-04
# Epoch 93/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8646 - loss: 0.5560 - val_accuracy: 0.8804 - val_loss: 0.5204 - learning_rate: 2.5000e-04
# Epoch 94/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8666 - loss: 0.5504 - val_accuracy: 0.8757 - val_loss: 0.5324 - learning_rate: 2.5000e-04
# Epoch 95/300
# 665/665 - 37s - 56ms/step - accuracy: 0.8654 - loss: 0.5510 - val_accuracy: 0.8803 - val_loss: 0.5276 - learning_rate: 2.5000e-04
# Epoch 96/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8657 - loss: 0.5501 - val_accuracy: 0.8803 - val_loss: 0.5232 - learning_rate: 2.5000e-04
# Epoch 97/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8671 - loss: 0.5474 - val_accuracy: 0.8761 - val_loss: 0.5291 - learning_rate: 2.5000e-04
# Epoch 98/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8663 - loss: 0.5530 - val_accuracy: 0.8793 - val_loss: 0.5184 - learning_rate: 2.5000e-04
# Epoch 99/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8685 - loss: 0.5464 - val_accuracy: 0.8788 - val_loss: 0.5205 - learning_rate: 2.5000e-04
# Epoch 100/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8708 - loss: 0.5420 - val_accuracy: 0.8700 - val_loss: 0.5632 - learning_rate: 2.5000e-04
# Epoch 101/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8683 - loss: 0.5425 - val_accuracy: 0.8756 - val_loss: 0.5406 - learning_rate: 2.5000e-04
# Epoch 102/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8710 - loss: 0.5366 - val_accuracy: 0.8684 - val_loss: 0.5602 - learning_rate: 2.5000e-04
# Epoch 103/300
# 665/665 - 37s - 55ms/step - accuracy: 0.
300
# 665/665 - 38s - 57ms/step - accuracy: 0.8787 - loss: 0.5171 - val_accuracy: 0.8795 - val_loss: 0.5315 - learning_rate: 2.5000e-04
# Epoch 129/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8772 - loss: 0.5130 - val_accuracy: 0.8895 - val_loss: 0.5005 - learning_rate: 2.5000e-04
# Epoch 130/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8789 - loss: 0.5103 - val_accuracy: 0.8881 - val_loss: 0.4880 - learning_rate: 2.5000e-04
# Epoch 131/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8781 - loss: 0.5112 - val_accuracy: 0.8784 - val_loss: 0.5332 - learning_rate: 2.5000e-04
# Epoch 132/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8768 - loss: 0.5154 - val_accuracy: 0.8772 - val_loss: 0.5301 - learning_rate: 2.5000e-04
# Epoch 133/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8821 - loss: 0.5038 - val_accuracy: 0.8893 - val_loss: 0.4870 - learning_rate: 2.5000e-04
# Epoch 134/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8795 - loss: 0.5105 - val_accuracy: 0.8863 - val_loss: 0.4995 - learning_rate: 2.5000e-04
# Epoch 135/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8795 - loss: 0.5041 - val_accuracy: 0.8799 - val_loss: 0.5241 - learning_rate: 2.5000e-04
# Epoch 136/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8808 - loss: 0.5050 - val_accuracy: 0.8849 - val_loss: 0.5068 - learning_rate: 2.5000e-04
# Epoch 137/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8796 - loss: 0.5074 - val_accuracy: 0.8809 - val_loss: 0.5292 - learning_rate: 2.5000e-04
# Epoch 138/300
# 665/665 - 38s - 56ms/step - accuracy: 0.8806 - loss: 0.5091 - val_accuracy: 0.8771 - val_loss: 0.5335 - learning_rate: 2.5000e-04
# Epoch 139/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8798 - loss: 0.5102 - val_accuracy: 0.8821 - val_loss: 0.5160 - learning_rate: 2.5000e-04
# Epoch 140/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8838 - loss: 0.4981 - val_accuracy: 0.8853 - val_loss: 0.5016 - learning_rate: 2.5000e-04
# Epoch 141/300
# 665/665 - 38s - 56ms/step - accuracy: 0.8810 - loss: 0.5041 - val_accuracy: 0.8681 - val_loss: 0.5623 - learning_rate: 2.5000e-04
# Epoch 142/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8786 - loss: 0.5150 - val_accuracy: 0.8832 - val_loss: 0.5211 - learning_rate: 2.5000e-04
# Epoch 143/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8822 - loss: 0.5033 - val_accuracy: 0.8876 - val_loss: 0.4977 - learning_rate: 2.5000e-04
# Epoch 144/300
# 665/665 - 38s - 57ms/step - accuracy: 0.8896 - loss: 0.4824 - val_accuracy: 0.8851 - val_loss: 0.5021 - learning_rate: 1.2500e-04
# Epoch 145/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8915 - loss: 0.4740 - val_accuracy: 0.8939 - val_loss: 0.4730 - learning_rate: 1.2500e-04
# Epoch 146/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8945 - loss: 0.4630 - val_accuracy: 0.8907 - val_loss: 0.4874 - learning_rate: 1.2500e-04
# Epoch 147/300
# 665/665 - 37s - 56ms/step - accuracy: 0.8947 - loss: 0.4606 - val_accuracy: 0.8884 - val_loss: 0.4999 - learning_rate: 1.2500e-04
# Epoch 148/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8949 - loss: 0.4611 - val_accuracy: 0.8896 - val_loss: 0.4887 - learning_rate: 1.2500e-04
# Epoch 149/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8964 - loss: 0.4547 - val_accuracy: 0.8876 - val_loss: 0.4816 - learning_rate: 1.2500e-04
# Epoch 150/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8972 - loss: 0.4501 - val_accuracy: 0.8944 - val_loss: 0.4686 - learning_rate: 1.2500e-04
# Epoch 151/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8972 - loss: 0.4463 - val_accuracy: 0.8939 - val_loss: 0.4649 - learning_rate: 1.2500e-04
# Epoch 152/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8967 - loss: 0.4490 - val_accuracy: 0.8927 - val_loss: 0.4672 - learning_rate: 1.2500e-04
# Epoch 153/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8971 - loss: 0.4496 - val_accuracy: 0.8959 - val_loss: 0.4579 - learning_rate: 1.2500e-04
# Epoch 154/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8989 - loss: 0.4423 - val_accuracy: 0.8907 - val_loss: 0.4772 - learning_rate: 1.2500e-04
# Epoch 155/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8982 - loss: 0.4385 - val_accuracy: 0.8904 - val_loss: 0.4745 - learning_rate: 1.2500e-04
# Epoch 156/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8980 - loss: 0.4407 - val_accuracy: 0.8984 - val_loss: 0.4584 - learning_rate: 1.2500e-04
# Epoch 157/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9022 - loss: 0.4358 - val_accuracy: 0.9016 - val_loss: 0.4420 - learning_rate: 1.2500e-04
# Epoch 158/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9020 - loss: 0.4284 - val_accuracy: 0.8932 - val_loss: 0.4623 - learning_rate: 1.2500e-04
# Epoch 159/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9000 - loss: 0.4355 - val_accuracy: 0.8975 - val_loss: 0.4575 - learning_rate: 1.2500e-04
# Epoch 160/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8983 - loss: 0.4345 - val_accuracy: 0.8937 - val_loss: 0.4730 - learning_rate: 1.2500e-04
# Epoch 161/300
# 665/665 - 37s - 55ms/step - accuracy: 0.8999 - loss: 0.4313 - val_accuracy: 0.8928 - val_loss: 0.4781 - learning_rate: 1.2500e-04
# Epoch 162/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9033 - loss: 0.4233 - val_accuracy: 0.8911 - val_loss: 0.4751 - learning_rate: 1.2500e-04
# Epoch 163/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9037 - loss: 0.4239 - val_accuracy: 0.8963 - val_loss: 0.4666 - learning_rate: 1.2500e-04
# Epoch 164/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9037 - loss: 0.4232 - val_accuracy: 0.8995 - val_loss: 0.4515 - learning_rate: 1.2500e-04
# Epoch 165/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9038 - loss: 0.4217 - val_accuracy: 0.8903 - val_loss: 0.4780 - learning_rate: 1.2500e-04
# Epoch 166/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9015 - loss: 0.4252 - val_accuracy: 0.8925 - val_loss: 0.4687 - learning_rate: 1.2500e-04
# Epoch 167/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9018 - loss: 0.4195 - val_accuracy: 0.8971 - val_loss: 0.4498 - learning_rate: 1.2500e-04
# Epoch 168/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9069 - loss: 0.4062 - val_accuracy: 0.8971 - val_loss: 0.4507 - learning_rate: 6.2500e-05
# Epoch 169/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9073 - loss: 0.4083 - val_accuracy: 0.8980 - val_loss: 0.4633 - learning_rate: 6.2500e-05
# Epoch 170/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9108 - loss: 0.3985 - val_accuracy: 0.8989 - val_loss: 0.4583 - learning_rate: 6.2500e-05
# Epoch 171/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9072 - loss: 0.4035 - val_accuracy: 0.8975 - val_loss: 0.4582 - learning_rate: 6.2500e-05
# Epoch 172/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9106 - loss: 0.3978 - val_accuracy: 0.8981 - val_loss: 0.4494 - learning_rate: 6.2500e-05
# Epoch 173/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9100 - loss: 0.3944 - val_accuracy: 0.9004 - val_loss: 0.4507 - learning_rate: 6.2500e-05
# Epoch 174/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9099 - loss: 0.3943 - val_accuracy: 0.9008 - val_loss: 0.4355 - learning_rate: 6.2500e-05
# Epoch 175/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9099 - loss: 0.3935 - val_accuracy: 0.8977 - val_loss: 0.4535 - learning_rate: 6.2500e-05
# Epoch 176/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9124 - loss: 0.3899 - val_accuracy: 0.8989 - val_loss: 0.4492 - learning_rate: 6.2500e-05
# Epoch 177/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9122 - loss: 0.3904 - val_accuracy: 0.8980 - val_loss: 0.4498 - learning_rate: 6.2500e-05
# Epoch 178/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9132 - loss: 0.3862 - val_accuracy: 0.8959 - val_loss: 0.4532 - learning_rate: 6.2500e-05
# Epoch 179/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9141 - loss: 0.3870 - val_accuracy: 0.8964 - val_loss: 0.4514 - learning_rate: 6.2500e-05
# Epoch 180/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9117 - loss: 0.3849 - val_accuracy: 0.8979 - val_loss: 0.4540 - learning_rate: 6.2500e-05
# Epoch 181/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9129 - loss: 0.3847 - val_accuracy: 0.9007 - val_loss: 0.4339 - learning_rate: 6.2500e-05
# Epoch 182/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9144 - loss: 0.3812 - val_accuracy: 0.8957 - val_loss: 0.4606 - learning_rate: 6.2500e-05
# Epoch 183/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9127 - loss: 0.3849 - val_accuracy: 0.8988 - val_loss: 0.4459 - learning_rate: 6.2500e-05
# Epoch 184/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9147 - loss: 0.3758 - val_accuracy: 0.9004 - val_loss: 0.4377 - learning_rate: 6.2500e-05
# Epoch 185/300
# 665/665 - 37s - 56ms/step - accuracy: 0.9140 - loss: 0.3803 - val_accuracy: 0.8991 - val_loss: 0.4471 - learning_rate: 6.2500e-05
# Epoch 186/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9142 - loss: 0.3795 - val_accuracy: 0.8987 - val_loss: 0.4479 - learning_rate: 6.2500e-05
# Epoch 187/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9136 - loss: 0.3811 - val_accuracy: 0.9035 - val_loss: 0.4306 - learning_rate: 6.2500e-05
# Epoch 188/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9127 - loss: 0.3774 - val_accuracy: 0.9043 - val_loss: 0.4352 - learning_rate: 6.2500e-05
# Epoch 189/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9137 - loss: 0.3795 - val_accuracy: 0.8989 - val_loss: 0.4455 - learning_rate: 6.2500e-05
# Epoch 190/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9136 - loss: 0.3750 - val_accuracy: 0.9000 - val_loss: 0.4390 - learning_rate: 6.2500e-05
# Epoch 191/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9160 - loss: 0.3713 - val_accuracy: 0.9003 - val_loss: 0.4406 - learning_rate: 6.2500e-05
# Epoch 192/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9154 - loss: 0.3738 - val_accuracy: 0.8961 - val_loss: 0.4479 - learning_rate: 6.2500e-05
# Epoch 193/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9161 - loss: 0.3713 - val_accuracy: 0.9017 - val_loss: 0.4412 - learning_rate: 6.2500e-05
# Epoch 194/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9153 - loss: 0.3727 - val_accuracy: 0.9003 - val_loss: 0.4340 - learning_rate: 6.2500e-05
# Epoch 195/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9164 - loss: 0.3660 - val_accuracy: 0.8996 - val_loss: 0.4459 - learning_rate: 6.2500e-05
# Epoch 196/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9174 - loss: 0.3663 - val_accuracy: 0.8988 - val_loss: 0.4413 - learning_rate: 6.2500e-05
# Epoch 197/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9177 - loss: 0.3648 - val_accuracy: 0.8989 - val_loss: 0.4349 - learning_rate: 6.2500e-05
# Epoch 198/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9184 - loss: 0.3647 - val_accuracy: 0.9040 - val_loss: 0.4216 - learning_rate: 3.1250e-05
# Epoch 199/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9164 - loss: 0.3620 - val_accuracy: 0.9011 - val_loss: 0.4362 - learning_rate: 3.1250e-05
# Epoch 200/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9198 - loss: 0.3549 - val_accuracy: 0.9013 - val_loss: 0.4339 - learning_rate: 3.1250e-05
# Epoch 201/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9206 - loss: 0.3565 - val_accuracy: 0.9047 - val_loss: 0.4236 - learning_rate: 3.1250e-05
# Epoch 202/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9173 - loss: 0.3632 - val_accuracy: 0.9016 - val_loss: 0.4278 - learning_rate: 3.1250e-05
# Epoch 203/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9223 - loss: 0.3519 - val_accuracy: 0.9013 - val_loss: 0.4376 - learning_rate: 3.1250e-05
# Epoch 204/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9227 - loss: 0.3501 - val_accuracy: 0.9032 - val_loss: 0.4296 - learning_rate: 3.1250e-05
# Epoch 205/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9219 - loss: 0.3488 - val_accuracy: 0.9037 - val_loss: 0.4335 - learning_rate: 3.1250e-05
# Epoch 206/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9199 - loss: 0.3535 - val_accuracy: 0.9041 - val_loss: 0.4283 - learning_rate: 3.1250e-05
# Epoch 207/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9209 - loss: 0.3530 - val_accuracy: 0.9041 - val_loss: 0.4340 - learning_rate: 3.1250e-05
# Epoch 208/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9204 - loss: 0.3502 - val_accuracy: 0.9024 - val_loss: 0.4355 - learning_rate: 3.1250e-05
# Epoch 209/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9230 - loss: 0.3445 - val_accuracy: 0.9025 - val_loss: 0.4347 - learning_rate: 1.5625e-05
# Epoch 210/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9220 - loss: 0.3478 - val_accuracy: 0.9020 - val_loss: 0.4332 - learning_rate: 1.5625e-05
# Epoch 211/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9228 - loss: 0.3467 - val_accuracy: 0.9043 - val_loss: 0.4261 - learning_rate: 1.5625e-05
# Epoch 212/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9239 - loss: 0.3446 - val_accuracy: 0.9020 - val_loss: 0.4339 - learning_rate: 1.5625e-05
# Epoch 213/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9248 - loss: 0.3425 - val_accuracy: 0.9024 - val_loss: 0.4267 - learning_rate: 1.5625e-05
# Epoch 214/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9228 - loss: 0.3462 - val_accuracy: 0.9027 - val_loss: 0.4323 - learning_rate: 1.5625e-05
# Epoch 215/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9222 - loss: 0.3448 - val_accuracy: 0.9021 - val_loss: 0.4338 - learning_rate: 1.5625e-05
# Epoch 216/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9250 - loss: 0.3402 - val_accuracy: 0.9045 - val_loss: 0.4253 - learning_rate: 1.5625e-05
# Epoch 217/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9256 - loss: 0.3421 - val_accuracy: 0.9043 - val_loss: 0.4282 - learning_rate: 1.5625e-05
# Epoch 218/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9248 - loss: 0.3398 - val_accuracy: 0.9049 - val_loss: 0.4245 - learning_rate: 1.5625e-05
# Epoch 219/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9240 - loss: 0.3412 - val_accuracy: 0.9072 - val_loss: 0.4193 - learning_rate: 1.0000e-05
# Epoch 220/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9235 - loss: 0.3424 - val_accuracy: 0.9055 - val_loss: 0.4296 - learning_rate: 1.0000e-05
# Epoch 221/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9220 - loss: 0.3440 - val_accuracy: 0.9035 - val_loss: 0.4313 - learning_rate: 1.0000e-05
# Epoch 222/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9250 - loss: 0.3404 - val_accuracy: 0.9039 - val_loss: 0.4291 - learning_rate: 1.0000e-05
# Epoch 223/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9249 - loss: 0.3388 - val_accuracy: 0.9043 - val_loss: 0.4282 - learning_rate: 1.0000e-05
# Epoch 224/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9259 - loss: 0.3350 - val_accuracy: 0.9036 - val_loss: 0.4317 - learning_rate: 1.0000e-05
# Epoch 225/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9258 - loss: 0.3350 - val_accuracy: 0.9043 - val_loss: 0.4277 - learning_rate: 1.0000e-05
# Epoch 226/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9251 - loss: 0.3390 - val_accuracy: 0.9052 - val_loss: 0.4276 - learning_rate: 1.0000e-05
# Epoch 227/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9241 - loss: 0.3406 - val_accuracy: 0.9035 - val_loss: 0.4283 - learning_rate: 1.0000e-05
# Epoch 228/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9250 - loss: 0.3393 - val_accuracy: 0.9049 - val_loss: 0.4282 - learning_rate: 1.0000e-05
# Epoch 229/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9243 - loss: 0.3383 - val_accuracy: 0.9047 - val_loss: 0.4273 - learning_rate: 1.0000e-05
# Epoch 230/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9267 - loss: 0.3346 - val_accuracy: 0.9040 - val_loss: 0.4292 - learning_rate: 1.0000e-05
# Epoch 231/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9264 - loss: 0.3371 - val_accuracy: 0.9024 - val_loss: 0.4297 - learning_rate: 1.0000e-05
# Epoch 232/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9258 - loss: 0.3359 - val_accuracy: 0.9039 - val_loss: 0.4261 - learning_rate: 1.0000e-05
# Epoch 233/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9247 - loss: 0.3374 - val_accuracy: 0.9052 - val_loss: 0.4232 - learning_rate: 1.0000e-05
# Epoch 234/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9251 - loss: 0.3372 - val_accuracy: 0.9039 - val_loss: 0.4256 - learning_rate: 1.0000e-05
# Epoch 235/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9284 - loss: 0.3302 - val_accuracy: 0.9052 - val_loss: 0.4212 - learning_rate: 1.0000e-05
# Epoch 236/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9264 - loss: 0.3342 - val_accuracy: 0.9040 - val_loss: 0.4238 - learning_rate: 1.0000e-05
# Epoch 237/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9250 - loss: 0.3359 - val_accuracy: 0.9048 - val_loss: 0.4243 - learning_rate: 1.0000e-05
# Epoch 238/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9268 - loss: 0.3326 - val_accuracy: 0.9031 - val_loss: 0.4267 - learning_rate: 1.0000e-05
# Epoch 239/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9247 - loss: 0.3343 - val_accuracy: 0.9035 - val_loss: 0.4237 - learning_rate: 1.0000e-05
# Epoch 240/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9270 - loss: 0.3287 - val_accuracy: 0.9036 - val_loss: 0.4266 - learning_rate: 1.0000e-05
# Epoch 241/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9284 - loss: 0.3282 - val_accuracy: 0.9033 - val_loss: 0.4245 - learning_rate: 1.0000e-05
# Epoch 242/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9268 - loss: 0.3335 - val_accuracy: 0.9053 - val_loss: 0.4216 - learning_rate: 1.0000e-05
# Epoch 243/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9278 - loss: 0.3312 - val_accuracy: 0.9048 - val_loss: 0.4273 - learning_rate: 1.0000e-05
# Epoch 244/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9253 - loss: 0.3339 - val_accuracy: 0.9044 - val_loss: 0.4264 - learning_rate: 1.0000e-05
# Epoch 245/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9258 - loss: 0.3353 - val_accuracy: 0.9067 - val_loss: 0.4192 - learning_rate: 1.0000e-05
# Epoch 246/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9279 - loss: 0.3303 - val_accuracy: 0.9043 - val_loss: 0.4224 - learning_rate: 1.0000e-05
# Epoch 247/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9272 - loss: 0.3331 - val_accuracy: 0.9045 - val_loss: 0.4209 - learning_rate: 1.0000e-05
# Epoch 248/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9257 - loss: 0.3317 - val_accuracy: 0.9043 - val_loss: 0.4276 - learning_rate: 1.0000e-05
# Epoch 249/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9264 - loss: 0.3285 - val_accuracy: 0.9045 - val_loss: 0.4266 - learning_rate: 1.0000e-05
# Epoch 250/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9267 - loss: 0.3333 - val_accuracy: 0.9045 - val_loss: 0.4226 - learning_rate: 1.0000e-05
# Epoch 251/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9262 - loss: 0.3329 - val_accuracy: 0.9051 - val_loss: 0.4236 - learning_rate: 1.0000e-05
# Epoch 252/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9281 - loss: 0.3301 - val_accuracy: 0.9032 - val_loss: 0.4282 - learning_rate: 1.0000e-05
# Epoch 253/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9272 - loss: 0.3310 - val_accuracy: 0.9040 - val_loss: 0.4267 - learning_rate: 1.0000e-05
# Epoch 254/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9272 - loss: 0.3304 - val_accuracy: 0.9045 - val_loss: 0.4223 - learning_rate: 1.0000e-05
# Epoch 255/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9271 - loss: 0.3311 - val_accuracy: 0.9039 - val_loss: 0.4220 - learning_rate: 1.0000e-05
# Epoch 256/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9290 - loss: 0.3249 - val_accuracy: 0.9029 - val_loss: 0.4222 - learning_rate: 1.0000e-05
# Epoch 257/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9273 - loss: 0.3266 - val_accuracy: 0.9040 - val_loss: 0.4194 - learning_rate: 1.0000e-05
# Epoch 258/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9271 - loss: 0.3322 - val_accuracy: 0.9041 - val_loss: 0.4263 - learning_rate: 1.0000e-05
# Epoch 259/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9283 - loss: 0.3273 - val_accuracy: 0.9041 - val_loss: 0.4229 - learning_rate: 1.0000e-05
# Epoch 260/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9272 - loss: 0.3296 - val_accuracy: 0.9047 - val_loss: 0.4208 - learning_rate: 1.0000e-05
# Epoch 261/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9267 - loss: 0.3316 - val_accuracy: 0.9037 - val_loss: 0.4205 - learning_rate: 1.0000e-05
# Epoch 262/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9288 - loss: 0.3230 - val_accuracy: 0.9036 - val_loss: 0.4257 - learning_rate: 1.0000e-05
# Epoch 263/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9257 - loss: 0.3321 - val_accuracy: 0.9035 - val_loss: 0.4254 - learning_rate: 1.0000e-05
# Epoch 264/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9256 - loss: 0.3318 - val_accuracy: 0.9044 - val_loss: 0.4223 - learning_rate: 1.0000e-05
# Epoch 265/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9280 - loss: 0.3287 - val_accuracy: 0.9024 - val_loss: 0.4252 - learning_rate: 1.0000e-05
# Epoch 266/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9286 - loss: 0.3228 - val_accuracy: 0.9033 - val_loss: 0.4288 - learning_rate: 1.0000e-05
# Epoch 267/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9279 - loss: 0.3268 - val_accuracy: 0.9039 - val_loss: 0.4248 - learning_rate: 1.0000e-05
# Epoch 268/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9280 - loss: 0.3251 - val_accuracy: 0.9053 - val_loss: 0.4241 - learning_rate: 1.0000e-05
# Epoch 269/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9280 - loss: 0.3233 - val_accuracy: 0.9045 - val_loss: 0.4283 - learning_rate: 1.0000e-05
# Epoch 270/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9281 - loss: 0.3244 - val_accuracy: 0.9041 - val_loss: 0.4258 - learning_rate: 1.0000e-05
# Epoch 271/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9300 - loss: 0.3205 - val_accuracy: 0.9041 - val_loss: 0.4276 - learning_rate: 1.0000e-05
# Epoch 272/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9275 - loss: 0.3266 - val_accuracy: 0.9029 - val_loss: 0.4245 - learning_rate: 1.0000e-05
# Epoch 273/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9281 - loss: 0.3258 - val_accuracy: 0.9032 - val_loss: 0.4219 - learning_rate: 1.0000e-05
# Epoch 274/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9276 - loss: 0.3237 - val_accuracy: 0.9029 - val_loss: 0.4240 - learning_rate: 1.0000e-05
# Epoch 275/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9291 - loss: 0.3231 - val_accuracy: 0.9057 - val_loss: 0.4172 - learning_rate: 1.0000e-05
# Epoch 276/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9289 - loss: 0.3212 - val_accuracy: 0.9055 - val_loss: 0.4193 - learning_rate: 1.0000e-05
# Epoch 277/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9284 - loss: 0.3219 - val_accuracy: 0.9059 - val_loss: 0.4204 - learning_rate: 1.0000e-05
# Epoch 278/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9284 - loss: 0.3259 - val_accuracy: 0.9052 - val_loss: 0.4217 - learning_rate: 1.0000e-05
# Epoch 279/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9304 - loss: 0.3214 - val_accuracy: 0.9059 - val_loss: 0.4196 - learning_rate: 1.0000e-05
# Epoch 280/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9284 - loss: 0.3223 - val_accuracy: 0.9053 - val_loss: 0.4218 - learning_rate: 1.0000e-05
# Epoch 281/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9283 - loss: 0.3218 - val_accuracy: 0.9039 - val_loss: 0.4261 - learning_rate: 1.0000e-05
# Epoch 282/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9297 - loss: 0.3232 - val_accuracy: 0.9051 - val_loss: 0.4250 - learning_rate: 1.0000e-05
# Epoch 283/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9290 - loss: 0.3211 - val_accuracy: 0.9037 - val_loss: 0.4254 - learning_rate: 1.0000e-05
# Epoch 284/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9284 - loss: 0.3229 - val_accuracy: 0.9043 - val_loss: 0.4224 - learning_rate: 1.0000e-05
# Epoch 285/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9288 - loss: 0.3245 - val_accuracy: 0.9057 - val_loss: 0.4219 - learning_rate: 1.0000e-05
# Epoch 286/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9281 - loss: 0.3254 - val_accuracy: 0.9051 - val_loss: 0.4247 - learning_rate: 1.0000e-05
# Epoch 287/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9297 - loss: 0.3176 - val_accuracy: 0.9075 - val_loss: 0.4196 - learning_rate: 1.0000e-05
# Epoch 288/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9291 - loss: 0.3215 - val_accuracy: 0.9059 - val_loss: 0.4242 - learning_rate: 1.0000e-05
# Epoch 289/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9298 - loss: 0.3190 - val_accuracy: 0.9056 - val_loss: 0.4209 - learning_rate: 1.0000e-05
# Epoch 290/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9306 - loss: 0.3195 - val_accuracy: 0.9053 - val_loss: 0.4228 - learning_rate: 1.0000e-05
# Epoch 291/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9286 - loss: 0.3211 - val_accuracy: 0.9049 - val_loss: 0.4198 - learning_rate: 1.0000e-05
# Epoch 292/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9288 - loss: 0.3211 - val_accuracy: 0.9039 - val_loss: 0.4220 - learning_rate: 1.0000e-05
# Epoch 293/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9285 - loss: 0.3218 - val_accuracy: 0.9047 - val_loss: 0.4221 - learning_rate: 1.0000e-05
# Epoch 294/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9296 - loss: 0.3211 - val_accuracy: 0.9037 - val_loss: 0.4215 - learning_rate: 1.0000e-05
# Epoch 295/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9295 - loss: 0.3205 - val_accuracy: 0.9043 - val_loss: 0.4226 - learning_rate: 1.0000e-05
# Epoch 296/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9292 - loss: 0.3199 - val_accuracy: 0.9040 - val_loss: 0.4208 - learning_rate: 1.0000e-05
# Epoch 297/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9294 - loss: 0.3166 - val_accuracy: 0.9037 - val_loss: 0.4251 - learning_rate: 1.0000e-05
# Epoch 298/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9306 - loss: 0.3133 - val_accuracy: 0.9037 - val_loss: 0.4266 - learning_rate: 1.0000e-05
# Epoch 299/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9286 - loss: 0.3187 - val_accuracy: 0.9041 - val_loss: 0.4260 - learning_rate: 1.0000e-05
# Epoch 300/300
# 665/665 - 37s - 55ms/step - accuracy: 0.9287 - loss: 0.3202 - val_accuracy: 0.9049 - val_loss: 0.4263 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 275.

# %%
plt.figure(figsize=(15,6))

# Plotting the training and validation loss
plt.subplot(1, 2, 1)
plt.plot(model.history.history['loss'], label='Train Loss', color='#8502d1')
plt.plot(model.history.history['val_loss'], label='Validation Loss', color='darkorange')
plt.legend()
plt.title('Loss Evolution')

# Plotting the training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(model.history.history['accuracy'], label='Train Accuracy', color='#8502d1')
plt.plot(model.history.history['val_accuracy'], label='Validation Accuracy', color='darkorange')
plt.legend()
plt.title('Accuracy Evolution')

plt.show()

# %%
# Use the model to make predictions, evaluate on test data
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=1)

print('\nTest Accuracy:', test_acc)
print('Test Loss:    ', test_loss)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9012 - loss: 0.4509
#
# Test Accuracy: 0.9010999798774719
# Test Loss:     0.4514664113521576

# %%
# Convert GitHub URL to raw URL
url = "https://raw.github.com/gameiro33/eportolio/f34dafd3857f6ae71e6be02a87ea7da48fdc98ba/frog_image.png"

resp = urllib.request.urlopen(url)
image = np.asarray(bytearray(resp.read()), dtype="uint8")
image = cv2.imdecode(image, cv2.IMREAD_UNCHANGED)

# Convert the image from BGR to RGB
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
# Display the image
plt.imshow(image)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.show()

# %%
# 1. First check the original image
print("Original image shape:", image.shape)

# 2. Resize the image to 32x32 (CIFAR-10 size)
image_resized = cv2.resize(image, (32, 32))
print("After resize shape:", image_resized.shape)
# Out:
# Original image shape: (256, 256, 3)
# After resize shape: (32, 32, 3)

# %%
# Display the image
plt.imshow(image_resized)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.show()

# %%
# 1. First check the original image
print("Original image shape:", image.shape)

# 2. Resize the image to 32x32 (CIFAR-10 size)
image_resized = cv2.resize(image, (32, 32))
print("After resize shape:", image_resized.shape)

# 3. Convert to float32 and normalize
image_normalized = image_resized.astype('float32') / 255.0
print("After normalization shape:", image_normalized.shape)

# 4. Add batch dimension
image_batch = np.expand_dims(image_normalized, axis=0)
print("Final input shape:", image_batch.shape)

# 5. Now make prediction
prediction = model.predict(image_batch)

# 6. Print results
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
predicted_class = class_names[np.argmax(prediction[0])]
print("\nPredicted class:", predicted_class)

# 7. Print all probabilities
print("\nClass probabilities:")
for class_name, prob in zip(class_names, prediction[0]):
    print(f"{class_name}: {prob:.4f}")
# Out:
# Original image shape: (256, 256, 3)
# After resize shape: (32, 32, 3)
# After normalization shape: (32, 32, 3)
# Final input shape: (1, 32, 32, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Predicted class: frog
#
# Class probabilities:
# airplane: 0.0000
# automobile: 0.0000
# bird: 0.0049
# cat: 0.0012
# deer: 0.0021
# dog: 0.0004
# frog: 0.9912
# horse: 0.0003
# ship: 0.0000
# truck: 0.0000

# %%
prediction = model.predict(image_batch)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step

# %%
predicted_class = prediction.argmax()

print('Predicted class: ', class_names[predicted_class])
# Out:
# Predicted class:  frog
