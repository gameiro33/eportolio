# %% [markdown]
# # Import Libraries

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dropout, Flatten, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.models import load_model
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
   # Configure TensorFlow to grow GPU memory allocation as needed
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# %% [markdown]
# Downloading CIFAR 10:

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %% [markdown]
# The standard practice for splitting data into training, validation, and test sets typically follows these guidelines:
# Training Set (60-80%): Used to train the model
# Validation Set (10-20%): Used for hyperparameter tuning and model selection
# Test Set (10-20%): Used for final model evaluation
#
# Since the training and test set are already split in this data set in a 1/6 proportion, we will further carve 10% out of the training set to be used for validation.
#
# Source: https://www.v7labs.com/blog/train-validation-test-set

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.1, random_state=0)

# %%
print('Train Images Shape:      ', X_train.shape)
print('Train Labels Shape:      ', y_train.shape)

print('\nValidation Images Shape: ', X_valid.shape)
print('Validation Labels Shape: ', y_valid.shape)

print('\nTest Images Shape:       ', X_test.shape)
print('Test Labels Shape:       ', y_test.shape)
# Out:
# Train Images Shape:       (45000, 32, 32, 3)
# Train Labels Shape:       (45000, 1)
#
# Validation Images Shape:  (5000, 32, 32, 3)
# Validation Labels Shape:  (5000, 1)
#
# Test Images Shape:        (10000, 32, 32, 3)
# Test Labels Shape:        (10000, 1)

# %%
# Display a 3x3 grid of random images
plt.figure(figsize=(8, 8))

# Define the class names, so that they can be shown in the plot
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# Plot 9 random images from the training set
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.imshow(X_train[i])
    plt.title(f'Class: {class_names[y_train[i][0]]}')
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
# Convert pixel values data type to float32
X_train = X_train.astype('float32')
X_test  = X_test.astype('float32')
X_valid = X_valid.astype('float32')

# Normalize pixel values to be between 0 and 1
X_train = X_train / 255.0
X_test = X_test / 255.0
X_valid = X_valid / 255.0

# Transform target variable into one-hotencoding
y_train = to_categorical(y_train, 10)
y_valid = to_categorical(y_valid, 10)
y_test  = to_categorical(y_test, 10)

# %% [markdown]
# # Data Augmentation
#
# Rotation:
#
# Source: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0
#
# Horizontal Flip:
#
# Source: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0
#
# Future work. Try:
# * Patch Suffle Regularization
# * Sample Pairing
# * Random Erasing

# %%
# Data augmentation
data_generator = ImageDataGenerator(
    # Rotate images randomly by up to 15 degrees
    rotation_range=15,
    
    # Shift images horizontally by up to 12% of their width
    width_shift_range=0.12,
    
    # Shift images vertically by up to 12% of their height
    height_shift_range=0.12,
    
    # Randomly flip images horizontally
    horizontal_flip=True,
    
    # Zoom images in by up to 10%
    zoom_range=0.1,
    
    # Change brightness by up to 10%
    brightness_range=[0.9,1.1],

    # Shear intensity (shear angle in counter-clockwise direction in degrees)
    shear_range=10,
    
    # Channel shift intensity
    channel_shift_range=0.1,
)

# %% [markdown]
# Using mixed precision training (FP16) which can significantly speed up training on modern GPUs

# %%
# Enable mixed precision training
tf.keras.mixed_precision.set_global_policy('mixed_float16')

# %% [markdown]
# Building the VGG16 inspired model
#
# Source: https://www.kaggle.com/code/farzadnekouei/cifar-10-image-classification-with-cnn

# %%
# Initialize a sequential model
model = Sequential()

# Set the weight decay value for L2 regularization
weight_decay = 0.0001

# Add the first convolutional layer with 32 filters of size 3x3
model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay), 
                 input_shape=X_train.shape[1:]))
# Add batch normalization layer
model.add(BatchNormalization())

# Add the second convolutional layer similar to the first
model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the first max pooling layer with pool size of 2x2
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add dropout layer with 0.2 dropout rate
model.add(Dropout(rate=0.2))

# Add the third and fourth convolutional layers with 64 filters
model.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))   
model.add(BatchNormalization())
model.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the second max pooling layer and increase dropout rate to 0.3
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.3))

# Add the fifth and sixth convolutional layers with 128 filters
model.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay))) 
model.add(BatchNormalization())
model.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the third max pooling layer and increase dropout rate to 0.4
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.4))

# Add the seventh and eighth convolutional layers with 256 filters
model.add(Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay))) 
model.add(BatchNormalization())
model.add(Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the fourth max pooling layer and increase dropout rate to 0.5
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.5))

# Flatten the tensor output from the previous layer
model.add(Flatten())

# Add a fully connected layer with softmax activation function for outputting class probabilities
model.add(Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_8 (Conv2D)               │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_12 (Conv2D)              │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 4, 4, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 4, 4, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 4, 4, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 4, 4, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 2, 2, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 2, 2, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │        10,250 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,186,346 (4.53 MB)
#  Trainable params: 1,184,426 (4.52 MB)
#  Non-trainable params: 1,920 (7.50 KB)

# %%
# Set the batch size for the training
batch_size = 64


# Set the maximum number of epochs for the training
epochs = 300

# Define the optimizer (Adam)
optimizer = Adam(learning_rate=0.0005)

# Compile the model with the defined optimizer, loss function, and metrics
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Add ReduceLROnPlateau callback
# Here, the learning rate will be reduced by half (factor=0.5) if no improvement in validation loss is observed for 10 epochs
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=0.00001)

# Add EarlyStopping callback
# Here, training will be stopped if no improvement in validation loss is observed for 40 epochs.
# The `restore_best_weights` parameter ensures that the model weights are reset to the values from the epoch
# with the best value of the monitored quantity (in this case, 'val_loss').
early_stopping = EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True, verbose=1)

train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))\
    .shuffle(1000)\
    .batch(batch_size)\
    .prefetch(tf.data.AUTOTUNE)

valid_ds = tf.data.Dataset.from_tensor_slices((X_valid, y_valid))\
    .batch(batch_size)\
    .prefetch(tf.data.AUTOTUNE)

# Then in model.fit:
model.fit(train_ds,
            epochs=epochs,
            validation_data=valid_ds,
            callbacks=[reduce_lr, early_stopping],
            verbose=2)
# Out:
# Epoch 1/300
# 704/704 - 49s - 70ms/step - accuracy: 0.3799 - loss: 2.1533 - val_accuracy: 0.3688 - val_loss: 1.8886 - learning_rate: 5.0000e-04
# Epoch 2/300
# 704/704 - 41s - 59ms/step - accuracy: 0.5410 - loss: 1.5244 - val_accuracy: 0.5428 - val_loss: 1.3625 - learning_rate: 5.0000e-04
# Epoch 3/300
# 704/704 - 41s - 58ms/step - accuracy: 0.6164 - loss: 1.3019 - val_accuracy: 0.6466 - val_loss: 1.1274 - learning_rate: 5.0000e-04
# Epoch 4/300
# 704/704 - 40s - 57ms/step - accuracy: 0.6611 - loss: 1.1851 - val_accuracy: 0.6754 - val_loss: 1.0532 - learning_rate: 5.0000e-04
# Epoch 5/300
# 704/704 - 40s - 56ms/step - accuracy: 0.6982 - loss: 1.0738 - val_accuracy: 0.7370 - val_loss: 0.9129 - learning_rate: 5.0000e-04
# Epoch 6/300
# 704/704 - 40s - 57ms/step - accuracy: 0.7296 - loss: 1.0047 - val_accuracy: 0.7000 - val_loss: 1.0081 - learning_rate: 5.0000e-04
# Epoch 7/300
# 704/704 - 40s - 56ms/step - accuracy: 0.7267 - loss: 1.0451 - val_accuracy: 0.7642 - val_loss: 0.8593 - learning_rate: 5.0000e-04
# Epoch 8/300
# 704/704 - 41s - 58ms/step - accuracy: 0.7631 - loss: 0.9404 - val_accuracy: 0.7612 - val_loss: 0.8756 - learning_rate: 5.0000e-04
# Epoch 9/300
# 704/704 - 42s - 59ms/step - accuracy: 0.7702 - loss: 0.9212 - val_accuracy: 0.6260 - val_loss: 1.2714 - learning_rate: 5.0000e-04
# Epoch 10/300
# 704/704 - 40s - 56ms/step - accuracy: 0.7682 - loss: 0.9287 - val_accuracy: 0.7806 - val_loss: 0.7929 - learning_rate: 5.0000e-04
# Epoch 11/300
# 704/704 - 41s - 58ms/step - accuracy: 0.7892 - loss: 0.8366 - val_accuracy: 0.7746 - val_loss: 0.8167 - learning_rate: 5.0000e-04
# Epoch 12/300
# 704/704 - 41s - 58ms/step - accuracy: 0.8037 - loss: 0.7770 - val_accuracy: 0.7872 - val_loss: 0.8059 - learning_rate: 5.0000e-04
# Epoch 13/300
# 704/704 - 40s - 57ms/step - accuracy: 0.8113 - loss: 0.7516 - val_accuracy: 0.7748 - val_loss: 0.8993 - learning_rate: 5.0000e-04
# Epoch 14/300
# 704/704 - 41s - 58ms/step - accuracy: 0.8190 - loss: 0.7294 - val_accuracy: 0.8036 - val_loss: 0.7637 - learning_rate: 5.0000e-04
# Epoch 15/300
# 704/704 - 41s - 58ms/step - accuracy: 0.8321 - loss: 0.6936 - val_accuracy: 0.8218 - val_loss: 0.7313 - learning_rate: 5.0000e-04
# Epoch 16/300
# 704/704 - 40s - 57ms/step - accuracy: 0.8374 - loss: 0.6708 - val_accuracy: 0.8088 - val_loss: 0.7625 - learning_rate: 5.0000e-04
# Epoch 17/300
# 704/704 - 40s - 57ms/step - accuracy: 0.8489 - loss: 0.6429 - val_accuracy: 0.8128 - val_loss: 0.7588 - learning_rate: 5.0000e-04
# Epoch 18/300
# 704/704 - 41s - 58ms/step - accuracy: 0.8566 - loss: 0.6204 - val_accuracy: 0.8298 - val_loss: 0.6988 - learning_rate: 5.0000e-04
# Epoch 19/300
# 704/704 - 41s - 58ms/step - accuracy: 0.8566 - loss: 0.6169 - val_accuracy: 0.8280 - val_loss: 0.7219 - learning_rate: 5.0000e-04
# Epoch 20/300
# 704/704 - 40s - 57ms/step - accuracy: 0.8681 - loss: 0.6000 - val_accuracy: 0.8338 - val_loss: 0.7016 - learning_rate: 5.0000e-04
# Epoch 21/300
# 704/704 - 41s - 59ms/step - accuracy: 0.8654 - loss: 0.6066 - val_accuracy: 0.8270 - val_loss: 0.7309 - learning_rate: 5.0000e-04
# Epoch 22/300
# 704/704 - 41s - 59ms/step - accuracy: 0.8756 - loss: 0.5841 - val_accuracy: 0.8306 - val_loss: 0.7292 - learning_rate: 5.0000e-04
# Epoch 23/300
# 704/704 - 43s - 61ms/step - accuracy: 0.8707 - loss: 0.6007 - val_accuracy: 0.8250 - val_loss: 0.7436 - learning_rate: 5.0000e-04
# Epoch 24/300
# 704/704 - 43s - 61ms/step - accuracy: 0.8826 - loss: 0.5687 - val_accuracy: 0.8344 - val_loss: 0.7171 - learning_rate: 5.0000e-04
# Epoch 25/300
# 704/704 - 41s - 58ms/step - accuracy: 0.8875 - loss: 0.5623 - val_accuracy: 0.8220 - val_loss: 0.7691 - learning_rate: 5.0000e-04
# Epoch 26/300
# 704/704 - 40s - 57ms/step - accuracy: 0.8846 - loss: 0.5688 - val_accuracy: 0.8448 - val_loss: 0.7235 - learning_rate: 5.0000e-04
# Epoch 27/300
# 704/704 - 40s - 57ms/step - accuracy: 0.8925 - loss: 0.5535 - val_accuracy: 0.8410 - val_loss: 0.7470 - learning_rate: 5.0000e-04
# Epoch 28/300
# 704/704 - 42s - 59ms/step - accuracy: 0.8939 - loss: 0.5540 - val_accuracy: 0.8372 - val_loss: 0.7481 - learning_rate: 5.0000e-04
# Epoch 29/300
# 704/704 - 41s - 58ms/step - accuracy: 0.9144 - loss: 0.4911 - val_accuracy: 0.8560 - val_loss: 0.7022 - learning_rate: 2.5000e-04
# Epoch 30/300
# 704/704 - 41s - 58ms/step - accuracy: 0.9244 - loss: 0.4564 - val_accuracy: 0.8562 - val_loss: 0.6950 - learning_rate: 2.5000e-04
# Epoch 31/300
# 704/704 - 41s - 58ms/step - accuracy: 0.9273 - loss: 0.4490 - val_accuracy: 0.8562 - val_loss: 0.7016 - learning_rate: 2.5000e-04
# Epoch 32/300
# 704/704 - 41s - 59ms/step - accuracy: 0.9323 - loss: 0.4324 - val_accuracy: 0.8578 - val_loss: 0.6968 - learning_rate: 2.5000e-04
# Epoch 33/300
# 704/704 - 42s - 59ms/step - accuracy: 0.9330 - loss: 0.4211 - val_accuracy: 0.8540 - val_loss: 0.7297 - learning_rate: 2.5000e-04
# Epoch 34/300
# 704/704 - 40s - 57ms/step - accuracy: 0.9349 - loss: 0.4191 - val_accuracy: 0.8568 - val_loss: 0.7032 - learning_rate: 2.5000e-04
# Epoch 35/300
# 704/704 - 40s - 57ms/step - accuracy: 0.9343 - loss: 0.4180 - val_accuracy: 0.8518 - val_loss: 0.7358 - learning_rate: 2.5000e-04
# Epoch 36/300
# 704/704 - 40s - 56ms/step - accuracy: 0.9387 - loss: 0.4000 - val_accuracy: 0.8600 - val_loss: 0.7119 - learning_rate: 2.5000e-04
# Epoch 37/300
# 704/704 - 39s - 56ms/step - accuracy: 0.9391 - loss: 0.3972 - val_accuracy: 0.8556 - val_loss: 0.7209 - learning_rate: 2.5000e-04
# Epoch 38/300
# 704/704 - 40s - 56ms/step - accuracy: 0.9423 - loss: 0.3871 - val_accuracy: 0.8584 - val_loss: 0.7086 - learning_rate: 2.5000e-04
# Epoch 39/300
# 704/704 - 39s - 56ms/step - accuracy: 0.9428 - loss: 0.3848 - val_accuracy: 0.8618 - val_loss: 0.7137 - learning_rate: 2.5000e-04
# Epoch 40/300
# 704/704 - 39s - 56ms/step - accuracy: 0.9447 - loss: 0.3777 - val_accuracy: 0.8618 - val_loss: 0.7015 - learning_rate: 2.5000e-04
# Epoch 41/300
# 704/704 - 40s - 56ms/step - accuracy: 0.9516 - loss: 0.3594 - val_accuracy: 0.8676 - val_loss: 0.6993 - learning_rate: 1.2500e-04
# Epoch 42/300
# 704/704 - 39s - 56ms/step - accuracy: 0.9562 - loss: 0.3418 - val_accuracy: 0.8628 - val_loss: 0.7092 - learning_rate: 1.2500e-04
# Epoch 43/300
# 704/704 - 39s - 56ms/step - accuracy: 0.9590 - loss: 0.3311 - val_accuracy: 0.8634 - val_loss: 0.6983 - learning_rate: 1.2500e-04
# Epoch 44/300
# 704/704 - 39s - 56ms/step - accuracy: 0.9609 - loss: 0.3249 - val_accuracy: 0.8656 - val_loss: 0.7168 - learning_rate: 1.2500e-04
# Epoch 45/300
# 704/704 - 39s - 56ms/step - accuracy: 0.9608 - loss: 0.3219 - val_accuracy: 0.8644 - val_loss: 0.7263 - learning_rate: 1.2500e-04
# Epoch 46/300
# 704/704 - 39s - 56ms/step - accuracy: 0.9621 - loss: 0.3157 - val_accuracy: 0.8658 - val_loss: 0.7166 - learning_rate: 1.2500e-04
# Epoch 47/300
# 704/704 - 39s - 56ms/step - accuracy: 0.9635 - loss: 0.3138 - val_accuracy: 0.8672 - val_loss: 0.7020 - learning_rate: 1.2500e-04
# Epoch 48/300
# 704/704 - 40s - 56ms/step - accuracy: 0.9626 - loss: 0.3108 - val_accuracy: 0.8684 - val_loss: 0.7117 - learning_rate: 1.2500e-04
# Epoch 49/300
# 704/704 - 40s - 57ms/step - accuracy: 0.9641 - loss: 0.3042 - val_accuracy: 0.8656 - val_loss: 0.7234 - learning_rate: 1.2500e-04
# Epoch 50/300
# 704/704 - 39s - 56ms/step - accuracy: 0.9651 - loss: 0.3002 - val_accuracy: 0.8676 - val_loss: 0.7221 - learning_rate: 1.2500e-04
# Epoch 51/300
# 704/704 - 40s - 56ms/step - accuracy: 0.9679 - loss: 0.2920 - val_accuracy: 0.8682 - val_loss: 0.7167 - learning_rate: 6.2500e-05
# Epoch 52/300
# 704/704 - 40s - 57ms/step - accuracy: 0.9693 - loss: 0.2869 - val_accuracy: 0.8698 - val_loss: 0.7077 - learning_rate: 6.2500e-05
# Epoch 53/300
# 704/704 - 41s - 58ms/step - accuracy: 0.9706 - loss: 0.2814 - val_accuracy: 0.8682 - val_loss: 0.7159 - learning_rate: 6.2500e-05
# Epoch 54/300
# 704/704 - 41s - 58ms/step - accuracy: 0.9721 - loss: 0.2772 - val_accuracy: 0.8710 - val_loss: 0.7225 - learning_rate: 6.2500e-05
# Epoch 55/300
# 704/704 - 41s - 58ms/step - accuracy: 0.9734 - loss: 0.2729 - val_accuracy: 0.8678 - val_loss: 0.7161 - learning_rate: 6.2500e-05
# Epoch 56/300
# 704/704 - 41s - 58ms/step - accuracy: 0.9726 - loss: 0.2723 - val_accuracy: 0.8670 - val_loss: 0.7219 - learning_rate: 6.2500e-05
# Epoch 57/300
# 704/704 - 40s - 57ms/step - accuracy: 0.9734 - loss: 0.2689 - val_accuracy: 0.8698 - val_loss: 0.7420 - learning_rate: 6.2500e-05
# Epoch 58/300
# 704/704 - 39s - 56ms/step - accuracy: 0.9734 - loss: 0.2677 - val_accuracy: 0.8724 - val_loss: 0.7208 - learning_rate: 6.2500e-05
# Epoch 59/300
# 704/704 - 40s - 56ms/step - accuracy: 0.9741 - loss: 0.2644 - val_accuracy: 0.8710 - val_loss: 0.7227 - learning_rate: 6.2500e-05
# Epoch 60/300
# 704/704 - 40s - 57ms/step - accuracy: 0.9734 - loss: 0.2663 - val_accuracy: 0.8702 - val_loss: 0.7229 - learning_rate: 6.2500e-05
# Epoch 61/300
# 704/704 - 41s - 58ms/step - accuracy: 0.9758 - loss: 0.2592 - val_accuracy: 0.8732 - val_loss: 0.7143 - learning_rate: 3.1250e-05
# Epoch 62/300
# 704/704 - 41s - 58ms/step - accuracy: 0.9772 - loss: 0.2544 - val_accuracy: 0.8716 - val_loss: 0.7170 - learning_rate: 3.1250e-05
# Epoch 63/300
# 704/704 - 40s - 57ms/step - accuracy: 0.9785 - loss: 0.2508 - val_accuracy: 0.8712 - val_loss: 0.7198 - learning_rate: 3.1250e-05
# Epoch 64/300
# 704/704 - 40s - 57ms/step - accuracy: 0.9778 - loss: 0.2504 - val_accuracy: 0.8702 - val_loss: 0.7224 - learning_rate: 3.1250e-05
# Epoch 65/300
# 704/704 - 40s - 57ms/step - accuracy: 0.9777 - loss: 0.2504 - val_accuracy: 0.8732 - val_loss: 0.7191 - learning_rate: 3.1250e-05
# Epoch 66/300
# 704/704 - 41s - 58ms/step - accuracy: 0.9783 - loss: 0.2489 - val_accuracy: 0.8734 - val_loss: 0.7242 - learning_rate: 3.1250e-05
# Epoch 67/300
# 704/704 - 41s - 58ms/step - accuracy: 0.9783 - loss: 0.2476 - val_accuracy: 0.8738 - val_loss: 0.7253 - learning_rate: 3.1250e-05
# Epoch 68/300
# 704/704 - 41s - 59ms/step - accuracy: 0.9788 - loss: 0.2459 - val_accuracy: 0.8744 - val_loss: 0.7204 - learning_rate: 3.1250e-05
# Epoch 69/300
# 704/704 - 40s - 57ms/step - accuracy: 0.9786 - loss: 0.2456 - val_accuracy: 0.8740 - val_loss: 0.7262 - learning_rate: 3.1250e-05
# Epoch 70/300
# 704/704 - 41s - 58ms/step - accuracy: 0.9796 - loss: 0.2433 - val_accuracy: 0.8734 - val_loss: 0.7209 - learning_rate: 3.1250e-05
# Epoch 70: early stopping
# Restoring model weights from the end of the best epoch: 30.

# %%
plt.figure(figsize=(15,6))

# Plotting the training and validation loss
plt.subplot(1, 2, 1)
plt.plot(model.history.history['loss'], label='Train Loss', color='#8502d1')
plt.plot(model.history.history['val_loss'], label='Validation Loss', color='darkorange')
plt.legend()
plt.title('Loss Evolution')

# Plotting the training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(model.history.history['accuracy'], label='Train Accuracy', color='#8502d1')
plt.plot(model.history.history['val_accuracy'], label='Validation Accuracy', color='darkorange')
plt.legend()
plt.title('Accuracy Evolution')

plt.show()

# %%
# Use the model to make predictions, evaluate on test data
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=1)

print('\nTest Accuracy:', test_acc)
print('Test Loss:    ', test_loss)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8547 - loss: 0.7035
#
# Test Accuracy: 0.8604000210762024
# Test Loss:     0.7043169736862183
