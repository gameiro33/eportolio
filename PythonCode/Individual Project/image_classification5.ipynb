# %% [markdown]
# # Import Libraries

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dropout, Flatten, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.models import load_model
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np

# %%
   # Configure TensorFlow to grow GPU memory allocation as needed
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# %% [markdown]
# Downloading CIFAR 10:

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %% [markdown]
# The standard practice for splitting data into training, validation, and test sets typically follows these guidelines:
# Training Set (60-80%): Used to train the model
# Validation Set (10-20%): Used for hyperparameter tuning and model selection
# Test Set (10-20%): Used for final model evaluation
#
# Since the training and test set are already split in this data set in a 1/6 proportion, we will further carve 10% out of the training set to be used for validation.
#
# Source: https://www.v7labs.com/blog/train-validation-test-set

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.15, random_state=0)

# %%
print('Train Images Shape:      ', X_train.shape)
print('Train Labels Shape:      ', y_train.shape)

print('\nValidation Images Shape: ', X_valid.shape)
print('Validation Labels Shape: ', y_valid.shape)

print('\nTest Images Shape:       ', X_test.shape)
print('Test Labels Shape:       ', y_test.shape)
# Out:
# Train Images Shape:       (42500, 32, 32, 3)
# Train Labels Shape:       (42500, 1)
#
# Validation Images Shape:  (7500, 32, 32, 3)
# Validation Labels Shape:  (7500, 1)
#
# Test Images Shape:        (10000, 32, 32, 3)
# Test Labels Shape:        (10000, 1)

# %%
# Display a 3x3 grid of random images
plt.figure(figsize=(8, 8))

# Define the class names, so that they can be shown in the plot
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# Plot 9 random images from the training set
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.imshow(X_train[i])
    plt.title(f'Class: {class_names[y_train[i][0]]}')
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
# Convert pixel values data type to float32
X_train = X_train.astype('float32')
X_test  = X_test.astype('float32')
X_valid = X_valid.astype('float32')

# Calculate the mean and standard deviation of the training images
mean = np.mean(X_train)
std  = np.std(X_train)

# Normalize the data
# The tiny value 1e-7 is added to prevent division by zero
X_train = (X_train-mean)/(std+1e-7)
X_test  = (X_test-mean) /(std+1e-7)
X_valid = (X_valid-mean)/(std+1e-7)

# %%
# One-hot encoding of labels
y_train = to_categorical(y_train, 10)
y_valid = to_categorical(y_valid, 10)
y_test  = to_categorical(y_test, 10)

# %% [markdown]
# # Data Augmentation
#
# Rotation:
#
# Source: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0
#
# Horizontal Flip:
#
# Source: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0
#
# Brightness:
#
# Source: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0
#
# Zoom:
#
# Source: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0
#
# Shearing:
#
# Source: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0
#
# Future work. Try:
# * Patch Suffle Regularization
# * Sample Pairing
# * Random Erasing

# %%
# Data augmentation
data_generator = ImageDataGenerator(
    # Rotate images randomly by up to 15 degrees
    rotation_range=15,
    # Randomly flip images horizontally
    horizontal_flip=True,
    # Zoom images in by up to 10%
    zoom_range=0.1,
    # Change brightness by up to 10%
    brightness_range=[0.9,1.1],
    # Shear intensity (shear angle in counter-clockwise direction in degrees)
    shear_range=10,
    # Channel shift intensity
    channel_shift_range=0.1,
)

# %% [markdown]
# Using mixed precision training (FP16) which can significantly speed up training on modern GPUs

# %%
# Enable mixed precision training
tf.keras.mixed_precision.set_global_policy('mixed_float16')

# %% [markdown]
# Building the VGG16 inspired model
#
# Source: https://www.kaggle.com/code/farzadnekouei/cifar-10-image-classification-with-cnn

# %%
# Initialize a sequential model
model = Sequential()

# Set the weight decay value for L2 regularization
weight_decay = 0.0001

# Add the first convolutional layer with 32 filters of size 3x3
model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay), 
                 input_shape=X_train.shape[1:]))
# Add batch normalization layer
model.add(BatchNormalization())

# Add the second convolutional layer similar to the first
model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the first max pooling layer with pool size of 2x2
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add dropout layer with 0.2 dropout rate
model.add(Dropout(rate=0.2))

# Add the third and fourth convolutional layers with 64 filters
model.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))   
model.add(BatchNormalization())
model.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the second max pooling layer and increase dropout rate to 0.3
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.3))

# Add the fifth and sixth convolutional layers with 128 filters
model.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay))) 
model.add(BatchNormalization())
model.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the third max pooling layer and increase dropout rate to 0.4
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.4))

# Add the seventh and eighth convolutional layers with 256 filters
model.add(Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay))) 
model.add(BatchNormalization())
model.add(Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the fourth max pooling layer and increase dropout rate to 0.5
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.5))

# Flatten the tensor output from the previous layer
model.add(Flatten())

# Add a fully connected layer with softmax activation function for outputting class probabilities
model.add(Dense(10, activation='softmax'))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-04-12 21:44:45.610226: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Pro
# 2025-04-12 21:44:45.610256: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-04-12 21:44:45.610275: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2025-04-12 21:44:45.610293: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-04-12 21:44:45.610306: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 4, 4, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 4, 4, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 4, 4, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 4, 4, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 2, 2, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 2, 2, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │        10,250 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,186,346 (4.53 MB)
#  Trainable params: 1,184,426 (4.52 MB)
#  Non-trainable params: 1,920 (7.50 KB)

# %%
# Set the batch size for the training
batch_size = 128

# Set the maximum number of epochs for the training
epochs = 300

# Define the optimizer (Adam)
optimizer = Adam(learning_rate=0.0005)

# Compile the model with the defined optimizer, loss function, and metrics
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Add ReduceLROnPlateau callback
# Here, the learning rate will be reduced by half (factor=0.5) if no improvement in validation loss is observed for 10 epochs
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=0.00001)

# Add EarlyStopping callback
# Here, training will be stopped if no improvement in validation loss is observed for 40 epochs.
# The `restore_best_weights` parameter ensures that the model weights are reset to the values from the epoch
# with the best value of the monitored quantity (in this case, 'val_loss').
early_stopping = EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True, verbose=1)

# Fit the model on the training data, using the defined batch size and number of epochs
# The validation data is used to evaluate the model's performance during training
# The callbacks implemented are learning rate reduction when a plateau is reached in validation loss and
# stopping training early if no improvement is observed
model.fit(data_generator.flow(X_train, y_train, batch_size=batch_size),
          epochs=epochs,
          validation_data=(X_valid, y_valid),
          callbacks=[reduce_lr, early_stopping], 
          verbose=2)
# Out:
# Epoch 1/300
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2025-04-12 21:44:48.098743: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 333/333 - 43s - 129ms/step - accuracy: 0.3146 - loss: 2.4908 - val_accuracy: 0.2609 - val_loss: 2.2365 - learning_rate: 5.0000e-04
# Epoch 2/300
# 333/333 - 31s - 94ms/step - accuracy: 0.4485 - loss: 1.7271 - val_accuracy: 0.4812 - val_loss: 1.5954 - learning_rate: 5.0000e-04
# Epoch 3/300
# 333/333 - 31s - 94ms/step - accuracy: 0.5072 - loss: 1.5497 - val_accuracy: 0.5793 - val_loss: 1.2909 - learning_rate: 5.0000e-04
# Epoch 4/300
# 333/333 - 35s - 104ms/step - accuracy: 0.5544 - loss: 1.4238 - val_accuracy: 0.5123 - val_loss: 1.5302 - learning_rate: 5.0000e-04
# Epoch 5/300
# 333/333 - 38s - 113ms/step - accuracy: 0.5840 - loss: 1.3296 - val_accuracy: 0.5140 - val_loss: 1.7238 - learning_rate: 5.0000e-04
# Epoch 6/300
# 333/333 - 39s - 118ms/step - accuracy: 0.5958 - loss: 1.3044 - val_accuracy: 0.6288 - val_loss: 1.1999 - learning_rate: 5.0000e-04
# Epoch 7/300
# 333/333 - 36s - 109ms/step - accuracy: 0.6188 - loss: 1.2450 - val_accuracy: 0.5831 - val_loss: 1.3860 - learning_rate: 5.0000e-04
# Epoch 8/300
# 333/333 - 36s - 108ms/step - accuracy: 0.6391 - loss: 1.1782 - val_accuracy: 0.6589 - val_loss: 1.1301 - learning_rate: 5.0000e-04
# Epoch 9/300
# 333/333 - 36s - 107ms/step - accuracy: 0.6519 - loss: 1.1644 - val_accuracy: 0.4731 - val_loss: 3.3919 - learning_rate: 5.0000e-04
# Epoch 10/300
# 333/333 - 36s - 109ms/step - accuracy: 0.6337 - loss: 1.2189 - val_accuracy: 0.5915 - val_loss: 1.2992 - learning_rate: 5.0000e-04
# Epoch 11/300
# 333/333 - 36s - 108ms/step - accuracy: 0.6540 - loss: 1.1723 - val_accuracy: 0.6801 - val_loss: 1.0471 - learning_rate: 5.0000e-04
# Epoch 12/300
# 333/333 - 35s - 106ms/step - accuracy: 0.6743 - loss: 1.0926 - val_accuracy: 0.7065 - val_loss: 0.9614 - learning_rate: 5.0000e-04
# Epoch 13/300
# 333/333 - 39s - 118ms/step - accuracy: 0.6863 - loss: 1.0655 - val_accuracy: 0.6261 - val_loss: 2.2713 - learning_rate: 5.0000e-04
# Epoch 14/300
# 333/333 - 39s - 117ms/step - accuracy: 0.6929 - loss: 1.0507 - val_accuracy: 0.7277 - val_loss: 0.9220 - learning_rate: 5.0000e-04
# Epoch 15/300
# 333/333 - 37s - 112ms/step - accuracy: 0.7026 - loss: 1.0200 - val_accuracy: 0.5833 - val_loss: 1.4460 - learning_rate: 5.0000e-04
# Epoch 16/300
# 333/333 - 37s - 112ms/step - accuracy: 0.6844 - loss: 1.0965 - val_accuracy: 0.7441 - val_loss: 0.8754 - learning_rate: 5.0000e-04
# Epoch 17/300
# 333/333 - 38s - 113ms/step - accuracy: 0.6963 - loss: 1.0702 - val_accuracy: 0.7289 - val_loss: 0.9133 - learning_rate: 5.0000e-04
# Epoch 18/300
# 333/333 - 37s - 111ms/step - accuracy: 0.7115 - loss: 1.0118 - val_accuracy: 0.7537 - val_loss: 0.8810 - learning_rate: 5.0000e-04
# Epoch 19/300
# 333/333 - 37s - 112ms/step - accuracy: 0.7206 - loss: 1.0182 - val_accuracy: 0.7039 - val_loss: 1.0183 - learning_rate: 5.0000e-04
# Epoch 20/300
# 333/333 - 38s - 113ms/step - accuracy: 0.6985 - loss: 1.1305 - val_accuracy: 0.7375 - val_loss: 0.9062 - learning_rate: 5.0000e-04
# Epoch 21/300
# 333/333 - 37s - 112ms/step - accuracy: 0.7149 - loss: 1.0549 - val_accuracy: 0.7517 - val_loss: 0.9551 - learning_rate: 5.0000e-04
# Epoch 22/300
# 333/333 - 37s - 112ms/step - accuracy: 0.7361 - loss: 0.9553 - val_accuracy: 0.7512 - val_loss: 0.8992 - learning_rate: 5.0000e-04
# Epoch 23/300
# 333/333 - 37s - 112ms/step - accuracy: 0.7418 - loss: 0.9483 - val_accuracy: 0.7531 - val_loss: 0.8666 - learning_rate: 5.0000e-04
# Epoch 24/300
# 333/333 - 37s - 112ms/step - accuracy: 0.7300 - loss: 0.9965 - val_accuracy: 0.7396 - val_loss: 0.9383 - learning_rate: 5.0000e-04
# Epoch 25/300
# 333/333 - 37s - 111ms/step - accuracy: 0.7164 - loss: 1.0664 - val_accuracy: 0.7036 - val_loss: 1.0083 - learning_rate: 5.0000e-04
# Epoch 26/300
# 333/333 - 37s - 110ms/step - accuracy: 0.7153 - loss: 1.0662 - val_accuracy: 0.7368 - val_loss: 0.9978 - learning_rate: 5.0000e-04
# Epoch 27/300
# 333/333 - 37s - 112ms/step - accuracy: 0.7414 - loss: 0.9514 - val_accuracy: 0.7771 - val_loss: 0.8124 - learning_rate: 5.0000e-04
# Epoch 28/300
# 333/333 - 37s - 111ms/step - accuracy: 0.7475 - loss: 0.9328 - val_accuracy: 0.7776 - val_loss: 0.9019 - learning_rate: 5.0000e-04
# Epoch 29/300
# 333/333 - 37s - 112ms/step - accuracy: 0.7571 - loss: 0.9072 - val_accuracy: 0.7629 - val_loss: 0.8884 - learning_rate: 5.0000e-04
# Epoch 30/300
# 333/333 - 37s - 110ms/step - accuracy: 0.7524 - loss: 0.9277 - val_accuracy: 0.7516 - val_loss: 0.9114 - learning_rate: 5.0000e-04
# Epoch 31/300
# 333/333 - 1101s - 3s/step - accuracy: 0.7414 - loss: 0.9762 - val_accuracy: 0.7195 - val_loss: 1.0079 - learning_rate: 5.0000e-04
# Epoch 32/300
# 333/333 - 36s - 108ms/step - accuracy: 0.7149 - loss: 1.0535 - val_accuracy: 0.7731 - val_loss: 0.8630 - learning_rate: 5.0000e-04
# Epoch 33/300
# 333/333 - 212s - 636ms/step - accuracy: 0.7535 - loss: 0.9344 - val_accuracy: 0.7485 - val_loss: 0.9550 - learning_rate: 5.0000e-04
# Epoch 34/300
# 333/333 - 37s - 111ms/step - accuracy: 0.7639 - loss: 0.8887 - val_accuracy: 0.7829 - val_loss: 0.8187 - learning_rate: 5.0000e-04
# Epoch 35/300
# 333/333 - 35s - 106ms/step - accuracy: 0.7769 - loss: 0.8501 - val_accuracy: 0.8020 - val_loss: 0.7702 - learning_rate: 5.0000e-04
# Epoch 36/300
# 333/333 - 35s - 106ms/step - accuracy: 0.7744 - loss: 0.8636 - val_accuracy: 0.8017 - val_loss: 0.7862 - learning_rate: 5.0000e-04
# Epoch 37/300
# 333/333 - 35s - 104ms/step - accuracy: 0.7876 - loss: 0.8128 - val_accuracy: 0.7737 - val_loss: 0.8773 - learning_rate: 5.0000e-04
# Epoch 38/300
# 333/333 - 35s - 105ms/step - accuracy: 0.7892 - loss: 0.8100 - val_accuracy: 0.8027 - val_loss: 0.7610 - learning_rate: 5.0000e-04
# Epoch 39/300
# 333/333 - 35s - 104ms/step - accuracy: 0.7972 - loss: 0.7767 - val_accuracy: 0.8137 - val_loss: 0.7339 - learning_rate: 5.0000e-04
# Epoch 40/300
# 333/333 - 35s - 106ms/step - accuracy: 0.7895 - loss: 0.7992 - val_accuracy: 0.8001 - val_loss: 0.8029 - learning_rate: 5.0000e-04
# Epoch 41/300
# 333/333 - 35s - 105ms/step - accuracy: 0.7866 - loss: 0.8119 - val_accuracy: 0.8135 - val_loss: 0.7372 - learning_rate: 5.0000e-04
# Epoch 42/300
# 333/333 - 35s - 105ms/step - accuracy: 0.7904 - loss: 0.8060 - val_accuracy: 0.8067 - val_loss: 0.7743 - learning_rate: 5.0000e-04
# Epoch 43/300
# 333/333 - 36s - 107ms/step - accuracy: 0.7944 - loss: 0.7979 - val_accuracy: 0.8133 - val_loss: 0.7561 - learning_rate: 5.0000e-04
# Epoch 44/300
# 333/333 - 35s - 106ms/step - accuracy: 0.7985 - loss: 0.7816 - val_accuracy: 0.8184 - val_loss: 0.7269 - learning_rate: 5.0000e-04
# Epoch 45/300
# 333/333 - 36s - 107ms/step - accuracy: 0.8080 - loss: 0.7465 - val_accuracy: 0.8072 - val_loss: 0.7479 - learning_rate: 5.0000e-04
# Epoch 46/300
# 333/333 - 35s - 105ms/step - accuracy: 0.8008 - loss: 0.7673 - val_accuracy: 0.7776 - val_loss: 0.8881 - learning_rate: 5.0000e-04
# Epoch 47/300
# 333/333 - 36s - 107ms/step - accuracy: 0.8006 - loss: 0.7751 - val_accuracy: 0.8221 - val_loss: 0.7041 - learning_rate: 5.0000e-04
# Epoch 48/300
# 333/333 - 35s - 106ms/step - accuracy: 0.8140 - loss: 0.7326 - val_accuracy: 0.8107 - val_loss: 0.7601 - learning_rate: 5.0000e-04
# Epoch 49/300
# 333/333 - 36s - 107ms/step - accuracy: 0.8072 - loss: 0.7534 - val_accuracy: 0.8269 - val_loss: 0.7035 - learning_rate: 5.0000e-04
# Epoch 50/300
# 333/333 - 36s - 108ms/step - accuracy: 0.8165 - loss: 0.7251 - val_accuracy: 0.8269 - val_loss: 0.7057 - learning_rate: 5.0000e-04
# Epoch 51/300
# 333/333 - 1005s - 3s/step - accuracy: 0.8202 - loss: 0.7243 - val_accuracy: 0.8381 - val_loss: 0.6708 - learning_rate: 5.0000e-04
# Epoch 52/300
# 333/333 - 36s - 109ms/step - accuracy: 0.8178 - loss: 0.7196 - val_accuracy: 0.8239 - val_loss: 0.7127 - learning_rate: 5.0000e-04
# Epoch 53/300
# 333/333 - 1016s - 3s/step - accuracy: 0.8222 - loss: 0.7107 - val_accuracy: 0.8260 - val_loss: 0.7139 - learning_rate: 5.0000e-04
# Epoch 54/300
# 333/333 - 943s - 3s/step - accuracy: 0.8259 - loss: 0.6988 - val_accuracy: 0.8348 - val_loss: 0.7039 - learning_rate: 5.0000e-04
# Epoch 55/300
# 333/333 - 26s - 77ms/step - accuracy: 0.8272 - loss: 0.7009 - val_accuracy: 0.8135 - val_loss: 0.7644 - learning_rate: 5.0000e-04
# Epoch 56/300
# 333/333 - 1034s - 3s/step - accuracy: 0.8170 - loss: 0.7217 - val_accuracy: 0.8308 - val_loss: 0.7072 - learning_rate: 5.0000e-04
# Epoch 57/300
# 333/333 - 25s - 76ms/step - accuracy: 0.8228 - loss: 0.7130 - val_accuracy: 0.8323 - val_loss: 0.7121 - learning_rate: 5.0000e-04
# Epoch 58/300
# 333/333 - 1041s - 3s/step - accuracy: 0.8142 - loss: 0.7369 - val_accuracy: 0.8213 - val_loss: 0.7300 - learning_rate: 5.0000e-04
# Epoch 59/300
# 333/333 - 25s - 76ms/step - accuracy: 0.8218 - loss: 0.7178 - val_accuracy: 0.8340 - val_loss: 0.6874 - learning_rate: 5.0000e-04
# Epoch 60/300
# 333/333 - 938s - 3s/step - accuracy: 0.8246 - loss: 0.7094 - val_accuracy: 0.8337 - val_loss: 0.7010 - learning_rate: 5.0000e-04
# Epoch 61/300
# 333/333 - 26s - 77ms/step - accuracy: 0.8304 - loss: 0.7019 - val_accuracy: 0.8319 - val_loss: 0.7066 - learning_rate: 5.0000e-04
# Epoch 62/300
# 333/333 - 26s - 78ms/step - accuracy: 0.8406 - loss: 0.6646 - val_accuracy: 0.8445 - val_loss: 0.6649 - learning_rate: 2.5000e-04
# Epoch 63/300
# 333/333 - 837s - 3s/step - accuracy: 0.8384 - loss: 0.6691 - val_accuracy: 0.8428 - val_loss: 0.6702 - learning_rate: 2.5000e-04
# Epoch 64/300
# 333/333 - 26s - 77ms/step - accuracy: 0.8419 - loss: 0.6535 - val_accuracy: 0.8528 - val_loss: 0.6500 - learning_rate: 2.5000e-04
# Epoch 65/300
# 333/333 - 26s - 77ms/step - accuracy: 0.8457 - loss: 0.6473 - val_accuracy: 0.8472 - val_loss: 0.6496 - learning_rate: 2.5000e-04
# Epoch 66/300
# 333/333 - 993s - 3s/step - accuracy: 0.8482 - loss: 0.6328 - val_accuracy: 0.8537 - val_loss: 0.6321 - learning_rate: 2.5000e-04
# Epoch 67/300
# 333/333 - 938s - 3s/step - accuracy: 0.8486 - loss: 0.6328 - val_accuracy: 0.8479 - val_loss: 0.6493 - learning_rate: 2.5000e-04
# Epoch 68/300
# 333/333 - 26s - 78ms/step - accuracy: 0.8519 - loss: 0.6236 - val_accuracy: 0.8477 - val_loss: 0.6595 - learning_rate: 2.5000e-04
# Epoch 69/300
# 333/333 - 944s - 3s/step - accuracy: 0.8548 - loss: 0.6084 - val_accuracy: 0.8561 - val_loss: 0.6267 - learning_rate: 2.5000e-04
# Epoch 70/300
# 333/333 - 26s - 78ms/step - accuracy: 0.8532 - loss: 0.6141 - val_accuracy: 0.8451 - val_loss: 0.6615 - learning_rate: 2.5000e-04
# Epoch 71/300
# 333/333 - 941s - 3s/step - accuracy: 0.8599 - loss: 0.5955 - val_accuracy: 0.8565 - val_loss: 0.6188 - learning_rate: 2.5000e-04
# Epoch 72/300
# 333/333 - 26s - 78ms/step - accuracy: 0.8591 - loss: 0.5977 - val_accuracy: 0.8553 - val_loss: 0.6286 - learning_rate: 2.5000e-04
# Epoch 73/300
# 333/333 - 878s - 3s/step - accuracy: 0.8552 - loss: 0.6063 - val_accuracy: 0.8496 - val_loss: 0.6561 - learning_rate: 2.5000e-04
# Epoch 74/300
# 333/333 - 25s - 75ms/step - accuracy: 0.8565 - loss: 0.6033 - val_accuracy: 0.8605 - val_loss: 0.6214 - learning_rate: 2.5000e-04
# Epoch 75/300
# 333/333 - 1030s - 3s/step - accuracy: 0.8613 - loss: 0.5874 - val_accuracy: 0.8420 - val_loss: 0.6604 - learning_rate: 2.5000e-04
# Epoch 76/300
# 333/333 - 23s - 70ms/step - accuracy: 0.8616 - loss: 0.5864 - val_accuracy: 0.8552 - val_loss: 0.6345 - learning_rate: 2.5000e-04
# Epoch 77/300
# 333/333 - 956s - 3s/step - accuracy: 0.8663 - loss: 0.5727 - val_accuracy: 0.8607 - val_loss: 0.6101 - learning_rate: 2.5000e-04
# Epoch 78/300
# 333/333 - 26s - 78ms/step - accuracy: 0.8601 - loss: 0.5826 - val_accuracy: 0.8571 - val_loss: 0.6199 - learning_rate: 2.5000e-04
# Epoch 79/300
# 333/333 - 941s - 3s/step - accuracy: 0.8665 - loss: 0.5670 - val_accuracy: 0.8541 - val_loss: 0.6344 - learning_rate: 2.5000e-04
# Epoch 80/300
# 333/333 - 952s - 3s/step - accuracy: 0.8613 - loss: 0.5829 - val_accuracy: 0.8539 - val_loss: 0.6340 - learning_rate: 2.5000e-04
# Epoch 81/300
# 333/333 - 26s - 77ms/step - accuracy: 0.8663 - loss: 0.5643 - val_accuracy: 0.8568 - val_loss: 0.6149 - learning_rate: 2.5000e-04
# Epoch 82/300
# 333/333 - 804s - 2s/step - accuracy: 0.8686 - loss: 0.5593 - val_accuracy: 0.8560 - val_loss: 0.6233 - learning_rate: 2.5000e-04
# Epoch 83/300
# 333/333 - 25s - 76ms/step - accuracy: 0.8652 - loss: 0.5674 - val_accuracy: 0.8624 - val_loss: 0.5998 - learning_rate: 2.5000e-04
# Epoch 84/300
# 333/333 - 368s - 1s/step - accuracy: 0.8701 - loss: 0.5534 - val_accuracy: 0.8473 - val_loss: 0.6461 - learning_rate: 2.5000e-04
# Epoch 85/300
# 333/333 - 26s - 77ms/step - accuracy: 0.8642 - loss: 0.5723 - val_accuracy: 0.8527 - val_loss: 0.6288 - learning_rate: 2.5000e-04
# Epoch 86/300
# 333/333 - 1050s - 3s/step - accuracy: 0.8679 - loss: 0.5597 - val_accuracy: 0.8673 - val_loss: 0.5867 - learning_rate: 2.5000e-04
# Epoch 87/300
# 333/333 - 26s - 77ms/step - accuracy: 0.8732 - loss: 0.5427 - val_accuracy: 0.8461 - val_loss: 0.6527 - learning_rate: 2.5000e-04
# Epoch 88/300
# 333/333 - 1067s - 3s/step - accuracy: 0.8675 - loss: 0.5597 - val_accuracy: 0.8543 - val_loss: 0.6213 - learning_rate: 2.5000e-04
# Epoch 89/300
# 333/333 - 26s - 77ms/step - accuracy: 0.8723 - loss: 0.5434 - val_accuracy: 0.8576 - val_loss: 0.6144 - learning_rate: 2.5000e-04
# Epoch 90/300
# 333/333 - 985s - 3s/step - accuracy: 0.8604 - loss: 0.5838 - val_accuracy: 0.8621 - val_loss: 0.6031 - learning_rate: 2.5000e-04
# Epoch 91/300
# 333/333 - 935s - 3s/step - accuracy: 0.8727 - loss: 0.5437 - val_accuracy: 0.8557 - val_loss: 0.6284 - learning_rate: 2.5000e-04
# Epoch 92/300
# 333/333 - 26s - 77ms/step - accuracy: 0.8699 - loss: 0.5535 - val_accuracy: 0.8581 - val_loss: 0.6176 - learning_rate: 2.5000e-04
# Epoch 93/300
# 333/333 - 103s - 308ms/step - accuracy: 0.8735 - loss: 0.5439 - val_accuracy: 0.8640 - val_loss: 0.5951 - learning_rate: 2.5000e-04
# Epoch 94/300
# 333/333 - 26s - 77ms/step - accuracy: 0.8779 - loss: 0.5254 - val_accuracy: 0.8667 - val_loss: 0.5882 - learning_rate: 2.5000e-04
# Epoch 95/300
# 333/333 - 959s - 3s/step - accuracy: 0.8759 - loss: 0.5304 - val_accuracy: 0.8640 - val_loss: 0.5786 - learning_rate: 2.5000e-04
# Epoch 96/300
# 333/333 - 26s - 77ms/step - accuracy: 0.8770 - loss: 0.5301 - val_accuracy: 0.8595 - val_loss: 0.6069 - learning_rate: 2.5000e-04
# Epoch 97/300
# 333/333 - 996s - 3s/step - accuracy: 0.8741 - loss: 0.5337 - val_accuracy: 0.8597 - val_loss: 0.6153 - learning_rate: 2.5000e-04
# Epoch 98/300
# 333/333 - 26s - 78ms/step - accuracy: 0.8777 - loss: 0.5250 - val_accuracy: 0.8493 - val_loss: 0.6313 - learning_rate: 2.5000e-04
# Epoch 99/300
# 333/333 - 944s - 3s/step - accuracy: 0.8702 - loss: 0.5431 - val_accuracy: 0.8639 - val_loss: 0.5972 - learning_rate: 2.5000e-04
# Epoch 100/300
# 333/333 - 26s - 77ms/step - accuracy: 0.8827 - loss: 0.5141 - val_accuracy: 0.8628 - val_loss: 0.5994 - learning_rate: 2.5000e-04
# Epoch 101/300
# 333/333 - 585s - 2s/step - accuracy: 0.8763 - loss: 0.5255 - val_accuracy: 0.8639 - val_loss: 0.5913 - learning_rate: 2.5000e-04
# Epoch 102/300
# 333/333 - 26s - 78ms/step - accuracy: 0.8766 - loss: 0.5253 - val_accuracy: 0.8663 - val_loss: 0.5854 - learning_rate: 2.5000e-04
# Epoch 103/300
# 333/333 - 984s - 3s/step - accuracy: 0.8814 - loss: 0.5150 - val_accuracy: 0.8580 - val_loss: 0.5954 - learning_rate: 2.5000e-04
# Epoch 104/300
# 333/333 - 26s - 78ms/step - accuracy: 0.8732 - loss: 0.5389 - val_accuracy: 0.8637 - val_loss: 0.5835 - learning_rate: 2.5000e-04
# Epoch 105/300
# 333/333 - 1013s - 3s/step - accuracy: 0.8800 - loss: 0.5196 - val_accuracy: 0.8688 - val_loss: 0.5745 - learning_rate: 2.5000e-04
# Epoch 106/300
# 333/333 - 26s - 77ms/step - accuracy: 0.8855 - loss: 0.5024 - val_accuracy: 0.8725 - val_loss: 0.5665 - learning_rate: 2.5000e-04
# Epoch 107/300
# 333/333 - 974s - 3s/step - accuracy: 0.8835 - loss: 0.5045 - val_accuracy: 0.8645 - val_loss: 0.5955 - learning_rate: 2.5000e-04
# Epoch 108/300
# 333/333 - 622s - 2s/step - accuracy: 0.8792 - loss: 0.5158 - val_accuracy: 0.8636 - val_loss: 0.5953 - learning_rate: 2.5000e-04
# Epoch 109/300
# 333/333 - 26s - 77ms/step - accuracy: 0.8837 - loss: 0.5060 - val_accuracy: 0.8664 - val_loss: 0.5796 - learning_rate: 2.5000e-04
# Epoch 110/300
# 333/333 - 26s - 77ms/step - accuracy: 0.8857 - loss: 0.4980 - val_accuracy: 0.8528 - val_loss: 0.6319 - learning_rate: 2.5000e-04
# Epoch 111/300
# 333/333 - 946s - 3s/step - accuracy: 0.8837 - loss: 0.5055 - val_accuracy: 0.8665 - val_loss: 0.5792 - learning_rate: 2.5000e-04
# Epoch 112/300
# 333/333 - 25s - 76ms/step - accuracy: 0.8741 - loss: 0.5355 - val_accuracy: 0.8637 - val_loss: 0.5919 - learning_rate: 2.5000e-04
# Epoch 113/300
# 333/333 - 26s - 77ms/step - accuracy: 0.8838 - loss: 0.5029 - val_accuracy: 0.8636 - val_loss: 0.5988 - learning_rate: 2.5000e-04
# Epoch 114/300
# 333/333 - 1034s - 3s/step - accuracy: 0.8865 - loss: 0.4949 - val_accuracy: 0.8372 - val_loss: 0.6716 - learning_rate: 2.5000e-04
# Epoch 115/300
# 333/333 - 26s - 77ms/step - accuracy: 0.8766 - loss: 0.5264 - val_accuracy: 0.8597 - val_loss: 0.6106 - learning_rate: 2.5000e-04
# Epoch 116/300
# 333/333 - 943s - 3s/step - accuracy: 0.8852 - loss: 0.5009 - val_accuracy: 0.8689 - val_loss: 0.5803 - learning_rate: 2.5000e-04
# Epoch 117/300
# 333/333 - 26s - 78ms/step - accuracy: 0.8903 - loss: 0.4831 - val_accuracy: 0.8671 - val_loss: 0.5839 - learning_rate: 1.2500e-04
# Epoch 118/300
# 333/333 - 606s - 2s/step - accuracy: 0.8945 - loss: 0.4750 - val_accuracy: 0.8717 - val_loss: 0.5720 - learning_rate: 1.2500e-04
# Epoch 119/300
# 333/333 - 981s - 3s/step - accuracy: 0.8935 - loss: 0.4760 - val_accuracy: 0.8751 - val_loss: 0.5625 - learning_rate: 1.2500e-04
# Epoch 120/300
# 333/333 - 26s - 78ms/step - accuracy: 0.8970 - loss: 0.4608 - val_accuracy: 0.8615 - val_loss: 0.6189 - learning_rate: 1.2500e-04
# Epoch 121/300
# 333/333 - 651s - 2s/step - accuracy: 0.8912 - loss: 0.4762 - val_accuracy: 0.8716 - val_loss: 0.5686 - learning_rate: 1.2500e-04
# Epoch 122/300
# 333/333 - 26s - 77ms/step - accuracy: 0.8984 - loss: 0.4593 - val_accuracy: 0.8677 - val_loss: 0.5819 - learning_rate: 1.2500e-04
# Epoch 123/300
# 333/333 - 33s - 100ms/step - accuracy: 0.8994 - loss: 0.4599 - val_accuracy: 0.8739 - val_loss: 0.5602 - learning_rate: 1.2500e-04
# Epoch 124/300
# 333/333 - 26s - 77ms/step - accuracy: 0.9008 - loss: 0.4519 - val_accuracy: 0.8752 - val_loss: 0.5601 - learning_rate: 1.2500e-04
# Epoch 125/300
# 333/333 - 966s - 3s/step - accuracy: 0.9008 - loss: 0.4505 - val_accuracy: 0.8717 - val_loss: 0.5673 - learning_rate: 1.2500e-04
# Epoch 126/300
# 333/333 - 25s - 76ms/step - accuracy: 0.8987 - loss: 0.4525 - val_accuracy: 0.8708 - val_loss: 0.5765 - learning_rate: 1.2500e-04
# Epoch 127/300
# 333/333 - 863s - 3s/step - accuracy: 0.9036 - loss: 0.4398 - val_accuracy: 0.8629 - val_loss: 0.6281 - learning_rate: 1.2500e-04
# Epoch 128/300
# 333/333 - 26s - 77ms/step - accuracy: 0.9024 - loss: 0.4446 - val_accuracy: 0.8697 - val_loss: 0.5703 - learning_rate: 1.2500e-04
# Epoch 129/300
# 333/333 - 173s - 521ms/step - accuracy: 0.9029 - loss: 0.4397 - val_accuracy: 0.8747 - val_loss: 0.5546 - learning_rate: 1.2500e-04
# Epoch 130/300
# 333/333 - 28s - 84ms/step - accuracy: 0.9005 - loss: 0.4466 - val_accuracy: 0.8783 - val_loss: 0.5528 - learning_rate: 1.2500e-04
# Epoch 131/300
# 333/333 - 27s - 82ms/step - accuracy: 0.9036 - loss: 0.4349 - val_accuracy: 0.8723 - val_loss: 0.5689 - learning_rate: 1.2500e-04
# Epoch 132/300
# 333/333 - 27s - 80ms/step - accuracy: 0.9061 - loss: 0.4347 - val_accuracy: 0.8784 - val_loss: 0.5461 - learning_rate: 1.2500e-04
# Epoch 133/300
# 333/333 - 26s - 79ms/step - accuracy: 0.9041 - loss: 0.4327 - val_accuracy: 0.8745 - val_loss: 0.5575 - learning_rate: 1.2500e-04
# Epoch 134/300
# 333/333 - 27s - 80ms/step - accuracy: 0.9028 - loss: 0.4336 - val_accuracy: 0.8731 - val_loss: 0.5628 - learning_rate: 1.2500e-04
# Epoch 135/300
# 333/333 - 26s - 79ms/step - accuracy: 0.9045 - loss: 0.4296 - val_accuracy: 0.8727 - val_loss: 0.5578 - learning_rate: 1.2500e-04
# Epoch 136/300
# 333/333 - 27s - 80ms/step - accuracy: 0.9040 - loss: 0.4352 - val_accuracy: 0.8697 - val_loss: 0.5700 - learning_rate: 1.2500e-04
# Epoch 137/300
# 333/333 - 26s - 79ms/step - accuracy: 0.9041 - loss: 0.4348 - val_accuracy: 0.8737 - val_loss: 0.5699 - learning_rate: 1.2500e-04
# Epoch 138/300
# 333/333 - 26s - 80ms/step - accuracy: 0.9084 - loss: 0.4244 - val_accuracy: 0.8763 - val_loss: 0.5612 - learning_rate: 1.2500e-04
# Epoch 139/300
# 333/333 - 27s - 80ms/step - accuracy: 0.9056 - loss: 0.4320 - val_accuracy: 0.8709 - val_loss: 0.5788 - learning_rate: 1.2500e-04
# Epoch 140/300
# 333/333 - 27s - 81ms/step - accuracy: 0.9054 - loss: 0.4272 - val_accuracy: 0.8733 - val_loss: 0.5529 - learning_rate: 1.2500e-04
# Epoch 141/300
# 333/333 - 27s - 81ms/step - accuracy: 0.9023 - loss: 0.4334 - val_accuracy: 0.8765 - val_loss: 0.5368 - learning_rate: 1.2500e-04
# Epoch 142/300
# 333/333 - 27s - 80ms/step - accuracy: 0.9053 - loss: 0.4285 - val_accuracy: 0.8777 - val_loss: 0.5377 - learning_rate: 1.2500e-04
# Epoch 143/300
# 333/333 - 27s - 81ms/step - accuracy: 0.9093 - loss: 0.4191 - val_accuracy: 0.8735 - val_loss: 0.5623 - learning_rate: 1.2500e-04
# Epoch 144/300
# 333/333 - 26s - 80ms/step - accuracy: 0.9105 - loss: 0.4134 - val_accuracy: 0.8663 - val_loss: 0.5737 - learning_rate: 1.2500e-04
# Epoch 145/300
# 333/333 - 26s - 79ms/step - accuracy: 0.9097 - loss: 0.4163 - val_accuracy: 0.8756 - val_loss: 0.5631 - learning_rate: 1.2500e-04
# Epoch 146/300
# 333/333 - 26s - 79ms/step - accuracy: 0.9101 - loss: 0.4090 - val_accuracy: 0.8755 - val_loss: 0.5595 - learning_rate: 1.2500e-04
# Epoch 147/300
# 333/333 - 26s - 79ms/step - accuracy: 0.9084 - loss: 0.4176 - val_accuracy: 0.8735 - val_loss: 0.5611 - learning_rate: 1.2500e-04
# Epoch 148/300
# 333/333 - 27s - 80ms/step - accuracy: 0.9067 - loss: 0.4190 - val_accuracy: 0.8727 - val_loss: 0.5606 - learning_rate: 1.2500e-04
# Epoch 149/300
# 333/333 - 26s - 79ms/step - accuracy: 0.9074 - loss: 0.4206 - val_accuracy: 0.8743 - val_loss: 0.5489 - learning_rate: 1.2500e-04
# Epoch 150/300
# 333/333 - 27s - 80ms/step - accuracy: 0.9094 - loss: 0.4123 - val_accuracy: 0.8775 - val_loss: 0.5520 - learning_rate: 1.2500e-04
# Epoch 151/300
# 333/333 - 26s - 79ms/step - accuracy: 0.9100 - loss: 0.4096 - val_accuracy: 0.8713 - val_loss: 0.5453 - learning_rate: 1.2500e-04
# Epoch 152/300
# 333/333 - 26s - 79ms/step - accuracy: 0.9151 - loss: 0.3978 - val_accuracy: 0.8733 - val_loss: 0.5604 - learning_rate: 6.2500e-05
# Epoch 153/300
# 333/333 - 27s - 80ms/step - accuracy: 0.9140 - loss: 0.3973 - val_accuracy: 0.8737 - val_loss: 0.5600 - learning_rate: 6.2500e-05
# Epoch 154/300
# 333/333 - 444s - 1s/step - accuracy: 0.9145 - loss: 0.3976 - val_accuracy: 0.8771 - val_loss: 0.5499 - learning_rate: 6.2500e-05
# Epoch 155/300
# 333/333 - 26s - 77ms/step - accuracy: 0.9166 - loss: 0.3898 - val_accuracy: 0.8763 - val_loss: 0.5575 - learning_rate: 6.2500e-05
# Epoch 156/300
# 333/333 - 463s - 1s/step - accuracy: 0.9184 - loss: 0.3876 - val_accuracy: 0.8771 - val_loss: 0.5480 - learning_rate: 6.2500e-05
# Epoch 157/300
# 333/333 - 25s - 76ms/step - accuracy: 0.9170 - loss: 0.3844 - val_accuracy: 0.8736 - val_loss: 0.5623 - learning_rate: 6.2500e-05
# Epoch 158/300
# 333/333 - 26s - 78ms/step - accuracy: 0.9185 - loss: 0.3867 - val_accuracy: 0.8764 - val_loss: 0.5564 - learning_rate: 6.2500e-05
# Epoch 159/300
# 333/333 - 879s - 3s/step - accuracy: 0.9160 - loss: 0.3920 - val_accuracy: 0.8784 - val_loss: 0.5492 - learning_rate: 6.2500e-05
# Epoch 160/300
# 333/333 - 27s - 82ms/step - accuracy: 0.9168 - loss: 0.3895 - val_accuracy: 0.8765 - val_loss: 0.5459 - learning_rate: 6.2500e-05
# Epoch 161/300
# 333/333 - 30s - 89ms/step - accuracy: 0.9172 - loss: 0.3856 - val_accuracy: 0.8748 - val_loss: 0.5487 - learning_rate: 6.2500e-05
# Epoch 162/300
# 333/333 - 29s - 86ms/step - accuracy: 0.9178 - loss: 0.3837 - val_accuracy: 0.8780 - val_loss: 0.5426 - learning_rate: 3.1250e-05
# Epoch 163/300
# 333/333 - 39s - 117ms/step - accuracy: 0.9194 - loss: 0.3756 - val_accuracy: 0.8773 - val_loss: 0.5548 - learning_rate: 3.1250e-05
# Epoch 164/300
# 333/333 - 40s - 119ms/step - accuracy: 0.9201 - loss: 0.3753 - val_accuracy: 0.8792 - val_loss: 0.5538 - learning_rate: 3.1250e-05
# Epoch 165/300
# 333/333 - 27s - 80ms/step - accuracy: 0.9218 - loss: 0.3739 - val_accuracy: 0.8772 - val_loss: 0.5565 - learning_rate: 3.1250e-05
# Epoch 166/300
# 333/333 - 26s - 78ms/step - accuracy: 0.9209 - loss: 0.3767 - val_accuracy: 0.8779 - val_loss: 0.5541 - learning_rate: 3.1250e-05
# Epoch 167/300
# 333/333 - 26s - 79ms/step - accuracy: 0.9223 - loss: 0.3697 - val_accuracy: 0.8776 - val_loss: 0.5551 - learning_rate: 3.1250e-05
# Epoch 168/300
# 333/333 - 26s - 79ms/step - accuracy: 0.9211 - loss: 0.3743 - val_accuracy: 0.8779 - val_loss: 0.5525 - learning_rate: 3.1250e-05
# Epoch 169/300
# 333/333 - 26s - 79ms/step - accuracy: 0.9211 - loss: 0.3725 - val_accuracy: 0.8796 - val_loss: 0.5486 - learning_rate: 3.1250e-05
# Epoch 170/300
# 333/333 - 26s - 78ms/step - accuracy: 0.9237 - loss: 0.3718 - val_accuracy: 0.8781 - val_loss: 0.5489 - learning_rate: 3.1250e-05
# Epoch 171/300
# 333/333 - 26s - 79ms/step - accuracy: 0.9219 - loss: 0.3725 - val_accuracy: 0.8784 - val_loss: 0.5484 - learning_rate: 3.1250e-05
# Epoch 172/300
# 333/333 - 26s - 79ms/step - accuracy: 0.9227 - loss: 0.3661 - val_accuracy: 0.8788 - val_loss: 0.5540 - learning_rate: 1.5625e-05
# Epoch 173/300
# 333/333 - 26s - 79ms/step - accuracy: 0.9233 - loss: 0.3684 - val_accuracy: 0.8793 - val_loss: 0.5484 - learning_rate: 1.5625e-05
# Epoch 174/300
# 333/333 - 26s - 79ms/step - accuracy: 0.9226 - loss: 0.3687 - val_accuracy: 0.8805 - val_loss: 0.5459 - learning_rate: 1.5625e-05
# Epoch 175/300
# 333/333 - 26s - 79ms/step - accuracy: 0.9259 - loss: 0.3613 - val_accuracy: 0.8817 - val_loss: 0.5444 - learning_rate: 1.5625e-05
# Epoch 176/300
# 333/333 - 26s - 79ms/step - accuracy: 0.9253 - loss: 0.3633 - val_accuracy: 0.8807 - val_loss: 0.5412 - learning_rate: 1.5625e-05
# Epoch 177/300
# 333/333 - 26s - 78ms/step - accuracy: 0.9241 - loss: 0.3647 - val_accuracy: 0.8793 - val_loss: 0.5495 - learning_rate: 1.5625e-05
# Epoch 178/300
# 333/333 - 26s - 78ms/step - accuracy: 0.9253 - loss: 0.3597 - val_accuracy: 0.8804 - val_loss: 0.5485 - learning_rate: 1.5625e-05
# Epoch 179/300
# 333/333 - 26s - 78ms/step - accuracy: 0.9259 - loss: 0.3578 - val_accuracy: 0.8821 - val_loss: 0.5466 - learning_rate: 1.5625e-05
# Epoch 180/300
# 333/333 - 26s - 78ms/step - accuracy: 0.9251 - loss: 0.3634 - val_accuracy: 0.8808 - val_loss: 0.5478 - learning_rate: 1.5625e-05
# Epoch 181/300
# 333/333 - 26s - 78ms/step - accuracy: 0.9227 - loss: 0.3652 - val_accuracy: 0.8796 - val_loss: 0.5516 - learning_rate: 1.5625e-05
# Epoch 181: early stopping
# Restoring model weights from the end of the best epoch: 141.

# %%
plt.figure(figsize=(15,6))

# Plotting the training and validation loss
plt.subplot(1, 2, 1)
plt.plot(model.history.history['loss'], label='Train Loss', color='#8502d1')
plt.plot(model.history.history['val_loss'], label='Validation Loss', color='darkorange')
plt.legend()
plt.title('Loss Evolution')

# Plotting the training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(model.history.history['accuracy'], label='Train Accuracy', color='#8502d1')
plt.plot(model.history.history['val_accuracy'], label='Validation Accuracy', color='darkorange')
plt.legend()
plt.title('Accuracy Evolution')

plt.show()

# %%
# Use the model to make predictions, evaluate on test data
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=1)

print('\nTest Accuracy:', test_acc)
print('Test Loss:    ', test_loss)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8724 - loss: 0.5725
#
# Test Accuracy: 0.8705999851226807
# Test Loss:     0.571282148361206
