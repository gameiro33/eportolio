# %% [markdown]
# # Import Libraries

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dropout, Flatten, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.models import load_model
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np

# %%
   # Configure TensorFlow to grow GPU memory allocation as needed
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# %% [markdown]
# Downloading CIFAR 10:

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %% [markdown]
# The standard practice for splitting data into training, validation, and test sets typically follows these guidelines:
# Training Set (60-80%): Used to train the model
# Validation Set (10-20%): Used for hyperparameter tuning and model selection
# Test Set (10-20%): Used for final model evaluation
#
# Since the training and test set are already split in this data set in a 1/6 proportion, we will further carve 10% out of the training set to be used for validation.
#
# Source: https://www.v7labs.com/blog/train-validation-test-set

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.15, random_state=0)

# %%
print('Train Images Shape:      ', X_train.shape)
print('Train Labels Shape:      ', y_train.shape)

print('\nValidation Images Shape: ', X_valid.shape)
print('Validation Labels Shape: ', y_valid.shape)

print('\nTest Images Shape:       ', X_test.shape)
print('Test Labels Shape:       ', y_test.shape)
# Out:
# Train Images Shape:       (42500, 32, 32, 3)
# Train Labels Shape:       (42500, 1)
#
# Validation Images Shape:  (7500, 32, 32, 3)
# Validation Labels Shape:  (7500, 1)
#
# Test Images Shape:        (10000, 32, 32, 3)
# Test Labels Shape:        (10000, 1)

# %%
# Display a 3x3 grid of random images
plt.figure(figsize=(8, 8))

# Define the class names, so that they can be shown in the plot
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# Plot 9 random images from the training set
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.imshow(X_train[i])
    plt.title(f'Class: {class_names[y_train[i][0]]}')
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
# Convert pixel values data type to float32
X_train = X_train.astype('float32')
X_test  = X_test.astype('float32')
X_valid = X_valid.astype('float32')

# Calculate the mean and standard deviation of the training images
mean = np.mean(X_train)
std  = np.std(X_train)

# Normalize the data
# The tiny value 1e-7 is added to prevent division by zero
X_train = (X_train-mean)/(std+1e-7)
X_test  = (X_test-mean) /(std+1e-7)
X_valid = (X_valid-mean)/(std+1e-7)

# %%
# One-hot encoding of labels
y_train = to_categorical(y_train, 10)
y_valid = to_categorical(y_valid, 10)
y_test  = to_categorical(y_test, 10)

# %% [markdown]
# # Data Augmentation
#
# Rotation:
#
# Source: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0
#
# Horizontal Flip:
#
# Source: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0
#
# Brightness:
#
# Source: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0
#
# Zoom:
#
# Source: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0
#
# Shearing:
#
# Source: https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0
#
# Future work. Try:
# * Patch Suffle Regularization
# * Sample Pairing
# * Random Erasing

# %%
# Data augmentation
data_generator = ImageDataGenerator(
    # Rotate images randomly by up to 15 degrees
    rotation_range=15,
    # Randomly flip images horizontally
    horizontal_flip=True,
    # Zoom images in by up to 10%
    zoom_range=0.1,
    # Change brightness by up to 10%
    brightness_range=[0.9,1.1],
    # Shear intensity (shear angle in counter-clockwise direction in degrees)
    shear_range=10,
    # Channel shift intensity
    channel_shift_range=0.1,
)

# %% [markdown]
# Using mixed precision training (FP16) which can significantly speed up training on modern GPUs

# %%
# Enable mixed precision training
tf.keras.mixed_precision.set_global_policy('mixed_float16')

# %% [markdown]
# Building the VGG16 inspired model
#
# Source: https://www.kaggle.com/code/farzadnekouei/cifar-10-image-classification-with-cnn

# %%
# Initialize a sequential model
model = Sequential()

# Set the weight decay value for L2 regularization
weight_decay = 0.0001

# Add the first convolutional layer with 32 filters of size 3x3
model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay), 
                 input_shape=X_train.shape[1:]))
# Add batch normalization layer
model.add(BatchNormalization())

# Add the second convolutional layer similar to the first
model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the first max pooling layer with pool size of 2x2
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add dropout layer with 0.2 dropout rate
model.add(Dropout(rate=0.2))

# Add the third and fourth convolutional layers with 64 filters
model.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))   
model.add(BatchNormalization())
model.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the second max pooling layer and increase dropout rate to 0.3
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.3))

# Add the fifth and sixth convolutional layers with 128 filters
model.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay))) 
model.add(BatchNormalization())
model.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the third max pooling layer and increase dropout rate to 0.4
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.4))

# Add the seventh and eighth convolutional layers with 256 filters
model.add(Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay))) 
model.add(BatchNormalization())
model.add(Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the fourth max pooling layer and increase dropout rate to 0.5
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.5))

# Flatten the tensor output from the previous layer
model.add(Flatten())

# Add a fully connected layer with softmax activation function for outputting class probabilities
model.add(Dense(10, activation='softmax'))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-04-12 18:28:20.394780: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Pro
# 2025-04-12 18:28:20.394802: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-04-12 18:28:20.394806: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2025-04-12 18:28:20.394825: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-04-12 18:28:20.394838: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 4, 4, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 4, 4, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 4, 4, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 4, 4, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 2, 2, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 2, 2, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │        10,250 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,186,346 (4.53 MB)
#  Trainable params: 1,184,426 (4.52 MB)
#  Non-trainable params: 1,920 (7.50 KB)

# %%
# Set the batch size for the training
batch_size = 256

# Set the maximum number of epochs for the training
epochs = 300

# Define the optimizer (Adam)
optimizer = Adam(learning_rate=0.0005)

# Compile the model with the defined optimizer, loss function, and metrics
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Add ReduceLROnPlateau callback
# Here, the learning rate will be reduced by half (factor=0.5) if no improvement in validation loss is observed for 10 epochs
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=0.00001)

# Add EarlyStopping callback
# Here, training will be stopped if no improvement in validation loss is observed for 40 epochs.
# The `restore_best_weights` parameter ensures that the model weights are reset to the values from the epoch
# with the best value of the monitored quantity (in this case, 'val_loss').
early_stopping = EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True, verbose=1)

# Fit the model on the training data, using the defined batch size and number of epochs
# The validation data is used to evaluate the model's performance during training
# The callbacks implemented are learning rate reduction when a plateau is reached in validation loss and
# stopping training early if no improvement is observed
model.fit(data_generator.flow(X_train, y_train, batch_size=batch_size),
          epochs=epochs,
          validation_data=(X_valid, y_valid),
          callbacks=[reduce_lr, early_stopping], 
          verbose=2)
# Out:
# Epoch 1/300
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2025-04-12 18:28:21.984332: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 167/167 - 21s - 128ms/step - accuracy: 0.2817 - loss: 2.8653 - val_accuracy: 0.1185 - val_loss: 2.9700 - learning_rate: 5.0000e-04
# Epoch 2/300
# 167/167 - 16s - 94ms/step - accuracy: 0.4163 - loss: 1.8130 - val_accuracy: 0.2384 - val_loss: 2.3830 - learning_rate: 5.0000e-04
# Epoch 3/300
# 167/167 - 16s - 95ms/step - accuracy: 0.4544 - loss: 1.6780 - val_accuracy: 0.4428 - val_loss: 1.7494 - learning_rate: 5.0000e-04
# Epoch 4/300
# 167/167 - 16s - 96ms/step - accuracy: 0.4887 - loss: 1.5709 - val_accuracy: 0.5416 - val_loss: 1.4057 - learning_rate: 5.0000e-04
# Epoch 5/300
# 167/167 - 16s - 95ms/step - accuracy: 0.5381 - loss: 1.4298 - val_accuracy: 0.5007 - val_loss: 1.9520 - learning_rate: 5.0000e-04
# Epoch 6/300
# 167/167 - 16s - 97ms/step - accuracy: 0.5594 - loss: 1.3896 - val_accuracy: 0.4365 - val_loss: 1.8437 - learning_rate: 5.0000e-04
# Epoch 7/300
# 167/167 - 17s - 102ms/step - accuracy: 0.5428 - loss: 1.4279 - val_accuracy: 0.4755 - val_loss: 1.8246 - learning_rate: 5.0000e-04
# Epoch 8/300
# 167/167 - 16s - 96ms/step - accuracy: 0.5373 - loss: 1.4517 - val_accuracy: 0.5785 - val_loss: 1.3223 - learning_rate: 5.0000e-04
# Epoch 9/300
# 167/167 - 16s - 96ms/step - accuracy: 0.5822 - loss: 1.3035 - val_accuracy: 0.6061 - val_loss: 1.2585 - learning_rate: 5.0000e-04
# Epoch 10/300
# 167/167 - 16s - 96ms/step - accuracy: 0.6024 - loss: 1.2716 - val_accuracy: 0.6475 - val_loss: 1.0915 - learning_rate: 5.0000e-04
# Epoch 11/300
# 167/167 - 16s - 96ms/step - accuracy: 0.6152 - loss: 1.2610 - val_accuracy: 0.4997 - val_loss: 1.6185 - learning_rate: 5.0000e-04
# Epoch 12/300
# 167/167 - 16s - 98ms/step - accuracy: 0.6070 - loss: 1.2643 - val_accuracy: 0.6151 - val_loss: 1.2262 - learning_rate: 5.0000e-04
# Epoch 13/300
# 167/167 - 16s - 95ms/step - accuracy: 0.6226 - loss: 1.2250 - val_accuracy: 0.6781 - val_loss: 1.0563 - learning_rate: 5.0000e-04
# Epoch 14/300
# 167/167 - 16s - 95ms/step - accuracy: 0.6236 - loss: 1.2630 - val_accuracy: 0.6672 - val_loss: 1.0637 - learning_rate: 5.0000e-04
# Epoch 15/300
# 167/167 - 16s - 97ms/step - accuracy: 0.6404 - loss: 1.1747 - val_accuracy: 0.6579 - val_loss: 1.0894 - learning_rate: 5.0000e-04
# Epoch 16/300
# 167/167 - 16s - 97ms/step - accuracy: 0.6408 - loss: 1.1931 - val_accuracy: 0.6645 - val_loss: 1.0760 - learning_rate: 5.0000e-04
# Epoch 17/300
# 167/167 - 16s - 98ms/step - accuracy: 0.6391 - loss: 1.1902 - val_accuracy: 0.6920 - val_loss: 1.0328 - learning_rate: 5.0000e-04
# Epoch 18/300
# 167/167 - 16s - 97ms/step - accuracy: 0.6651 - loss: 1.0973 - val_accuracy: 0.5448 - val_loss: 1.5733 - learning_rate: 5.0000e-04
# Epoch 19/300
# 167/167 - 16s - 96ms/step - accuracy: 0.6316 - loss: 1.2141 - val_accuracy: 0.5629 - val_loss: 1.4033 - learning_rate: 5.0000e-04
# Epoch 20/300
# 167/167 - 17s - 101ms/step - accuracy: 0.6374 - loss: 1.1916 - val_accuracy: 0.6825 - val_loss: 1.0354 - learning_rate: 5.0000e-04
# Epoch 21/300
# 167/167 - 17s - 101ms/step - accuracy: 0.6614 - loss: 1.1213 - val_accuracy: 0.6291 - val_loss: 1.2058 - learning_rate: 5.0000e-04
# Epoch 22/300
# 167/167 - 17s - 101ms/step - accuracy: 0.6691 - loss: 1.1139 - val_accuracy: 0.7132 - val_loss: 0.9375 - learning_rate: 5.0000e-04
# Epoch 23/300
# 167/167 - 16s - 97ms/step - accuracy: 0.6897 - loss: 1.0440 - val_accuracy: 0.6667 - val_loss: 1.0896 - learning_rate: 5.0000e-04
# Epoch 24/300
# 167/167 - 17s - 99ms/step - accuracy: 0.6827 - loss: 1.0669 - val_accuracy: 0.7268 - val_loss: 0.9179 - learning_rate: 5.0000e-04
# Epoch 25/300
# 167/167 - 16s - 96ms/step - accuracy: 0.6960 - loss: 1.0281 - val_accuracy: 0.7040 - val_loss: 0.9841 - learning_rate: 5.0000e-04
# Epoch 26/300
300
# 167/167 - 15s - 89ms/step - accuracy: 0.8580 - loss: 0.5414 - val_accuracy: 0.8425 - val_loss: 0.6039 - learning_rate: 1.0000e-05
# Epoch 202/300
# 167/167 - 15s - 89ms/step - accuracy: 0.8572 - loss: 0.5397 - val_accuracy: 0.8400 - val_loss: 0.6096 - learning_rate: 1.0000e-05
# Epoch 203/300
# 167/167 - 15s - 89ms/step - accuracy: 0.8608 - loss: 0.5332 - val_accuracy: 0.8400 - val_loss: 0.6104 - learning_rate: 1.0000e-05
# Epoch 204/300
# 167/167 - 15s - 90ms/step - accuracy: 0.8566 - loss: 0.5361 - val_accuracy: 0.8403 - val_loss: 0.6102 - learning_rate: 1.0000e-05
# Epoch 205/300
# 167/167 - 15s - 90ms/step - accuracy: 0.8572 - loss: 0.5367 - val_accuracy: 0.8387 - val_loss: 0.6150 - learning_rate: 1.0000e-05
# Epoch 206/300
# 167/167 - 15s - 90ms/step - accuracy: 0.8612 - loss: 0.5280 - val_accuracy: 0.8413 - val_loss: 0.6104 - learning_rate: 1.0000e-05
# Epoch 207/300
# 167/167 - 15s - 90ms/step - accuracy: 0.8572 - loss: 0.5325 - val_accuracy: 0.8383 - val_loss: 0.6161 - learning_rate: 1.0000e-05
# Epoch 208/300
# 167/167 - 435s - 3s/step - accuracy: 0.8591 - loss: 0.5350 - val_accuracy: 0.8413 - val_loss: 0.6100 - learning_rate: 1.0000e-05
# Epoch 209/300
# 167/167 - 16s - 96ms/step - accuracy: 0.8590 - loss: 0.5337 - val_accuracy: 0.8401 - val_loss: 0.6117 - learning_rate: 1.0000e-05
# Epoch 210/300
# 167/167 - 16s - 96ms/step - accuracy: 0.8573 - loss: 0.5371 - val_accuracy: 0.8393 - val_loss: 0.6152 - learning_rate: 1.0000e-05
# Epoch 211/300
# 167/167 - 16s - 96ms/step - accuracy: 0.8590 - loss: 0.5383 - val_accuracy: 0.8396 - val_loss: 0.6113 - learning_rate: 1.0000e-05
# Epoch 212/300
# 167/167 - 16s - 97ms/step - accuracy: 0.8573 - loss: 0.5404 - val_accuracy: 0.8397 - val_loss: 0.6098 - learning_rate: 1.0000e-05
# Epoch 213/300
# 167/167 - 17s - 100ms/step - accuracy: 0.8584 - loss: 0.5338 - val_accuracy: 0.8412 - val_loss: 0.6070 - learning_rate: 1.0000e-05
# Epoch 214/300
# 167/167 - 17s - 99ms/step - accuracy: 0.8600 - loss: 0.5315 - val_accuracy: 0.8403 - val_loss: 0.6086 - learning_rate: 1.0000e-05
# Epoch 215/300
# 167/167 - 16s - 98ms/step - accuracy: 0.8606 - loss: 0.5344 - val_accuracy: 0.8427 - val_loss: 0.6049 - learning_rate: 1.0000e-05
# Epoch 216/300
# 167/167 - 17s - 102ms/step - accuracy: 0.8590 - loss: 0.5358 - val_accuracy: 0.8420 - val_loss: 0.6069 - learning_rate: 1.0000e-05
# Epoch 217/300
# 167/167 - 18s - 111ms/step - accuracy: 0.8602 - loss: 0.5340 - val_accuracy: 0.8411 - val_loss: 0.6083 - learning_rate: 1.0000e-05
# Epoch 218/300
# 167/167 - 20s - 120ms/step - accuracy: 0.8600 - loss: 0.5277 - val_accuracy: 0.8411 - val_loss: 0.6072 - learning_rate: 1.0000e-05
# Epoch 219/300
# 167/167 - 21s - 126ms/step - accuracy: 0.8576 - loss: 0.5348 - val_accuracy: 0.8420 - val_loss: 0.6068 - learning_rate: 1.0000e-05
# Epoch 220/300
# 167/167 - 20s - 122ms/step - accuracy: 0.8580 - loss: 0.5320 - val_accuracy: 0.8405 - val_loss: 0.6069 - learning_rate: 1.0000e-05
# Epoch 221/300
# 167/167 - 22s - 131ms/step - accuracy: 0.8586 - loss: 0.5342 - val_accuracy: 0.8403 - val_loss: 0.6063 - learning_rate: 1.0000e-05
# Epoch 222/300
# 167/167 - 22s - 129ms/step - accuracy: 0.8606 - loss: 0.5292 - val_accuracy: 0.8405 - val_loss: 0.6060 - learning_rate: 1.0000e-05
# Epoch 223/300
# 167/167 - 23s - 140ms/step - accuracy: 0.8611 - loss: 0.5299 - val_accuracy: 0.8393 - val_loss: 0.6115 - learning_rate: 1.0000e-05
# Epoch 224/300
# 167/167 - 25s - 152ms/step - accuracy: 0.8615 - loss: 0.5319 - val_accuracy: 0.8404 - val_loss: 0.6071 - learning_rate: 1.0000e-05
# Epoch 225/300
# 167/167 - 25s - 151ms/step - accuracy: 0.8599 - loss: 0.5356 - val_accuracy: 0.8403 - val_loss: 0.6078 - learning_rate: 1.0000e-05
# Epoch 226/300
# 167/167 - 25s - 148ms/step - accuracy: 0.8603 - loss: 0.5317 - val_accuracy: 0.8409 - val_loss: 0.6064 - learning_rate: 1.0000e-05
# Epoch 227/300
# 167/167 - 23s - 140ms/step - accuracy: 0.8596 - loss: 0.5340 - val_accuracy: 0.8412 - val_loss: 0.6018 - learning_rate: 1.0000e-05
# Epoch 228/300
# 167/167 - 23s - 137ms/step - accuracy: 0.8595 - loss: 0.5310 - val_accuracy: 0.8420 - val_loss: 0.6039 - learning_rate: 1.0000e-05
# Epoch 229/300
# 167/167 - 23s - 136ms/step - accuracy: 0.8604 - loss: 0.5301 - val_accuracy: 0.8405 - val_loss: 0.6053 - learning_rate: 1.0000e-05
# Epoch 230/300
# 167/167 - 23s - 138ms/step - accuracy: 0.8599 - loss: 0.5299 - val_accuracy: 0.8408 - val_loss: 0.6047 - learning_rate: 1.0000e-05
# Epoch 231/300
# 167/167 - 23s - 139ms/step - accuracy: 0.8582 - loss: 0.5352 - val_accuracy: 0.8431 - val_loss: 0.6021 - learning_rate: 1.0000e-05
# Epoch 232/300
# 167/167 - 23s - 136ms/step - accuracy: 0.8626 - loss: 0.5266 - val_accuracy: 0.8437 - val_loss: 0.5990 - learning_rate: 1.0000e-05
# Epoch 233/300
# 167/167 - 23s - 138ms/step - accuracy: 0.8602 - loss: 0.5307 - val_accuracy: 0.8441 - val_loss: 0.5985 - learning_rate: 1.0000e-05
# Epoch 234/300
# 167/167 - 23s - 139ms/step - accuracy: 0.8617 - loss: 0.5309 - val_accuracy: 0.8411 - val_loss: 0.6039 - learning_rate: 1.0000e-05
# Epoch 235/300
# 167/167 - 23s - 135ms/step - accuracy: 0.8604 - loss: 0.5317 - val_accuracy: 0.8424 - val_loss: 0.6040 - learning_rate: 1.0000e-05
# Epoch 236/300
# 167/167 - 24s - 143ms/step - accuracy: 0.8602 - loss: 0.5324 - val_accuracy: 0.8429 - val_loss: 0.6023 - learning_rate: 1.0000e-05
# Epoch 237/300
# 167/167 - 26s - 157ms/step - accuracy: 0.8626 - loss: 0.5237 - val_accuracy: 0.8416 - val_loss: 0.6038 - learning_rate: 1.0000e-05
# Epoch 238/300
# 167/167 - 24s - 146ms/step - accuracy: 0.8613 - loss: 0.5323 - val_accuracy: 0.8420 - val_loss: 0.6011 - learning_rate: 1.0000e-05
# Epoch 239/300
# 167/167 - 24s - 143ms/step - accuracy: 0.8616 - loss: 0.5294 - val_accuracy: 0.8424 - val_loss: 0.6036 - learning_rate: 1.0000e-05
# Epoch 240/300
# 167/167 - 24s - 141ms/step - accuracy: 0.8596 - loss: 0.5303 - val_accuracy: 0.8420 - val_loss: 0.6061 - learning_rate: 1.0000e-05
# Epoch 241/300
# 167/167 - 24s - 144ms/step - accuracy: 0.8596 - loss: 0.5287 - val_accuracy: 0.8419 - val_loss: 0.6041 - learning_rate: 1.0000e-05
# Epoch 242/300
# 167/167 - 24s - 142ms/step - accuracy: 0.8630 - loss: 0.5238 - val_accuracy: 0.8416 - val_loss: 0.6041 - learning_rate: 1.0000e-05
# Epoch 243/300
# 167/167 - 24s - 142ms/step - accuracy: 0.8602 - loss: 0.5266 - val_accuracy: 0.8429 - val_loss: 0.6038 - learning_rate: 1.0000e-05
# Epoch 244/300
# 167/167 - 24s - 144ms/step - accuracy: 0.8602 - loss: 0.5290 - val_accuracy: 0.8439 - val_loss: 0.5999 - learning_rate: 1.0000e-05
# Epoch 245/300
# 167/167 - 23s - 139ms/step - accuracy: 0.8605 - loss: 0.5223 - val_accuracy: 0.8433 - val_loss: 0.5998 - learning_rate: 1.0000e-05
# Epoch 246/300
# 167/167 - 24s - 144ms/step - accuracy: 0.8606 - loss: 0.5267 - val_accuracy: 0.8420 - val_loss: 0.6025 - learning_rate: 1.0000e-05
# Epoch 247/300
# 167/167 - 24s - 145ms/step - accuracy: 0.8616 - loss: 0.5259 - val_accuracy: 0.8423 - val_loss: 0.6012 - learning_rate: 1.0000e-05
# Epoch 248/300
# 167/167 - 24s - 141ms/step - accuracy: 0.8607 - loss: 0.5281 - val_accuracy: 0.8424 - val_loss: 0.6026 - learning_rate: 1.0000e-05
# Epoch 249/300
# 167/167 - 24s - 144ms/step - accuracy: 0.8612 - loss: 0.5260 - val_accuracy: 0.8436 - val_loss: 0.6005 - learning_rate: 1.0000e-05
# Epoch 250/300
# 167/167 - 23s - 140ms/step - accuracy: 0.8624 - loss: 0.5215 - val_accuracy: 0.8429 - val_loss: 0.6012 - learning_rate: 1.0000e-05
# Epoch 251/300
# 167/167 - 24s - 142ms/step - accuracy: 0.8633 - loss: 0.5234 - val_accuracy: 0.8416 - val_loss: 0.6020 - learning_rate: 1.0000e-05
# Epoch 252/300
# 167/167 - 24s - 142ms/step - accuracy: 0.8608 - loss: 0.5261 - val_accuracy: 0.8425 - val_loss: 0.6026 - learning_rate: 1.0000e-05
# Epoch 253/300
# 167/167 - 23s - 138ms/step - accuracy: 0.8613 - loss: 0.5244 - val_accuracy: 0.8421 - val_loss: 0.6023 - learning_rate: 1.0000e-05
# Epoch 254/300
# 167/167 - 24s - 141ms/step - accuracy: 0.8592 - loss: 0.5300 - val_accuracy: 0.8431 - val_loss: 0.6004 - learning_rate: 1.0000e-05
# Epoch 255/300
# 167/167 - 24s - 142ms/step - accuracy: 0.8612 - loss: 0.5279 - val_accuracy: 0.8425 - val_loss: 0.5996 - learning_rate: 1.0000e-05
# Epoch 256/300
# 167/167 - 23s - 139ms/step - accuracy: 0.8630 - loss: 0.5240 - val_accuracy: 0.8433 - val_loss: 0.6007 - learning_rate: 1.0000e-05
# Epoch 257/300
# 167/167 - 23s - 141ms/step - accuracy: 0.8629 - loss: 0.5231 - val_accuracy: 0.8419 - val_loss: 0.6026 - learning_rate: 1.0000e-05
# Epoch 258/300
# 167/167 - 24s - 143ms/step - accuracy: 0.8612 - loss: 0.5288 - val_accuracy: 0.8411 - val_loss: 0.6045 - learning_rate: 1.0000e-05
# Epoch 259/300
# 167/167 - 24s - 141ms/step - accuracy: 0.8609 - loss: 0.5296 - val_accuracy: 0.8424 - val_loss: 0.6009 - learning_rate: 1.0000e-05
# Epoch 260/300
# 167/167 - 24s - 141ms/step - accuracy: 0.8610 - loss: 0.5267 - val_accuracy: 0.8443 - val_loss: 0.5992 - learning_rate: 1.0000e-05
# Epoch 261/300
# 167/167 - 23s - 139ms/step - accuracy: 0.8621 - loss: 0.5220 - val_accuracy: 0.8439 - val_loss: 0.5980 - learning_rate: 1.0000e-05
# Epoch 262/300
# 167/167 - 23s - 140ms/step - accuracy: 0.8613 - loss: 0.5287 - val_accuracy: 0.8435 - val_loss: 0.5980 - learning_rate: 1.0000e-05
# Epoch 263/300
# 167/167 - 24s - 143ms/step - accuracy: 0.8620 - loss: 0.5232 - val_accuracy: 0.8427 - val_loss: 0.6003 - learning_rate: 1.0000e-05
# Epoch 264/300
# 167/167 - 130s - 781ms/step - accuracy: 0.8609 - loss: 0.5287 - val_accuracy: 0.8428 - val_loss: 0.6005 - learning_rate: 1.0000e-05
# Epoch 265/300
# 167/167 - 981s - 6s/step - accuracy: 0.8610 - loss: 0.5213 - val_accuracy: 0.8435 - val_loss: 0.6016 - learning_rate: 1.0000e-05
# Epoch 266/300
# 167/167 - 23s - 140ms/step - accuracy: 0.8622 - loss: 0.5251 - val_accuracy: 0.8435 - val_loss: 0.6017 - learning_rate: 1.0000e-05
# Epoch 267/300
# 167/167 - 196s - 1s/step - accuracy: 0.8618 - loss: 0.5193 - val_accuracy: 0.8445 - val_loss: 0.5995 - learning_rate: 1.0000e-05
# Epoch 268/300
# 167/167 - 26s - 155ms/step - accuracy: 0.8589 - loss: 0.5252 - val_accuracy: 0.8432 - val_loss: 0.5988 - learning_rate: 1.0000e-05
# Epoch 269/300
# 167/167 - 24s - 145ms/step - accuracy: 0.8620 - loss: 0.5257 - val_accuracy: 0.8429 - val_loss: 0.5994 - learning_rate: 1.0000e-05
# Epoch 270/300
# 167/167 - 22s - 133ms/step - accuracy: 0.8652 - loss: 0.5204 - val_accuracy: 0.8432 - val_loss: 0.5993 - learning_rate: 1.0000e-05
# Epoch 271/300
# 167/167 - 23s - 137ms/step - accuracy: 0.8622 - loss: 0.5234 - val_accuracy: 0.8432 - val_loss: 0.5989 - learning_rate: 1.0000e-05
# Epoch 272/300
# 167/167 - 23s - 135ms/step - accuracy: 0.8628 - loss: 0.5190 - val_accuracy: 0.8449 - val_loss: 0.5988 - learning_rate: 1.0000e-05
# Epoch 273/300
# 167/167 - 22s - 133ms/step - accuracy: 0.8627 - loss: 0.5213 - val_accuracy: 0.8445 - val_loss: 0.5998 - learning_rate: 1.0000e-05
# Epoch 274/300
# 167/167 - 23s - 135ms/step - accuracy: 0.8630 - loss: 0.5224 - val_accuracy: 0.8447 - val_loss: 0.5994 - learning_rate: 1.0000e-05
# Epoch 275/300
# 167/167 - 22s - 133ms/step - accuracy: 0.8615 - loss: 0.5214 - val_accuracy: 0.8444 - val_loss: 0.5990 - learning_rate: 1.0000e-05
# Epoch 276/300
# 167/167 - 22s - 134ms/step - accuracy: 0.8652 - loss: 0.5163 - val_accuracy: 0.8441 - val_loss: 0.5983 - learning_rate: 1.0000e-05
# Epoch 277/300
# 167/167 - 23s - 135ms/step - accuracy: 0.8613 - loss: 0.5224 - val_accuracy: 0.8461 - val_loss: 0.5984 - learning_rate: 1.0000e-05
# Epoch 278/300
# 167/167 - 22s - 132ms/step - accuracy: 0.8620 - loss: 0.5216 - val_accuracy: 0.8447 - val_loss: 0.5991 - learning_rate: 1.0000e-05
# Epoch 279/300
# 167/167 - 22s - 134ms/step - accuracy: 0.8628 - loss: 0.5210 - val_accuracy: 0.8448 - val_loss: 0.5986 - learning_rate: 1.0000e-05
# Epoch 280/300
# 167/167 - 23s - 136ms/step - accuracy: 0.8640 - loss: 0.5180 - val_accuracy: 0.8435 - val_loss: 0.5996 - learning_rate: 1.0000e-05
# Epoch 281/300
# 167/167 - 22s - 133ms/step - accuracy: 0.8648 - loss: 0.5137 - val_accuracy: 0.8444 - val_loss: 0.5981 - learning_rate: 1.0000e-05
# Epoch 282/300
# 167/167 - 23s - 136ms/step - accuracy: 0.8607 - loss: 0.5263 - val_accuracy: 0.8457 - val_loss: 0.5959 - learning_rate: 1.0000e-05
# Epoch 283/300
# 167/167 - 22s - 135ms/step - accuracy: 0.8640 - loss: 0.5216 - val_accuracy: 0.8441 - val_loss: 0.5982 - learning_rate: 1.0000e-05
# Epoch 284/300
# 167/167 - 22s - 135ms/step - accuracy: 0.8612 - loss: 0.5145 - val_accuracy: 0.8444 - val_loss: 0.5963 - learning_rate: 1.0000e-05
# Epoch 285/300
# 167/167 - 23s - 138ms/step - accuracy: 0.8629 - loss: 0.5202 - val_accuracy: 0.8435 - val_loss: 0.5977 - learning_rate: 1.0000e-05
# Epoch 286/300
# 167/167 - 22s - 134ms/step - accuracy: 0.8604 - loss: 0.5235 - val_accuracy: 0.8444 - val_loss: 0.5963 - learning_rate: 1.0000e-05
# Epoch 287/300
# 167/167 - 22s - 135ms/step - accuracy: 0.8599 - loss: 0.5235 - val_accuracy: 0.8428 - val_loss: 0.6006 - learning_rate: 1.0000e-05
# Epoch 288/300
# 167/167 - 23s - 136ms/step - accuracy: 0.8638 - loss: 0.5232 - val_accuracy: 0.8437 - val_loss: 0.6021 - learning_rate: 1.0000e-05
# Epoch 289/300
# 167/167 - 22s - 134ms/step - accuracy: 0.8650 - loss: 0.5152 - val_accuracy: 0.8424 - val_loss: 0.6008 - learning_rate: 1.0000e-05
# Epoch 290/300
# 167/167 - 23s - 136ms/step - accuracy: 0.8627 - loss: 0.5187 - val_accuracy: 0.8445 - val_loss: 0.5975 - learning_rate: 1.0000e-05
# Epoch 291/300
# 167/167 - 23s - 136ms/step - accuracy: 0.8637 - loss: 0.5175 - val_accuracy: 0.8441 - val_loss: 0.5999 - learning_rate: 1.0000e-05
# Epoch 292/300
# 167/167 - 23s - 137ms/step - accuracy: 0.8641 - loss: 0.5178 - val_accuracy: 0.8441 - val_loss: 0.5982 - learning_rate: 1.0000e-05
# Epoch 293/300
# 167/167 - 22s - 135ms/step - accuracy: 0.8670 - loss: 0.5109 - val_accuracy: 0.8443 - val_loss: 0.5987 - learning_rate: 1.0000e-05
# Epoch 294/300
# 167/167 - 23s - 138ms/step - accuracy: 0.8628 - loss: 0.5177 - val_accuracy: 0.8433 - val_loss: 0.5986 - learning_rate: 1.0000e-05
# Epoch 295/300
# 167/167 - 22s - 134ms/step - accuracy: 0.8650 - loss: 0.5091 - val_accuracy: 0.8437 - val_loss: 0.5982 - learning_rate: 1.0000e-05
# Epoch 296/300
# 167/167 - 993s - 6s/step - accuracy: 0.8648 - loss: 0.5149 - val_accuracy: 0.8433 - val_loss: 0.5972 - learning_rate: 1.0000e-05
# Epoch 297/300
# 167/167 - 23s - 138ms/step - accuracy: 0.8630 - loss: 0.5153 - val_accuracy: 0.8419 - val_loss: 0.5999 - learning_rate: 1.0000e-05
# Epoch 298/300
# 167/167 - 1003s - 6s/step - accuracy: 0.8648 - loss: 0.5173 - val_accuracy: 0.8432 - val_loss: 0.6018 - learning_rate: 1.0000e-05
# Epoch 299/300
# 167/167 - 24s - 144ms/step - accuracy: 0.8638 - loss: 0.5136 - val_accuracy: 0.8439 - val_loss: 0.6027 - learning_rate: 1.0000e-05
# Epoch 300/300
# 167/167 - 934s - 6s/step - accuracy: 0.8645 - loss: 0.5164 - val_accuracy: 0.8431 - val_loss: 0.5996 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 282.

# %%
plt.figure(figsize=(15,6))

# Plotting the training and validation loss
plt.subplot(1, 2, 1)
plt.plot(model.history.history['loss'], label='Train Loss', color='#8502d1')
plt.plot(model.history.history['val_loss'], label='Validation Loss', color='darkorange')
plt.legend()
plt.title('Loss Evolution')

# Plotting the training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(model.history.history['accuracy'], label='Train Accuracy', color='#8502d1')
plt.plot(model.history.history['val_accuracy'], label='Validation Accuracy', color='darkorange')
plt.legend()
plt.title('Accuracy Evolution')

plt.show()

# %%
# Use the model to make predictions, evaluate on test data
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=1)

print('\nTest Accuracy:', test_acc)
print('Test Loss:    ', test_loss)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.8446 - loss: 0.6187
#
# Test Accuracy: 0.8436999917030334
# Test Loss:     0.6142386794090271
